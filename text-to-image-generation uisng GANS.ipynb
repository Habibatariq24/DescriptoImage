# %% [markdown]
# L22-7501,L22-7515,L227540,L22-7492

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<2.1.0,>=1.26.0->tensorflow) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<2.1.0,>=1.26.0->tensorflow) (2024.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
pip install diffusers transformers accelerate datasets ftfy torchvision tqdm safetensors peft
# Out:
# Requirement already satisfied: diffusers in /usr/local/lib/python3.11/dist-packages (0.32.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.3.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.5.0)
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.20.1+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (0.5.2)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.14.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from diffusers) (8.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from diffusers) (3.18.0)
# Requirement already satisfied: huggingface-hub>=0.23.2 in /usr/local/lib/python3.11/dist-packages (from diffusers) (0.30.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from diffusers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from diffusers) (2.32.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from diffusers) (11.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (7.0.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.5.1+cu124)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.16)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy) (0.2.13)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.19.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->diffusers) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->diffusers) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->diffusers) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->diffusers) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->diffusers) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->diffusers) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (2025.1.31)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->diffusers) (3.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->diffusers) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->diffusers) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->diffusers) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->diffusers) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->diffusers) (2024.2.0)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.1 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 8.9 MB/s eta 0:00:00
# Installing collected packages: ftfy, fsspec
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.12.0 which is incompatible.
# bigframes 1.36.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# Successfully installed fsspec-2024.12.0 ftfy-6.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pillow torchvision
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.20.1+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.5.1 in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.5.1+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.5.1->torchvision)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.5.1->torchvision)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.5.1->torchvision)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.5.1->torchvision)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.5.1->torchvision)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.5.1->torchvision)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.5.1->torchvision)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.5.1->torchvision) (1.3.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.5.1->torchvision) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision) (2024.2.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.9 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.6 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.0 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pylibcugraph-cu12 24.12.0 requires pylibraft-cu12==24.12.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 24.12.0 requires rmm-cu12==24.12.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Reshape, Conv2DTranspose, Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
import cv2 #
# Out:
# 2025-05-10 13:33:04.112297: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746883984.315470      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746883984.372525      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# **Downlaoding Image From URL**

# %%
import pandas as pd
import os
import requests
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm

# Load your dataset
df = pd.read_csv("/kaggle/input/fashion-csv/fashion.csv")

# Create directory to save images
image_dir = "fashion_images"
os.makedirs(image_dir, exist_ok=True)

# Function to download one image
def download_image(index, url):
    image_filename = os.path.join(image_dir, f"{index}.jpg")
    try:
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            with open(image_filename, 'wb') as f:
                f.write(response.content)
            return image_filename
    except Exception as e:
        pass
    return None

# Use ThreadPoolExecutor for parallel downloading
image_paths = [None] * len(df)

with ThreadPoolExecutor(max_workers=20) as executor:
    futures = {
        executor.submit(download_image, idx, row["ImageURL"]): idx
        for idx, row in df.iterrows()
    }

    for future in tqdm(as_completed(futures), total=len(futures)):
        idx = futures[future]
        result = future.result()
        image_paths[idx] = result

# Add image paths to DataFrame
df["ImagePath"] = image_paths
df.to_csv("fashion_dataset_with_images.csv", index=False)
# Out:
# 100%|██████████| 2906/2906 [00:17<00:00, 163.69it/s]

# %% [markdown]
# **# Load dataset**

# %%
# Load dataset
df = pd.read_csv('/kaggle/working/fashion_dataset_with_images.csv')


df.head()
# Out:
#    ProductId Gender Category SubCategory ProductType Colour   Usage  \
# 0      42419  Girls  Apparel     Topwear        Tops  White  Casual
# 1      34009  Girls  Apparel     Topwear        Tops  Black  Casual
# 2      40143  Girls  Apparel     Topwear        Tops   Blue  Casual
# 3      23623  Girls  Apparel     Topwear        Tops   Pink  Casual
# 4      47154  Girls  Apparel  Bottomwear      Capris  Black  Casual
#
#                                   ProductTitle      Image  \
# 0           Gini and Jony Girls Knit White Top  42419.jpg
# 1                Gini and Jony Girls Black Top  34009.jpg
# 2  Gini and Jony Girls Pretty Blossom Blue Top  40143.jpg
# 3   Doodle Kids Girls Pink I love Shopping Top  23623.jpg
# 4             Gini and Jony Girls Black Capris  47154.jpg
#
#                                             ImageURL             ImagePath
# 0  http://assets.myntassets.com/v1/images/style/p...  fashion_images/0.jpg
# 1  http://assets.myntassets.com/v1/images/style/p...  fashion_images/1.jpg
# 2  http://assets.myntassets.com/v1/images/style/p...  fashion_images/2.jpg
# 3  http://assets.myntassets.com/v1/images/style/p...  fashion_images/3.jpg
# 4  http://assets.myntassets.com/v1/images/style/p...  fashion_images/4.jpg

# %%
df['Gender'].unique()
# Out:
# array(['Girls', 'Boys', 'Men', 'Women'], dtype=object)

# %%
rows, cols = df.shape
print(f"Dataset contains {rows} rows and {cols} columns.")
# Out:
# Dataset contains 2906 rows and 11 columns.

# %% [markdown]
# **Class Imbalance**

# %%
from imblearn.over_sampling import SMOTE
import numpy as np

if 'Category' in df.columns:
    class_counts = df['Category'].value_counts()
    print("\nClass Distribution Before Balancing:\n", class_counts)

    # Check for class imbalance (if min class < 50% of max class)
    min_class_count = class_counts.min()
    max_class_count = class_counts.max()

    if min_class_count / max_class_count < 0.5:
        print("\nApplying SMOTE to balance the dataset...\n")

        numerical_features = df.select_dtypes(include=np.number).drop(columns=['Category'], errors='ignore')

        smote = SMOTE(random_state=42)
        X_resampled, y_resampled = smote.fit_resample(numerical_features, df['Category'])
        balanced_df = pd.DataFrame(X_resampled, columns=numerical_features.columns)
        balanced_df['Category'] = y_resampled

        print("\nClass Distribution After Balancing:\n", balanced_df['Category'].value_counts())
    else:
        print("\nDataset is already balanced. No SMOTE applied.\n")
else:
    print("Category column not found in the dataset.")
# Out:
# Class Distribution Before Balancing:
#  Category
# Footwear    1580
# Apparel     1326
# Name: count, dtype: int64
#
# Dataset is already balanced. No SMOTE applied.

# %% [markdown]
# **Combining Images**

# %% [markdown]
# **Checking nulls**

# %%
df.isnull().sum()
# Out:
# ProductId       0
# Gender          0
# Category        0
# SubCategory     0
# ProductType     0
# Colour          0
# Usage           0
# ProductTitle    0
# Image           0
# ImageURL        0
# ImagePath       0
# dtype: int64

# %%
import pandas as pd
import re



def strip_before_gender(name):
    if pd.isna(name):
        return name  # skip NaNs
    match = re.search(r'\b(Girls|Boys|Men|Women)\b', name, flags=re.IGNORECASE)
    if match:
        return name[match.start():]
    return name

df['CleanedProductTitle'] = df['ProductTitle'].apply(strip_before_gender)
print(df[['ProductTitle','CleanedProductTitle' ]].head())
# Out:
#                                   ProductTitle             CleanedProductTitle
# 0           Gini and Jony Girls Knit White Top            Girls Knit White Top
# 1                Gini and Jony Girls Black Top                 Girls Black Top
# 2  Gini and Jony Girls Pretty Blossom Blue Top   Girls Pretty Blossom Blue Top
# 3   Doodle Kids Girls Pink I love Shopping Top  Girls Pink I love Shopping Top
# 4             Gini and Jony Girls Black Capris              Girls Black Capris

# %%
import re

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'http\S+|www\S+', '', text)         # Remove URLs
    text = re.sub(r'[^a-z0-9 ]', '', text)             # Keep only alphanumeric + spaces
    text = re.sub(r'\s+', ' ', text).strip()           # Normalize spaces
    return text

# Apply cleaning to each column before combining
df['Usage_clean'] = df['Usage'].apply(clean_text)
df['ProductType_clean'] = df['CleanedProductTitle'].apply(clean_text)

# Now combine the cleaned columns
df["CombinedTitle"] = df['Usage_clean'] +  " " + df['CleanedProductTitle']
# Show result
print(df["CombinedTitle"].head())
# Out:
# 0              casual Girls Knit White Top
# 1                   casual Girls Black Top
# 2     casual Girls Pretty Blossom Blue Top
# 3    casual Girls Pink I love Shopping Top
# 4                casual Girls Black Capris
# Name: CombinedTitle, dtype: object

# %% [markdown]
# **Padding and Tokenizizng**

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Initialize tokenizer
tokenizer = Tokenizer(num_words=5000, oov_token="<OOV>")
tokenizer.fit_on_texts(df['CombinedTitle'])

# Convert to sequences
sequences = tokenizer.texts_to_sequences(df['CombinedTitle'])

# Find max sequence length
max_length = max(len(seq) for seq in sequences)

# Pad sequences
padded_captions = pad_sequences(sequences, maxlen=max_length, padding='post')

# Vocabulary size
vocab_size = len(tokenizer.word_index) + 1

print(f"Vocabulary Size: {vocab_size}")
print(f"Max Sequence Length: {max_length}")
# Out:
# Vocabulary Size: 1155
# Max Sequence Length: 12

# %% [markdown]
# **preprocessing iamge**

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np

image_size = (64, 64)

def load_and_preprocess_image(img_path):
    img = load_img(img_path, target_size=image_size)
    img = img_to_array(img) / 255.0  # normalize to [0, 1]
    return img

# Filter valid image paths
df = df[df['ImagePath'].notnull() & df['CombinedTitle'].notnull()]

# Load images
image_data = np.array([load_and_preprocess_image(path) for path in df['ImagePath']])

# %%
import matplotlib.pyplot as plt
import random
from PIL import Image
valid_image_paths = df['ImagePath'].dropna().tolist()
random_image_path = random.choice(valid_image_paths)

original_image = Image.open(random_image_path)
processed_image = load_and_preprocess_image(random_image_path)

fig, axes = plt.subplots(1, 2, figsize=(10, 5))

axes[0].imshow(original_image)
axes[0].set_title("Original Image")
axes[0].axis("off")

axes[1].imshow(processed_image)
axes[1].set_title("Processed Image (Normalized)")
axes[1].axis("off")

plt.show()

# %% [markdown]
# **Models **

# %% [markdown]
# **Simple GAN**

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Embedding, LSTM, Concatenate, BatchNormalization, LeakyReLU, Conv2DTranspose, Conv2D
from tensorflow.keras.models import Model

# Parameters
vocab_size = 1155
max_caption_len = 12
embedding_dim = 100
noise_dim = 100
image_shape = (64, 64, 3)

# Text Encoder
def build_text_encoder():
    caption_input = Input(shape=(max_caption_len,))
    x = Embedding(vocab_size, embedding_dim)(caption_input)
    x = LSTM(128)(x)
    return Model(caption_input, x, name="TextEncoder")

# Generator
def build_generator():
    text_encoder = build_text_encoder()
    noise_input = Input(shape=(noise_dim,))
    caption_input = Input(shape=(max_caption_len,))

    text_features = text_encoder(caption_input)
    merged = Concatenate()([noise_input, text_features])

    x = Dense(8*8*256, use_bias=False)(merged)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = Reshape((8, 8, 256))(x)

    x = Conv2DTranspose(128, (5,5), strides=(2,2), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(64, (5,5), strides=(2,2), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(3, (5,5), strides=(2,2), padding='same', activation='tanh')(x)

    return Model([noise_input, caption_input], x, name="Generator")

# Discriminator
def build_discriminator():
    text_encoder = build_text_encoder()
    image_input = Input(shape=image_shape)
    caption_input = Input(shape=(max_caption_len,))

    text_features = text_encoder(caption_input)
    text_features = Dense(image_shape[0] * image_shape[1])(text_features)
    text_features = Reshape((image_shape[0], image_shape[1], 1))(text_features)

    merged = Concatenate()([image_input, text_features])

    x = Conv2D(64, (5,5), strides=(2,2), padding='same')(merged)
    x = LeakyReLU()(x)

    x = Conv2D(128, (5,5), strides=(2,2), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Flatten()(x)
    x = Dense(1, activation='sigmoid')(x)

    return Model([image_input, caption_input], x, name="Discriminator")

# Create models
generator = build_generator()
discriminator = build_discriminator()

generator.summary()
discriminator.summary()
# Out:
# Model: "Generator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_24            │ (None, 12)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_23            │ (None, 100)            │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TextEncoder (Functional)  │ (None, 128)            │        232,748 │ input_layer_24[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_7             │ (None, 228)            │              0 │ input_layer_23[0][0],  │
# │ (Concatenate)             │                        │                │ TextEncoder[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_18 (Dense)          │ (None, 16384)          │      3,735,552 │ concatenate_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 16384)          │         65,536 │ dense_18[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_21            │ (None, 16384)          │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_8 (Reshape)       │ (None, 8, 8, 256)      │              0 │ leaky_re_lu_21[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_18       │ (None, 16, 16, 128)    │        819,200 │ reshape_8[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 16, 16, 128)    │            512 │ conv2d_transpose_18[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_22            │ (None, 16, 16, 128)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_19       │ (None, 32, 32, 64)     │        204,800 │ leaky_re_lu_22[0][0]   │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 32, 32, 64)     │            256 │ conv2d_transpose_19[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_23            │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_20       │ (None, 64, 64, 3)      │          4,803 │ leaky_re_lu_23[0][0]   │
# │ (Conv2DTranspose)         │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 5,063,407 (19.32 MB)
#  Trainable params: 5,030,255 (19.19 MB)
#  Non-trainable params: 33,152 (129.50 KB)
# Model: "Discriminator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_27            │ (None, 12)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TextEncoder (Functional)  │ (None, 128)            │        232,748 │ input_layer_27[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_19 (Dense)          │ (None, 4096)           │        528,384 │ TextEncoder[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_26            │ (None, 64, 64, 3)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_9 (Reshape)       │ (None, 64, 64, 1)      │              0 │ dense_19[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_8             │ (None, 64, 64, 4)      │              0 │ input_layer_26[0][0],  │
# │ (Concatenate)             │                        │                │ reshape_9[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 32, 32, 64)     │          6,464 │ concatenate_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_24            │ (None, 32, 32, 64)     │              0 │ conv2d_6[0][0]         │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 16, 16, 128)    │        204,928 │ leaky_re_lu_24[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_18    │ (None, 16, 16, 128)    │            512 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_25            │ (None, 16, 16, 128)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_3 (Flatten)       │ (None, 32768)          │              0 │ leaky_re_lu_25[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_20 (Dense)          │ (None, 1)              │         32,769 │ flatten_3[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,005,805 (3.84 MB)
#  Trainable params: 1,005,549 (3.84 MB)
#  Non-trainable params: 256 (1.00 KB)

# %% [markdown]
# **Traing on 50 epochs**

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

BATCH_SIZE = 64
EPOCHS = 50
noise_dim = 100
BUFFER_SIZE = image_data.shape[0]

# Prepare dataset
dataset = tf.data.Dataset.from_tensor_slices((image_data, padded_captions))
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

# Optimizers
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# Loss function (Binary Crossentropy)
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    return real_loss + fake_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# Training step (per batch)
@tf.function
def train_step(images, captions):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator([noise, captions], training=True)

        real_output = discriminator([images, captions], training=True)
        fake_output = discriminator([generated_images, captions], training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return gen_loss, disc_loss

# Generate and save images for specific captions
def generate_and_save_images(model, captions, epoch):
    noise = tf.random.normal([len(captions), noise_dim])
    generated_images = model([noise, captions], training=False)

    plt.figure(figsize=(12, 4))
    for i in range(len(captions)):
        plt.subplot(1, len(captions), i+1)
        plt.imshow((generated_images[i].numpy() + 1) / 2.0)  # Rescale images
        plt.axis('off')
    plt.suptitle(f'Epoch {epoch}')
    plt.show()

# Define 2 specific captions to monitor during training
specific_captions = [
    "ethnic Boys Printed Maroon Kurta",
    "sports Men Gel Running White Sports Shoes",
    "casual Men Aventura Sandal",
    "casual Boys Expressions Yellow T-shirt"
]


# Convert captions to padded format (ensure they match your tokenization & padding)
specific_captions_padded = tokenizer.texts_to_sequences(specific_captions)
specific_captions_padded = tf.keras.preprocessing.sequence.pad_sequences(specific_captions_padded, maxlen=max_caption_len, padding='post')

# Start training
for epoch in range(1, EPOCHS + 1):
    print(f"\nEpoch {epoch}/{EPOCHS}")
    for batch_images, batch_captions in dataset:
        g_loss, d_loss = train_step(batch_images, batch_captions)

    print(f"Generator Loss: {g_loss.numpy():.4f}, Discriminator Loss: {d_loss.numpy():.4f}")

    # Generate and save images for the specific captions only at the final epoch
    if epoch == EPOCHS:
        sample_captions = tf.convert_to_tensor(specific_captions_padded)
        generate_and_save_images(generator, sample_captions, epoch)
# Out:
# Epoch 1/50
# Generator Loss: 2.6496, Discriminator Loss: 0.1159
#
# Epoch 2/50
# Generator Loss: 3.3716, Discriminator Loss: 0.1672
#
# Epoch 3/50
# Generator Loss: 6.1282, Discriminator Loss: 1.3328
#
# Epoch 4/50
# Generator Loss: 3.5231, Discriminator Loss: 0.3079
#
# Epoch 5/50
# Generator Loss: 5.2779, Discriminator Loss: 0.5075
#
# Epoch 6/50
# Generator Loss: 1.6302, Discriminator Loss: 0.3386
#
# Epoch 7/50
# Generator Loss: 5.1169, Discriminator Loss: 0.7451
#
# Epoch 8/50
# Generator Loss: 5.3136, Discriminator Loss: 0.7309
#
# Epoch 9/50
# Generator Loss: 4.1762, Discriminator Loss: 0.0411
#
# Epoch 10/50
# Generator Loss: 0.6229, Discriminator Loss: 1.0761
#
# Epoch 11/50
# Generator Loss: 1.9799, Discriminator Loss: 0.2859
#
# Epoch 12/50
# Generator Loss: 4.4205, Discriminator Loss: 0.0769
#
# Epoch 13/50
# Generator Loss: 4.9183, Discriminator Loss: 0.1885
#
# Epoch 14/50
# Generator Loss: 4.5824, Discriminator Loss: 0.0661
#
# Epoch 15/50
# Generator Loss: 6.1058, Discriminator Loss: 0.2605
#
# Epoch 16/50
# Generator Loss: 4.5587, Discriminator Loss: 0.4033
#
# Epoch 17/50
# Generator Loss: 1.3029, Discriminator Loss: 0.4598
#
# Epoch 18/50
# Generator Loss: 2.2622, Discriminator Loss: 0.2158
#
# Epoch 19/50
# Generator Loss: 3.8973, Discriminator Loss: 0.0616
#
# Epoch 20/50
# Generator Loss: 1.5328, Discriminator Loss: 0.4110
#
# Epoch 21/50
# Generator Loss: 1.4235, Discriminator Loss: 0.3988
#
# Epoch 22/50
# Generator Loss: 2.6136, Discriminator Loss: 0.1674
#
# Epoch 23/50
# Generator Loss: 3.4375, Discriminator Loss: 0.0522
#
# Epoch 24/50
# Generator Loss: 3.6762, Discriminator Loss: 0.1824
#
# Epoch 25/50
# Generator Loss: 3.1792, Discriminator Loss: 0.1903
#
# Epoch 26/50
# Generator Loss: 4.8547, Discriminator Loss: 0.2154
#
# Epoch 27/50
# Generator Loss: 3.8942, Discriminator Loss: 0.0691
#
# Epoch 28/50
# Generator Loss: 6.3213, Discriminator Loss: 0.0288
#
# Epoch 29/50
# Generator Loss: 3.6155, Discriminator Loss: 0.1112
#
# Epoch 30/50
# Generator Loss: 0.9119, Discriminator Loss: 0.7031
#
# Epoch 31/50
# Generator Loss: 2.1539, Discriminator Loss: 0.2117
#
# Epoch 32/50
# Generator Loss: 1.9203, Discriminator Loss: 0.2307
#
# Epoch 33/50
# Generator Loss: 6.6033, Discriminator Loss: 0.2157
#
# Epoch 34/50
# Generator Loss: 6.1432, Discriminator Loss: 0.2921
#
# Epoch 35/50
# Generator Loss: 2.9774, Discriminator Loss: 0.1352
#
# Epoch 36/50
# Generator Loss: 3.1337, Discriminator Loss: 0.0699
#
# Epoch 37/50
# Generator Loss: 4.4229, Discriminator Loss: 0.0394
#
# Epoch 38/50
# Generator Loss: 3.1791, Discriminator Loss: 0.1675
#
# Epoch 39/50
# Generator Loss: 1.6916, Discriminator Loss: 0.3208
#
# Epoch 40/50
# Generator Loss: 0.8210, Discriminator Loss: 0.9067
#
# Epoch 41/50
# Generator Loss: 3.1169, Discriminator Loss: 0.1882
#
# Epoch 42/50
# Generator Loss: 3.4811, Discriminator Loss: 0.0519
#
# Epoch 43/50
# Generator Loss: 3.7812, Discriminator Loss: 0.0795
#
# Epoch 44/50
# Generator Loss: 6.7825, Discriminator Loss: 0.2975
#
# Epoch 45/50
# Generator Loss: 3.3021, Discriminator Loss: 0.0661
#
# Epoch 46/50
# Generator Loss: 4.8221, Discriminator Loss: 0.2155
#
# Epoch 47/50
# Generator Loss: 1.8046, Discriminator Loss: 0.2601
#
# Epoch 48/50
# Generator Loss: 2.9725, Discriminator Loss: 0.1296
#
# Epoch 49/50
# Generator Loss: 1.5666, Discriminator Loss: 0.3400
#
# Epoch 50/50
# Generator Loss: 4.2893, Discriminator Loss: 0.0764

# %% [markdown]
# **Training on 200**

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

BATCH_SIZE = 64
EPOCHS = 200
noise_dim = 100
BUFFER_SIZE = image_data.shape[0]

# Prepare dataset
dataset = tf.data.Dataset.from_tensor_slices((image_data, padded_captions))
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

# Optimizers
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# Loss function (Binary Crossentropy)
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    return real_loss + fake_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# Training step (per batch)
@tf.function
def train_step(images, captions):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator([noise, captions], training=True)

        real_output = discriminator([images, captions], training=True)
        fake_output = discriminator([generated_images, captions], training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return gen_loss, disc_loss

# Generate and save images for specific captions
def generate_and_save_images(model, captions, epoch):
    noise = tf.random.normal([len(captions), noise_dim])
    generated_images = model([noise, captions], training=False)

    plt.figure(figsize=(12, 4))
    for i in range(len(captions)):
        plt.subplot(1, len(captions), i+1)
        plt.imshow((generated_images[i].numpy() + 1) / 2.0)  # Rescale images
        plt.axis('off')
    plt.suptitle(f'Epoch {epoch}')
    plt.show()

# Define 2 specific captions to monitor during training
specific_captions = [
    "ethnic Boys Printed Maroon Kurta",
    "sports Men Gel Running White Sports Shoes",
    "casual Men Aventura Sandal",
    "casual Boys Expressions Yellow T-shirt"
]

# Convert captions to padded format (ensure they match your tokenization & padding)
specific_captions_padded = tokenizer.texts_to_sequences(specific_captions)
specific_captions_padded = tf.keras.preprocessing.sequence.pad_sequences(specific_captions_padded, maxlen=max_caption_len, padding='post')

# Start training
for epoch in range(1, EPOCHS + 1):
    print(f"\nEpoch {epoch}/{EPOCHS}")
    for batch_images, batch_captions in dataset:
        g_loss, d_loss = train_step(batch_images, batch_captions)

    print(f"Generator Loss: {g_loss.numpy():.4f}, Discriminator Loss: {d_loss.numpy():.4f}")

    # Generate and save images for the specific captions only at the final epoch
    if epoch == EPOCHS:
        sample_captions = tf.convert_to_tensor(specific_captions_padded)
        generate_and_save_images(generator, sample_captions, epoch)
# Out:
# Epoch 1/200
# Generator Loss: 2.5260, Discriminator Loss: 0.1618
#
# Epoch 2/200
# Generator Loss: 4.5836, Discriminator Loss: 0.9371
#
# Epoch 3/200
# Generator Loss: 1.1776, Discriminator Loss: 0.5176
#
# Epoch 4/200
# Generator Loss: 3.4073, Discriminator Loss: 0.2794
#
# Epoch 5/200
# Generator Loss: 1.8403, Discriminator Loss: 0.2405
#
# Epoch 6/200
# Generator Loss: 1.9743, Discriminator Loss: 0.2103
#
# Epoch 7/200
# Generator Loss: 1.6652, Discriminator Loss: 0.4857
#
# Epoch 8/200
# Generator Loss: 3.1720, Discriminator Loss: 0.1877
#
# Epoch 9/200
# Generator Loss: 2.1810, Discriminator Loss: 0.7532
#
# Epoch 10/200
# Generator Loss: 2.3668, Discriminator Loss: 0.1731
#
# Epoch 11/200
# Generator Loss: 3.8293, Discriminator Loss: 0.6029
#
# Epoch 12/200
# Generator Loss: 1.4747, Discriminator Loss: 0.3523
#
# Epoch 13/200
# Generator Loss: 3.4500, Discriminator Loss: 0.3814
#
# Epoch 14/200
# Generator Loss: 2.0137, Discriminator Loss: 0.2145
#
# Epoch 15/200
# Generator Loss: 0.8274, Discriminator Loss: 0.7180
#
# Epoch 16/200
# Generator Loss: 3.3263, Discriminator Loss: 0.0880
#
# Epoch 17/200
# Generator Loss: 3.6697, Discriminator Loss: 0.2104
#
# Epoch 18/200
# Generator Loss: 3.5977, Discriminator Loss: 0.2540
#
# Epoch 19/200
# Generator Loss: 3.6346, Discriminator Loss: 0.1787
#
# Epoch 20/200
# Generator Loss: 1.5320, Discriminator Loss: 0.3571
#
# Epoch 21/200
# Generator Loss: 3.3732, Discriminator Loss: 0.1964
#
# Epoch 22/200
# Generator Loss: 1.0473, Discriminator Loss: 0.5766
#
# Epoch 23/200
# Generator Loss: 4.3724, Discriminator Loss: 0.3396
#
# Epoch 24/200
# Generator Loss: 2.4036, Discriminator Loss: 0.2183
#
# Epoch 25/200
# Generator Loss: 2.6745, Discriminator Loss: 0.1145
#
# Epoch 26/200
# Generator Loss: 0.9661, Discriminator Loss: 0.5778
#
# Epoch 27/200
# Generator Loss: 3.7848, Discriminator Loss: 0.1448
#
# Epoch 28/200
# Generator Loss: 0.9472, Discriminator Loss: 0.8886
#
# Epoch 29/200
# Generator Loss: 3.7629, Discriminator Loss: 0.4764
#
# Epoch 30/200
# Generator Loss: 3.5060, Discriminator Loss: 0.2718
#
# Epoch 31/200
# Generator Loss: 3.4074, Discriminator Loss: 0.4842
#
# Epoch 32/200
# Generator Loss: 4.8817, Discriminator Loss: 0.4988
#
# Epoch 33/200
# Generator Loss: 4.6478, Discriminator Loss: 0.5493
#
# Epoch 34/200
# Generator Loss: 1.5637, Discriminator Loss: 0.3384
#
# Epoch 35/200
# Generator Loss: 3.4545, Discriminator Loss: 0.2468
#
# Epoch 36/200
# Generator Loss: 1.5727, Discriminator Loss: 0.3096
#
# Epoch 37/200
# Generator Loss: 3.3206, Discriminator Loss: 0.0651
#
# Epoch 38/200
# Generator Loss: 6.0342, Discriminator Loss: 0.5078
#
# Epoch 39/200
# Generator Loss: 1.9449, Discriminator Loss: 0.2050
#
# Epoch 40/200
# Generator Loss: 2.2564, Discriminator Loss: 0.1663
#
# Epoch 41/200
# Generator Loss: 3.5306, Discriminator Loss: 0.1671
#
# Epoch 42/200
# Generator Loss: 2.6385, Discriminator Loss: 0.2932
#
# Epoch 43/200
# Generator Loss: 1.7479, Discriminator Loss: 0.2426
#
# Epoch 44/200
# Generator Loss: 3.2622, Discriminator Loss: 0.1106
#
# Epoch 45/200
# Generator Loss: 2.2735, Discriminator Loss: 0.2229
#
# Epoch 46/200
# Generator Loss: 1.4247, Discriminator Loss: 0.4721
#
# Epoch 47/200
# Generator Loss: 0.8873, Discriminator Loss: 0.6766
#
# Epoch 48/200
# Generator Loss: 4.8750, Discriminator Loss: 0.7556
#
# Epoch 49/200
# Generator Loss: 2.3729, Discriminator Loss: 0.1453
#
# Epoch 50/200
# Generator Loss: 2.3463, Discriminator Loss: 0.1864
#
# Epoch 51/200
# Generator Loss: 3.6544, Discriminator Loss: 0.7357
#
# Epoch 52/200
# Generator Loss: 2.4337, Discriminator Loss: 0.1212
#
# Epoch 53/200
# Generator Loss: 3.0589, Discriminator Loss: 0.2933
#
# Epoch 54/200
# Generator Loss: 3.3384, Discriminator Loss: 0.0812
#
# Epoch 55/200
# Generator Loss: 2.3393, Discriminator Loss: 0.2045
#
# Epoch 56/200
# Generator Loss: 1.4785, Discriminator Loss: 0.3550
#
# Epoch 57/200
# Generator Loss: 3.0322, Discriminator Loss: 0.3237
#
# Epoch 58/200
# Generator Loss: 1.2759, Discriminator Loss: 0.4196
#
# Epoch 59/200
# Generator Loss: 4.3228, Discriminator Loss: 0.3638
#
# Epoch 60/200
# Generator Loss: 3.5948, Discriminator Loss: 0.1530
#
# Epoch 61/200
# Generator Loss: 1.7377, Discriminator Loss: 0.2735
#
# Epoch 62/200
# Generator Loss: 6.3308, Discriminator Loss: 1.9340
#
# Epoch 63/200
# Generator Loss: 5.0101, Discriminator Loss: 0.1985
#
# Epoch 64/200
# Generator Loss: 1.4444, Discriminator Loss: 0.4631
#
# Epoch 65/200
# Generator Loss: 4.5539, Discriminator Loss: 0.3082
#
# Epoch 66/200
# Generator Loss: 2.9703, Discriminator Loss: 0.2199
#
# Epoch 67/200
# Generator Loss: 2.5277, Discriminator Loss: 0.4107
#
# Epoch 68/200
# Generator Loss: 0.9688, Discriminator Loss: 0.9247
#
# Epoch 69/200
# Generator Loss: 3.4702, Discriminator Loss: 0.1172
#
# Epoch 70/200
# Generator Loss: 2.7019, Discriminator Loss: 0.2221
#
# Epoch 71/200
# Generator Loss: 3.3348, Discriminator Loss: 0.1705
#
# Epoch 72/200
# Generator Loss: 2.9880, Discriminator Loss: 0.1263
#
# Epoch 73/200
# Generator Loss: 1.5821, Discriminator Loss: 0.3552
#
# Epoch 74/200
# Generator Loss: 2.2184, Discriminator Loss: 0.3449
#
# Epoch 75/200
# Generator Loss: 1.4714, Discriminator Loss: 0.3469
#
# Epoch 76/200
# Generator Loss: 1.1913, Discriminator Loss: 0.4563
#
# Epoch 77/200
# Generator Loss: 1.3828, Discriminator Loss: 0.3589
#
# Epoch 78/200
# Generator Loss: 4.5792, Discriminator Loss: 0.8458
#
# Epoch 79/200
# Generator Loss: 3.2446, Discriminator Loss: 0.1841
#
# Epoch 80/200
# Generator Loss: 1.4232, Discriminator Loss: 0.3953
#
# Epoch 81/200
# Generator Loss: 2.0544, Discriminator Loss: 0.2862
#
# Epoch 82/200
# Generator Loss: 3.7711, Discriminator Loss: 0.2224
#
# Epoch 83/200
# Generator Loss: 1.4919, Discriminator Loss: 0.3067
#
# Epoch 84/200
# Generator Loss: 1.8799, Discriminator Loss: 0.2990
#
# Epoch 85/200
# Generator Loss: 1.4490, Discriminator Loss: 0.3448
#
# Epoch 86/200
# Generator Loss: 3.7128, Discriminator Loss: 0.2684
#
# Epoch 87/200
# Generator Loss: 2.6350, Discriminator Loss: 0.1906
#
# Epoch 88/200
# Generator Loss: 3.9159, Discriminator Loss: 0.7511
#
# Epoch 89/200
# Generator Loss: 1.5706, Discriminator Loss: 0.3905
#
# Epoch 90/200
# Generator Loss: 0.9479, Discriminator Loss: 0.7692
#
# Epoch 91/200
# Generator Loss: 1.1754, Discriminator Loss: 0.6584
#
# Epoch 92/200
# Generator Loss: 1.9409, Discriminator Loss: 0.2049
#
# Epoch 93/200
# Generator Loss: 4.1047, Discriminator Loss: 0.5317
#
# Epoch 94/200
# Generator Loss: 2.4905, Discriminator Loss: 0.2134
#
# Epoch 95/200
# Generator Loss: 2.3615, Discriminator Loss: 0.1440
#
# Epoch 96/200
# Generator Loss: 0.8548, Discriminator Loss: 0.8450
#
# Epoch 97/200
# Generator Loss: 2.8315, Discriminator Loss: 0.1194
#
# Epoch 98/200
# Generator Loss: 2.9140, Discriminator Loss: 0.2078
#
# Epoch 99/200
# Generator Loss: 4.3044, Discriminator Loss: 0.5076
#
# Epoch 100/200
# Generator Loss: 5.5168, Discriminator Loss: 0.3901
#
# Epoch 101/200
# Generator Loss: 3.3346, Discriminator Loss: 0.0673
#
# Epoch 102/200
# Generator Loss: 4.6744, Discriminator Loss: 0.4961
#
# Epoch 103/200
# Generator Loss: 1.6123, Discriminator Loss: 0.5178
#
# Epoch 104/200
# Generator Loss: 5.4110, Discriminator Loss: 1.4521
#
# Epoch 105/200
# Generator Loss: 2.2254, Discriminator Loss: 0.1876
#
# Epoch 106/200
# Generator Loss: 4.3493, Discriminator Loss: 0.0590
#
# Epoch 107/200
# Generator Loss: 2.1384, Discriminator Loss: 0.2024
#
# Epoch 108/200
# Generator Loss: 4.3048, Discriminator Loss: 0.1379
#
# Epoch 109/200
# Generator Loss: 4.5822, Discriminator Loss: 0.1576
#
# Epoch 110/200
# Generator Loss: 4.5259, Discriminator Loss: 0.1812
#
# Epoch 111/200
# Generator Loss: 2.6241, Discriminator Loss: 0.1304
#
# Epoch 112/200
# Generator Loss: 4.9786, Discriminator Loss: 0.0370
#
# Epoch 113/200
# Generator Loss: 4.5266, Discriminator Loss: 0.0896
#
# Epoch 114/200
# Generator Loss: 3.6221, Discriminator Loss: 0.2142
#
# Epoch 115/200
# Generator Loss: 2.7234, Discriminator Loss: 0.1786
#
# Epoch 116/200
# Generator Loss: 3.1557, Discriminator Loss: 0.1862
#
# Epoch 117/200
# Generator Loss: 8.8136, Discriminator Loss: 3.2483
#
# Epoch 118/200
# Generator Loss: 7.5170, Discriminator Loss: 1.0883
#
# Epoch 119/200
# Generator Loss: 3.0576, Discriminator Loss: 0.2278
#
# Epoch 120/200
# Generator Loss: 2.5565, Discriminator Loss: 0.1568
#
# Epoch 121/200
# Generator Loss: 4.9939, Discriminator Loss: 0.4661
#
# Epoch 122/200
# Generator Loss: 3.9776, Discriminator Loss: 0.1378
#
# Epoch 123/200
# Generator Loss: 5.3198, Discriminator Loss: 1.2438
#
# Epoch 124/200
# Generator Loss: 3.2875, Discriminator Loss: 0.1433
#
# Epoch 125/200
# Generator Loss: 5.1372, Discriminator Loss: 0.0476
#
# Epoch 126/200
# Generator Loss: 3.4425, Discriminator Loss: 0.1800
#
# Epoch 127/200
# Generator Loss: 4.5465, Discriminator Loss: 0.2616
#
# Epoch 128/200
# Generator Loss: 3.3933, Discriminator Loss: 0.1219
#
# Epoch 129/200
# Generator Loss: 3.1880, Discriminator Loss: 0.2529
#
# Epoch 130/200
# Generator Loss: 0.2805, Discriminator Loss: 1.6903
#
# Epoch 131/200
# Generator Loss: 1.4056, Discriminator Loss: 0.4639
#
# Epoch 132/200
# Generator Loss: 4.0724, Discriminator Loss: 0.0770
#
# Epoch 133/200
# Generator Loss: 3.0144, Discriminator Loss: 0.2503
#
# Epoch 134/200
# Generator Loss: 1.9924, Discriminator Loss: 0.2164
#
# Epoch 135/200
# Generator Loss: 3.1683, Discriminator Loss: 0.1012
#
# Epoch 136/200
# Generator Loss: 4.9276, Discriminator Loss: 0.0770
#
# Epoch 137/200
# Generator Loss: 1.3361, Discriminator Loss: 0.3741
#
# Epoch 138/200
# Generator Loss: 1.6152, Discriminator Loss: 0.2887
#
# Epoch 139/200
# Generator Loss: 2.2975, Discriminator Loss: 0.2962
#
# Epoch 140/200
# Generator Loss: 3.6574, Discriminator Loss: 0.1225
#
# Epoch 141/200
# Generator Loss: 5.0825, Discriminator Loss: 0.1827
#
# Epoch 142/200
# Generator Loss: 0.6609, Discriminator Loss: 0.9236
#
# Epoch 143/200
# Generator Loss: 2.4602, Discriminator Loss: 0.2470
#
# Epoch 144/200
# Generator Loss: 2.5247, Discriminator Loss: 0.1217
#
# Epoch 145/200
# Generator Loss: 1.8318, Discriminator Loss: 0.2704
#
# Epoch 146/200
# Generator Loss: 5.4253, Discriminator Loss: 0.0322
#
# Epoch 147/200
# Generator Loss: 2.0193, Discriminator Loss: 0.4003
#
# Epoch 148/200
# Generator Loss: 2.8720, Discriminator Loss: 0.1698
#
# Epoch 149/200
# Generator Loss: 5.9946, Discriminator Loss: 0.2739
#
# Epoch 150/200
# Generator Loss: 3.2727, Discriminator Loss: 0.1513
#
# Epoch 151/200
# Generator Loss: 4.8438, Discriminator Loss: 0.6069
#
# Epoch 152/200
# Generator Loss: 2.6885, Discriminator Loss: 0.1475
#
# Epoch 153/200
# Generator Loss: 3.5888, Discriminator Loss: 0.4069
#
# Epoch 154/200
# Generator Loss: 1.9576, Discriminator Loss: 0.2761
#
# Epoch 155/200
# Generator Loss: 1.3214, Discriminator Loss: 0.4565
#
# Epoch 156/200
# Generator Loss: 4.0157, Discriminator Loss: 0.3476
#
# Epoch 157/200
# Generator Loss: 5.0510, Discriminator Loss: 0.7702
#
# Epoch 158/200
# Generator Loss: 3.0729, Discriminator Loss: 0.1365
#
# Epoch 159/200
# Generator Loss: 3.6321, Discriminator Loss: 0.1602
#
# Epoch 160/200
# Generator Loss: 2.9096, Discriminator Loss: 0.1024
#
# Epoch 161/200
# Generator Loss: 4.7985, Discriminator Loss: 0.6570
#
# Epoch 162/200
# Generator Loss: 6.0232, Discriminator Loss: 0.4713
#
# Epoch 163/200
# Generator Loss: 2.7174, Discriminator Loss: 0.1687
#
# Epoch 164/200
# Generator Loss: 2.5791, Discriminator Loss: 0.1316
#
# Epoch 165/200
# Generator Loss: 4.0681, Discriminator Loss: 0.4276
#
# Epoch 166/200
# Generator Loss: 3.6210, Discriminator Loss: 0.0466
#
# Epoch 167/200
# Generator Loss: 1.8872, Discriminator Loss: 0.2444
#
# Epoch 168/200
# Generator Loss: 5.0388, Discriminator Loss: 0.0504
#
# Epoch 169/200
# Generator Loss: 2.4403, Discriminator Loss: 0.1648
#
# Epoch 170/200
# Generator Loss: 0.8006, Discriminator Loss: 0.8972
#
# Epoch 171/200
# Generator Loss: 1.6798, Discriminator Loss: 0.3999
#
# Epoch 172/200
# Generator Loss: 3.2229, Discriminator Loss: 0.0932
#
# Epoch 173/200
# Generator Loss: 1.8090, Discriminator Loss: 0.2683
#
# Epoch 174/200
# Generator Loss: 2.3970, Discriminator Loss: 0.3496
#
# Epoch 175/200
# Generator Loss: 1.7665, Discriminator Loss: 0.3284
#
# Epoch 176/200
# Generator Loss: 1.1385, Discriminator Loss: 0.6243
#
# Epoch 177/200
# Generator Loss: 2.7025, Discriminator Loss: 0.1031
#
# Epoch 178/200
# Generator Loss: 2.0534, Discriminator Loss: 0.1959
#
# Epoch 179/200
# Generator Loss: 4.8135, Discriminator Loss: 0.4936
#
# Epoch 180/200
# Generator Loss: 1.4035, Discriminator Loss: 0.4470
#
# Epoch 181/200
# Generator Loss: 2.4981, Discriminator Loss: 0.1667
#
# Epoch 182/200
# Generator Loss: 3.4332, Discriminator Loss: 0.2075
#
# Epoch 183/200
# Generator Loss: 3.0487, Discriminator Loss: 0.1036
#
# Epoch 184/200
# Generator Loss: 4.0375, Discriminator Loss: 0.1294
#
# Epoch 185/200
# Generator Loss: 3.1285, Discriminator Loss: 0.1312
#
# Epoch 186/200
# Generator Loss: 3.8222, Discriminator Loss: 0.2682
#
# Epoch 187/200
# Generator Loss: 4.0426, Discriminator Loss: 0.0444
#
# Epoch 188/200
# Generator Loss: 2.4476, Discriminator Loss: 0.1576
#
# Epoch 189/200
# Generator Loss: 2.4928, Discriminator Loss: 0.1487
#
# Epoch 190/200
# Generator Loss: 4.3822, Discriminator Loss: 0.1816
#
# Epoch 191/200
# Generator Loss: 3.3877, Discriminator Loss: 0.0667
#
# Epoch 192/200
# Generator Loss: 1.6841, Discriminator Loss: 0.3107
#
# Epoch 193/200
# Generator Loss: 2.5105, Discriminator Loss: 0.1735
#
# Epoch 194/200
# Generator Loss: 1.4163, Discriminator Loss: 0.3793
#
# Epoch 195/200
# Generator Loss: 2.5835, Discriminator Loss: 0.1356
#
# Epoch 196/200
# Generator Loss: 4.6716, Discriminator Loss: 0.1322
#
# Epoch 197/200
# Generator Loss: 3.5786, Discriminator Loss: 0.0897
#
# Epoch 198/200
# Generator Loss: 3.4834, Discriminator Loss: 0.0677
#
# Epoch 199/200
# Generator Loss: 3.0956, Discriminator Loss: 0.1451
#
# Epoch 200/200
# Generator Loss: 3.6141, Discriminator Loss: 0.4546

# %% [markdown]
# **TRainubf on 600**

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

BATCH_SIZE = 64
EPOCHS = 600
noise_dim = 100
BUFFER_SIZE = image_data.shape[0]

# Prepare dataset
dataset = tf.data.Dataset.from_tensor_slices((image_data, padded_captions))
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

# Optimizers
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# Loss function (Binary Crossentropy)
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    return real_loss + fake_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# Training step (per batch)
@tf.function
def train_step(images, captions):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator([noise, captions], training=True)

        real_output = discriminator([images, captions], training=True)
        fake_output = discriminator([generated_images, captions], training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return gen_loss, disc_loss

# Generate and save images for specific captions
def generate_and_save_images(model, captions, epoch):
    noise = tf.random.normal([len(captions), noise_dim])
    generated_images = model([noise, captions], training=False)

    plt.figure(figsize=(12, 4))
    for i in range(len(captions)):
        plt.subplot(1, len(captions), i+1)
        plt.imshow((generated_images[i].numpy() + 1) / 2.0)  # Rescale images
        plt.axis('off')
    plt.suptitle(f'Epoch {epoch}')
    plt.show()

# Define 2 specific captions to monitor during training
specific_captions = [
    "ethnic Boys Printed Maroon Kurta",
    "sports Men Gel Running White Sports Shoes",
    "casual Men Aventura Sandal",
    "casual Boys Expressions Yellow T-shirt"
]

# Convert captions to padded format (ensure they match your tokenization & padding)
specific_captions_padded = tokenizer.texts_to_sequences(specific_captions)
specific_captions_padded = tf.keras.preprocessing.sequence.pad_sequences(specific_captions_padded, maxlen=max_caption_len, padding='post')

# Start training
for epoch in range(1, EPOCHS + 1):
    print(f"\nEpoch {epoch}/{EPOCHS}")
    for batch_images, batch_captions in dataset:
        g_loss, d_loss = train_step(batch_images, batch_captions)

    print(f"Generator Loss: {g_loss.numpy():.4f}, Discriminator Loss: {d_loss.numpy():.4f}")

    # Generate and save images for the specific captions only at the final epoch
    if epoch == EPOCHS:
        sample_captions = tf.convert_to_tensor(specific_captions_padded)
        generate_and_save_images(generator, sample_captions, epoch)
# Out:
# Epoch 1/600
# Generator Loss: 2.3808, Discriminator Loss: 0.1481
#
# Epoch 2/600
# Generator Loss: 0.6316, Discriminator Loss: 1.2029
#
# Epoch 3/600
# Generator Loss: 3.0642, Discriminator Loss: 0.1780
#
# Epoch 4/600
# Generator Loss: 1.3300, Discriminator Loss: 0.4325
#
# Epoch 5/600
# Generator Loss: 3.9228, Discriminator Loss: 1.2807
#
# Epoch 6/600
# Generator Loss: 2.4447, Discriminator Loss: 0.2204
#
# Epoch 7/600
# Generator Loss: 5.0424, Discriminator Loss: 0.6277
#
# Epoch 8/600
# Generator Loss: 2.4467, Discriminator Loss: 0.4884
#
# Epoch 9/600
# Generator Loss: 0.5616, Discriminator Loss: 1.3174
#
# Epoch 10/600
# Generator Loss: 1.5579, Discriminator Loss: 0.3360
#
# Epoch 11/600
# Generator Loss: 4.0798, Discriminator Loss: 0.0509
#
# Epoch 12/600
# Generator Loss: 4.7634, Discriminator Loss: 0.9401
#
# Epoch 13/600
# Generator Loss: 4.1517, Discriminator Loss: 0.5606
#
# Epoch 14/600
# Generator Loss: 1.7067, Discriminator Loss: 0.3765
#
# Epoch 15/600
# Generator Loss: 2.4072, Discriminator Loss: 0.2156
#
# Epoch 16/600
# Generator Loss: 3.5504, Discriminator Loss: 0.1031
#
# Epoch 17/600
# Generator Loss: 3.6689, Discriminator Loss: 0.0900
#
# Epoch 18/600
# Generator Loss: 6.6772, Discriminator Loss: 0.6335
#
# Epoch 19/600
# Generator Loss: 1.9252, Discriminator Loss: 0.3416
#
# Epoch 20/600
# Generator Loss: 3.5328, Discriminator Loss: 0.2221
#
# Epoch 21/600
# Generator Loss: 4.1704, Discriminator Loss: 0.0656
#
# Epoch 22/600
# Generator Loss: 1.9517, Discriminator Loss: 0.3192
#
# Epoch 23/600
# Generator Loss: 4.3276, Discriminator Loss: 0.6470
#
# Epoch 24/600
# Generator Loss: 3.3520, Discriminator Loss: 0.2510
#
# Epoch 25/600
# Generator Loss: 5.7379, Discriminator Loss: 0.3450
#
# Epoch 26/600
# Generator Loss: 0.9116, Discriminator Loss: 0.7964
#
# Epoch 27/600
# Generator Loss: 3.1143, Discriminator Loss: 0.4957
#
# Epoch 28/600
# Generator Loss: 2.4786, Discriminator Loss: 0.2755
#
# Epoch 29/600
# Generator Loss: 4.3851, Discriminator Loss: 0.1047
#
# Epoch 30/600
# Generator Loss: 1.7099, Discriminator Loss: 0.3366
#
# Epoch 31/600
# Generator Loss: 2.0309, Discriminator Loss: 0.2094
#
# Epoch 32/600
# Generator Loss: 1.4319, Discriminator Loss: 0.4194
#
# Epoch 33/600
# Generator Loss: 2.2154, Discriminator Loss: 0.2073
#
# Epoch 34/600
# Generator Loss: 4.2178, Discriminator Loss: 0.2057
#
# Epoch 35/600
# Generator Loss: 2.8109, Discriminator Loss: 0.1426
#
# Epoch 36/600
# Generator Loss: 4.1892, Discriminator Loss: 0.0673
#
# Epoch 37/600
# Generator Loss: 1.9772, Discriminator Loss: 0.2172
#
# Epoch 38/600
# Generator Loss: 4.2684, Discriminator Loss: 0.5234
#
# Epoch 39/600
# Generator Loss: 3.3878, Discriminator Loss: 0.3339
#
# Epoch 40/600
# Generator Loss: 1.6659, Discriminator Loss: 0.3666
#
# Epoch 41/600
# Generator Loss: 3.3580, Discriminator Loss: 0.1089
#
# Epoch 42/600
# Generator Loss: 3.2738, Discriminator Loss: 0.1489
#
# Epoch 43/600
# Generator Loss: 4.0450, Discriminator Loss: 0.7924
#
# Epoch 44/600
# Generator Loss: 4.6142, Discriminator Loss: 0.2329
#
# Epoch 45/600
# Generator Loss: 2.3777, Discriminator Loss: 0.1522
#
# Epoch 46/600
# Generator Loss: 2.6745, Discriminator Loss: 0.2234
#
# Epoch 47/600
# Generator Loss: 0.5050, Discriminator Loss: 1.3128
#
# Epoch 48/600
# Generator Loss: 4.5605, Discriminator Loss: 0.0881
#
# Epoch 49/600
# Generator Loss: 3.6774, Discriminator Loss: 0.2891
#
# Epoch 50/600
# Generator Loss: 2.8679, Discriminator Loss: 0.1356
#
# Epoch 51/600
# Generator Loss: 3.5359, Discriminator Loss: 0.2623
#
# Epoch 52/600
# Generator Loss: 2.2892, Discriminator Loss: 0.3879
#
# Epoch 53/600
# Generator Loss: 0.9726, Discriminator Loss: 0.8806
#
# Epoch 54/600
# Generator Loss: 2.2958, Discriminator Loss: 0.3983
#
# Epoch 55/600
# Generator Loss: 3.9812, Discriminator Loss: 0.1881
#
# Epoch 56/600
# Generator Loss: 3.3724, Discriminator Loss: 0.1935
#
# Epoch 57/600
# Generator Loss: 1.4668, Discriminator Loss: 0.3711
#
# Epoch 58/600
# Generator Loss: 1.9962, Discriminator Loss: 0.2803
#
# Epoch 59/600
# Generator Loss: 3.9801, Discriminator Loss: 0.0865
#
# Epoch 60/600
# Generator Loss: 1.8614, Discriminator Loss: 0.2692
#
# Epoch 61/600
# Generator Loss: 3.7995, Discriminator Loss: 0.2588
#
# Epoch 62/600
# Generator Loss: 2.8170, Discriminator Loss: 0.1835
#
# Epoch 63/600
# Generator Loss: 0.6646, Discriminator Loss: 0.9956
#
# Epoch 64/600
# Generator Loss: 2.7671, Discriminator Loss: 0.2093
#
# Epoch 65/600
# Generator Loss: 3.4362, Discriminator Loss: 0.2383
#
# Epoch 66/600
# Generator Loss: 4.8777, Discriminator Loss: 0.3292
#
# Epoch 67/600
# Generator Loss: 0.7622, Discriminator Loss: 0.8776
#
# Epoch 68/600
# Generator Loss: 4.2110, Discriminator Loss: 0.1148
#
# Epoch 69/600
# Generator Loss: 3.3499, Discriminator Loss: 0.0900
#
# Epoch 70/600
# Generator Loss: 0.9252, Discriminator Loss: 0.7172
#
# Epoch 71/600
# Generator Loss: 6.6597, Discriminator Loss: 0.5751
#
# Epoch 72/600
# Generator Loss: 3.2143, Discriminator Loss: 0.0888
#
# Epoch 73/600
# Generator Loss: 3.1390, Discriminator Loss: 0.5701
#
# Epoch 74/600
# Generator Loss: 2.5480, Discriminator Loss: 1.1177
#
# Epoch 75/600
# Generator Loss: 2.0405, Discriminator Loss: 0.2410
#
# Epoch 76/600
# Generator Loss: 2.9161, Discriminator Loss: 0.3127
#
# Epoch 77/600
# Generator Loss: 3.2190, Discriminator Loss: 0.0753
#
# Epoch 78/600
# Generator Loss: 5.0736, Discriminator Loss: 0.6668
#
# Epoch 79/600
# Generator Loss: 2.2433, Discriminator Loss: 0.2198
#
# Epoch 80/600
# Generator Loss: 1.9036, Discriminator Loss: 0.2502
#
# Epoch 81/600
# Generator Loss: 2.0677, Discriminator Loss: 0.2108
#
# Epoch 82/600
# Generator Loss: 1.0233, Discriminator Loss: 0.9503
#
# Epoch 83/600
# Generator Loss: 3.5603, Discriminator Loss: 0.2784
#
# Epoch 84/600
# Generator Loss: 6.0396, Discriminator Loss: 1.7944
#
# Epoch 85/600
# Generator Loss: 2.6863, Discriminator Loss: 0.7136
#
# Epoch 86/600
# Generator Loss: 3.0060, Discriminator Loss: 0.4653
#
# Epoch 87/600
# Generator Loss: 3.7772, Discriminator Loss: 0.2303
#
# Epoch 88/600
# Generator Loss: 2.2534, Discriminator Loss: 0.2768
#
# Epoch 89/600
# Generator Loss: 0.2212, Discriminator Loss: 2.0254
#
# Epoch 90/600
# Generator Loss: 2.7062, Discriminator Loss: 0.1001
#
# Epoch 91/600
# Generator Loss: 1.8298, Discriminator Loss: 0.2620
#
# Epoch 92/600
# Generator Loss: 2.9987, Discriminator Loss: 0.1983
#
# Epoch 93/600
# Generator Loss: 3.8007, Discriminator Loss: 0.0558
#
# Epoch 94/600
# Generator Loss: 1.2612, Discriminator Loss: 0.4435
#
# Epoch 95/600
# Generator Loss: 2.2186, Discriminator Loss: 0.1933
#
# Epoch 96/600
# Generator Loss: 3.5716, Discriminator Loss: 0.2103
#
# Epoch 97/600
# Generator Loss: 1.6654, Discriminator Loss: 0.3211
#
# Epoch 98/600
# Generator Loss: 0.9694, Discriminator Loss: 0.7095
#
# Epoch 99/600
# Generator Loss: 5.3424, Discriminator Loss: 0.9118
#
# Epoch 100/600
# Generator Loss: 3.9210, Discriminator Loss: 1.9373
#
# Epoch 101/600
# Generator Loss: 2.2915, Discriminator Loss: 0.1717
#
# Epoch 102/600
# Generator Loss: 2.2919, Discriminator Loss: 0.1901
#
# Epoch 103/600
# Generator Loss: 4.6435, Discriminator Loss: 0.5662
#
# Epoch 104/600
# Generator Loss: 5.3850, Discriminator Loss: 0.3815
#
# Epoch 105/600
# Generator Loss: 2.1370, Discriminator Loss: 0.2391
#
# Epoch 106/600
# Generator Loss: 6.1929, Discriminator Loss: 0.3226
#
# Epoch 107/600
# Generator Loss: 2.1390, Discriminator Loss: 0.3372
#
# Epoch 108/600
# Generator Loss: 1.2469, Discriminator Loss: 0.4435
#
# Epoch 109/600
# Generator Loss: 1.9870, Discriminator Loss: 0.4280
#
# Epoch 110/600
# Generator Loss: 4.6625, Discriminator Loss: 0.2217
#
# Epoch 111/600
# Generator Loss: 3.0968, Discriminator Loss: 0.0918
#
# Epoch 112/600
# Generator Loss: 1.5814, Discriminator Loss: 0.3610
#
# Epoch 113/600
# Generator Loss: 2.0149, Discriminator Loss: 0.2065
#
# Epoch 114/600
# Generator Loss: 3.4242, Discriminator Loss: 0.2433
#
# Epoch 115/600
# Generator Loss: 4.6419, Discriminator Loss: 0.4048
#
# Epoch 116/600
# Generator Loss: 0.9814, Discriminator Loss: 0.6666
#
# Epoch 117/600
# Generator Loss: 1.5453, Discriminator Loss: 0.3431
#
# Epoch 118/600
# Generator Loss: 1.4090, Discriminator Loss: 0.4373
#
# Epoch 119/600
# Generator Loss: 3.4691, Discriminator Loss: 0.1634
#
# Epoch 120/600
# Generator Loss: 2.7587, Discriminator Loss: 0.5627
#
# Epoch 121/600
# Generator Loss: 2.5642, Discriminator Loss: 0.2555
#
# Epoch 122/600
# Generator Loss: 1.7853, Discriminator Loss: 0.4199
#
# Epoch 123/600
# Generator Loss: 6.3772, Discriminator Loss: 0.0469
#
# Epoch 124/600
# Generator Loss: 0.1835, Discriminator Loss: 2.1920
#
# Epoch 125/600
# Generator Loss: 1.4281, Discriminator Loss: 0.5146
#
# Epoch 126/600
# Generator Loss: 6.1564, Discriminator Loss: 0.2379
#
# Epoch 127/600
# Generator Loss: 0.6965, Discriminator Loss: 1.0347
#
# Epoch 128/600
# Generator Loss: 5.9448, Discriminator Loss: 0.3468
#
# Epoch 129/600
# Generator Loss: 1.0025, Discriminator Loss: 0.7670
#
# Epoch 130/600
# Generator Loss: 3.4551, Discriminator Loss: 0.1259
#
# Epoch 131/600
# Generator Loss: 3.5148, Discriminator Loss: 0.1400
#
# Epoch 132/600
# Generator Loss: 1.5265, Discriminator Loss: 0.4750
#
# Epoch 133/600
# Generator Loss: 3.9675, Discriminator Loss: 0.3161
#
# Epoch 134/600
# Generator Loss: 3.5420, Discriminator Loss: 0.0863
#
# Epoch 135/600
# Generator Loss: 2.3206, Discriminator Loss: 0.3918
#
# Epoch 136/600
# Generator Loss: 0.9883, Discriminator Loss: 0.6780
#
# Epoch 137/600
# Generator Loss: 3.4597, Discriminator Loss: 1.3096
#
# Epoch 138/600
# Generator Loss: 4.1779, Discriminator Loss: 0.0932
#
# Epoch 139/600
# Generator Loss: 3.8540, Discriminator Loss: 0.3064
#
# Epoch 140/600
# Generator Loss: 0.2823, Discriminator Loss: 1.7270
#
# Epoch 141/600
# Generator Loss: 3.2335, Discriminator Loss: 0.1802
#
# Epoch 142/600
# Generator Loss: 1.6487, Discriminator Loss: 0.3629
#
# Epoch 143/600
# Generator Loss: 3.5539, Discriminator Loss: 0.5533
#
# Epoch 144/600
# Generator Loss: 5.0782, Discriminator Loss: 0.9895
#
# Epoch 145/600
# Generator Loss: 1.1111, Discriminator Loss: 0.5493
#
# Epoch 146/600
# Generator Loss: 4.0345, Discriminator Loss: 0.3747
#
# Epoch 147/600
# Generator Loss: 3.1899, Discriminator Loss: 0.0866
#
# Epoch 148/600
# Generator Loss: 4.7375, Discriminator Loss: 0.3469
#
# Epoch 149/600
# Generator Loss: 1.9610, Discriminator Loss: 0.2399
#
# Epoch 150/600
# Generator Loss: 2.5118, Discriminator Loss: 0.2611
#
# Epoch 151/600
# Generator Loss: 1.1284, Discriminator Loss: 0.5906
#
# Epoch 152/600
# Generator Loss: 2.3559, Discriminator Loss: 0.1927
#
# Epoch 153/600
# Generator Loss: 0.9287, Discriminator Loss: 0.7387
#
# Epoch 154/600
# Generator Loss: 5.6750, Discriminator Loss: 0.8888
#
# Epoch 155/600
# Generator Loss: 2.3994, Discriminator Loss: 0.5069
#
# Epoch 156/600
# Generator Loss: 5.1571, Discriminator Loss: 2.2256
#
# Epoch 157/600
# Generator Loss: 2.8655, Discriminator Loss: 0.1325
#
# Epoch 158/600
# Generator Loss: 3.3186, Discriminator Loss: 0.1454
#
# Epoch 159/600
# Generator Loss: 1.7939, Discriminator Loss: 0.2458
#
# Epoch 160/600
# Generator Loss: 3.5641, Discriminator Loss: 0.0758
#
# Epoch 161/600
# Generator Loss: 2.6640, Discriminator Loss: 0.1703
#
# Epoch 162/600
# Generator Loss: 1.6089, Discriminator Loss: 0.3160
#
# Epoch 163/600
# Generator Loss: 3.2370, Discriminator Loss: 0.3338
#
# Epoch 164/600
# Generator Loss: 2.7468, Discriminator Loss: 0.1407
#
# Epoch 165/600
# Generator Loss: 3.2650, Discriminator Loss: 0.1768
#
# Epoch 166/600
# Generator Loss: 1.0464, Discriminator Loss: 0.5852
#
# Epoch 167/600
# Generator Loss: 3.9496, Discriminator Loss: 1.0181
#
# Epoch 168/600
# Generator Loss: 2.7936, Discriminator Loss: 0.1331
#
# Epoch 169/600
# Generator Loss: 4.6325, Discriminator Loss: 2.2975
#
# Epoch 170/600
# Generator Loss: 0.3940, Discriminator Loss: 1.3873
#
# Epoch 171/600
# Generator Loss: 1.8886, Discriminator Loss: 0.2642
#
# Epoch 172/600
# Generator Loss: 4.2500, Discriminator Loss: 0.1173
#
# Epoch 173/600
# Generator Loss: 2.5008, Discriminator Loss: 0.5061
#
# Epoch 174/600
# Generator Loss: 2.2625, Discriminator Loss: 0.1872
#
# Epoch 175/600
# Generator Loss: 2.7790, Discriminator Loss: 0.1911
#
# Epoch 176/600
# Generator Loss: 2.4248, Discriminator Loss: 0.1707
#
# Epoch 177/600
# Generator Loss: 3.0537, Discriminator Loss: 0.0648
#
# Epoch 178/600
# Generator Loss: 5.3693, Discriminator Loss: 0.2133
#
# Epoch 179/600
# Generator Loss: 2.9062, Discriminator Loss: 0.7086
#
# Epoch 180/600
# Generator Loss: 2.2906, Discriminator Loss: 0.2085
#
# Epoch 181/600
# Generator Loss: 1.2303, Discriminator Loss: 0.4986
#
# Epoch 182/600
# Generator Loss: 5.2525, Discriminator Loss: 0.0661
#
# Epoch 183/600
# Generator Loss: 4.8429, Discriminator Loss: 0.1052
#
# Epoch 184/600
# Generator Loss: 5.3156, Discriminator Loss: 1.9687
#
# Epoch 185/600
# Generator Loss: 3.4141, Discriminator Loss: 0.2117
#
# Epoch 186/600
# Generator Loss: 4.9918, Discriminator Loss: 0.5907
#
# Epoch 187/600
# Generator Loss: 3.7438, Discriminator Loss: 0.2725
#
# Epoch 188/600
# Generator Loss: 1.9849, Discriminator Loss: 0.2873
#
# Epoch 189/600
# Generator Loss: 4.8265, Discriminator Loss: 0.5471
#
# Epoch 190/600
# Generator Loss: 3.7925, Discriminator Loss: 0.0487
#
# Epoch 191/600
# Generator Loss: 0.3740, Discriminator Loss: 1.5196
#
# Epoch 192/600
# Generator Loss: 4.2840, Discriminator Loss: 0.4393
#
# Epoch 193/600
# Generator Loss: 3.1998, Discriminator Loss: 0.1563
#
# Epoch 194/600
# Generator Loss: 2.2435, Discriminator Loss: 0.1927
#
# Epoch 195/600
# Generator Loss: 3.1316, Discriminator Loss: 0.0801
#
# Epoch 196/600
# Generator Loss: 2.0230, Discriminator Loss: 0.5564
#
# Epoch 197/600
# Generator Loss: 2.8762, Discriminator Loss: 0.2599
#
# Epoch 198/600
# Generator Loss: 1.8858, Discriminator Loss: 0.4867
#
# Epoch 199/600
# Generator Loss: 3.4729, Discriminator Loss: 0.4775
#
# Epoch 200/600
# Generator Loss: 0.1315, Discriminator Loss: 2.4506
#
# Epoch 201/600
# Generator Loss: 2.5980, Discriminator Loss: 0.1602
#
# Epoch 202/600
# Generator Loss: 3.2363, Discriminator Loss: 0.7584
#
# Epoch 203/600
# Generator Loss: 3.8108, Discriminator Loss: 0.2648
#
# Epoch 204/600
# Generator Loss: 5.2268, Discriminator Loss: 0.7206
#
# Epoch 205/600
# Generator Loss: 0.7492, Discriminator Loss: 0.9070
#
# Epoch 206/600
# Generator Loss: 1.1606, Discriminator Loss: 0.5983
#
# Epoch 207/600
# Generator Loss: 2.0274, Discriminator Loss: 0.2144
#
# Epoch 208/600
# Generator Loss: 2.6289, Discriminator Loss: 0.1221
#
# Epoch 209/600
# Generator Loss: 3.5924, Discriminator Loss: 1.0136
#
# Epoch 210/600
# Generator Loss: 0.9660, Discriminator Loss: 0.7231
#
# Epoch 211/600
# Generator Loss: 0.8888, Discriminator Loss: 0.7817
#
# Epoch 212/600
# Generator Loss: 3.0274, Discriminator Loss: 0.1055
#
# Epoch 213/600
# Generator Loss: 2.1085, Discriminator Loss: 0.3437
#
# Epoch 214/600
# Generator Loss: 3.2805, Discriminator Loss: 0.1644
#
# Epoch 215/600
# Generator Loss: 4.9341, Discriminator Loss: 0.0892
#
# Epoch 216/600
# Generator Loss: 1.1524, Discriminator Loss: 0.5230
#
# Epoch 217/600
# Generator Loss: 0.4938, Discriminator Loss: 1.1857
#
# Epoch 218/600
# Generator Loss: 3.9084, Discriminator Loss: 0.5098
#
# Epoch 219/600
# Generator Loss: 3.4268, Discriminator Loss: 0.2672
#
# Epoch 220/600
# Generator Loss: 2.9699, Discriminator Loss: 0.2426
#
# Epoch 221/600
# Generator Loss: 0.1931, Discriminator Loss: 2.1383
#
# Epoch 222/600
# Generator Loss: 1.8463, Discriminator Loss: 0.2503
#
# Epoch 223/600
# Generator Loss: 0.5196, Discriminator Loss: 1.0933
#
# Epoch 224/600
# Generator Loss: 3.1480, Discriminator Loss: 0.1931
#
# Epoch 225/600
# Generator Loss: 2.1061, Discriminator Loss: 0.2562
#
# Epoch 226/600
# Generator Loss: 5.4444, Discriminator Loss: 0.5257
#
# Epoch 227/600
# Generator Loss: 3.7687, Discriminator Loss: 0.2732
#
# Epoch 228/600
# Generator Loss: 4.7889, Discriminator Loss: 1.2581
#
# Epoch 229/600
# Generator Loss: 2.1326, Discriminator Loss: 0.2415
#
# Epoch 230/600
# Generator Loss: 3.7077, Discriminator Loss: 0.3123
#
# Epoch 231/600
# Generator Loss: 1.9688, Discriminator Loss: 0.2921
#
# Epoch 232/600
# Generator Loss: 1.3160, Discriminator Loss: 0.5079
#
# Epoch 233/600
# Generator Loss: 4.4350, Discriminator Loss: 0.3037
#
# Epoch 234/600
# Generator Loss: 5.8293, Discriminator Loss: 1.1284
#
# Epoch 235/600
# Generator Loss: 3.2135, Discriminator Loss: 0.4539
#
# Epoch 236/600
# Generator Loss: 1.0476, Discriminator Loss: 0.6230
#
# Epoch 237/600
# Generator Loss: 1.7244, Discriminator Loss: 0.3071
#
# Epoch 238/600
# Generator Loss: 2.1895, Discriminator Loss: 0.1752
#
# Epoch 239/600
# Generator Loss: 3.0922, Discriminator Loss: 0.1202
#
# Epoch 240/600
# Generator Loss: 2.0947, Discriminator Loss: 0.4549
#
# Epoch 241/600
# Generator Loss: 3.1543, Discriminator Loss: 0.1682
#
# Epoch 242/600
# Generator Loss: 1.9401, Discriminator Loss: 0.2879
#
# Epoch 243/600
# Generator Loss: 1.3751, Discriminator Loss: 0.5159
#
# Epoch 244/600
# Generator Loss: 2.2277, Discriminator Loss: 0.3357
#
# Epoch 245/600
# Generator Loss: 0.9219, Discriminator Loss: 0.7388
#
# Epoch 246/600
# Generator Loss: 4.3018, Discriminator Loss: 1.0984
#
# Epoch 247/600
# Generator Loss: 5.2711, Discriminator Loss: 0.9740
#
# Epoch 248/600
# Generator Loss: 4.3185, Discriminator Loss: 0.5233
#
# Epoch 249/600
# Generator Loss: 2.8735, Discriminator Loss: 0.5491
#
# Epoch 250/600
# Generator Loss: 6.0609, Discriminator Loss: 1.3826
#
# Epoch 251/600
# Generator Loss: 1.0934, Discriminator Loss: 0.5947
#
# Epoch 252/600
# Generator Loss: 3.6090, Discriminator Loss: 0.1370
#
# Epoch 253/600
# Generator Loss: 3.8781, Discriminator Loss: 0.7025
#
# Epoch 254/600
# Generator Loss: 3.5182, Discriminator Loss: 0.1938
#
# Epoch 255/600
# Generator Loss: 4.0121, Discriminator Loss: 0.2603
#
# Epoch 256/600
# Generator Loss: 3.9398, Discriminator Loss: 0.2843
#
# Epoch 257/600
# Generator Loss: 1.7833, Discriminator Loss: 0.3748
#
# Epoch 258/600
# Generator Loss: 0.6343, Discriminator Loss: 1.0884
#
# Epoch 259/600
# Generator Loss: 3.7497, Discriminator Loss: 0.3883
#
# Epoch 260/600
# Generator Loss: 3.6852, Discriminator Loss: 0.3894
#
# Epoch 261/600
# Generator Loss: 3.9084, Discriminator Loss: 1.2171
#
# Epoch 262/600
# Generator Loss: 3.5246, Discriminator Loss: 0.0704
#
# Epoch 263/600
# Generator Loss: 1.6460, Discriminator Loss: 0.3210
#
# Epoch 264/600
# Generator Loss: 4.6772, Discriminator Loss: 1.1693
#
# Epoch 265/600
# Generator Loss: 2.2312, Discriminator Loss: 0.1730
#
# Epoch 266/600
# Generator Loss: 2.9436, Discriminator Loss: 0.3577
#
# Epoch 267/600
# Generator Loss: 2.8557, Discriminator Loss: 0.1863
#
# Epoch 268/600
# Generator Loss: 1.6413, Discriminator Loss: 0.3815
#
# Epoch 269/600
# Generator Loss: 6.6995, Discriminator Loss: 0.3658
#
# Epoch 270/600
# Generator Loss: 5.4803, Discriminator Loss: 0.7228
#
# Epoch 271/600
# Generator Loss: 2.4921, Discriminator Loss: 0.1256
#
# Epoch 272/600
# Generator Loss: 1.8858, Discriminator Loss: 0.2601
#
# Epoch 273/600
# Generator Loss: 5.3477, Discriminator Loss: 0.2660
#
# Epoch 274/600
# Generator Loss: 1.8054, Discriminator Loss: 0.9282
#
# Epoch 275/600
# Generator Loss: 1.5788, Discriminator Loss: 0.3990
#
# Epoch 276/600
# Generator Loss: 3.5467, Discriminator Loss: 0.2689
#
# Epoch 277/600
# Generator Loss: 3.9779, Discriminator Loss: 0.0540
#
# Epoch 278/600
# Generator Loss: 3.4485, Discriminator Loss: 0.0830
#
# Epoch 279/600
# Generator Loss: 2.2633, Discriminator Loss: 0.3247
#
# Epoch 280/600
# Generator Loss: 0.7770, Discriminator Loss: 0.8389
#
# Epoch 281/600
# Generator Loss: 5.6942, Discriminator Loss: 1.4770
#
# Epoch 282/600
# Generator Loss: 1.7879, Discriminator Loss: 0.4838
#
# Epoch 283/600
# Generator Loss: 4.6949, Discriminator Loss: 0.8444
#
# Epoch 284/600
# Generator Loss: 3.6057, Discriminator Loss: 0.2662
#
# Epoch 285/600
# Generator Loss: 3.5597, Discriminator Loss: 0.0916
#
# Epoch 286/600
# Generator Loss: 2.2059, Discriminator Loss: 0.2040
#
# Epoch 287/600
# Generator Loss: 3.0803, Discriminator Loss: 0.3072
#
# Epoch 288/600
# Generator Loss: 0.7749, Discriminator Loss: 0.8699
#
# Epoch 289/600
# Generator Loss: 5.2706, Discriminator Loss: 0.0652
#
# Epoch 290/600
# Generator Loss: 0.8166, Discriminator Loss: 0.7818
#
# Epoch 291/600
# Generator Loss: 2.2924, Discriminator Loss: 0.2711
#
# Epoch 292/600
# Generator Loss: 3.6820, Discriminator Loss: 0.3933
#
# Epoch 293/600
# Generator Loss: 3.1461, Discriminator Loss: 0.2065
#
# Epoch 294/600
# Generator Loss: 1.4546, Discriminator Loss: 0.4063
#
# Epoch 295/600
# Generator Loss: 5.3276, Discriminator Loss: 1.2181
#
# Epoch 296/600
# Generator Loss: 3.6476, Discriminator Loss: 0.1082
#
# Epoch 297/600
# Generator Loss: 3.3169, Discriminator Loss: 0.5750
#
# Epoch 298/600
# Generator Loss: 2.3997, Discriminator Loss: 0.1505
#
# Epoch 299/600
# Generator Loss: 2.2202, Discriminator Loss: 0.4594
#
# Epoch 300/600
# Generator Loss: 2.2035, Discriminator Loss: 0.2467
#
# Epoch 301/600
# Generator Loss: 3.9336, Discriminator Loss: 0.1975
#
# Epoch 302/600
# Generator Loss: 1.6186, Discriminator Loss: 0.5418
#
# Epoch 303/600
# Generator Loss: 3.9367, Discriminator Loss: 0.3235
#
# Epoch 304/600
# Generator Loss: 5.1411, Discriminator Loss: 0.2254
#
# Epoch 305/600
# Generator Loss: 1.9292, Discriminator Loss: 0.2134
#
# Epoch 306/600
# Generator Loss: 3.9094, Discriminator Loss: 0.5317
#
# Epoch 307/600
# Generator Loss: 3.0230, Discriminator Loss: 0.1892
#
# Epoch 308/600
# Generator Loss: 2.1257, Discriminator Loss: 0.3407
#
# Epoch 309/600
# Generator Loss: 3.5832, Discriminator Loss: 0.2329
#
# Epoch 310/600
# Generator Loss: 2.2928, Discriminator Loss: 0.1568
#
# Epoch 311/600
# Generator Loss: 4.1053, Discriminator Loss: 0.0245
#
# Epoch 312/600
# Generator Loss: 2.7192, Discriminator Loss: 0.1429
#
# Epoch 313/600
# Generator Loss: 4.4598, Discriminator Loss: 0.1171
#
# Epoch 314/600
# Generator Loss: 3.6878, Discriminator Loss: 0.0486
#
# Epoch 315/600
# Generator Loss: 2.3922, Discriminator Loss: 0.2905
#
# Epoch 316/600
# Generator Loss: 3.3736, Discriminator Loss: 0.0849
#
# Epoch 317/600
# Generator Loss: 0.9725, Discriminator Loss: 0.6530
#
# Epoch 318/600
# Generator Loss: 3.1933, Discriminator Loss: 0.0966
#
# Epoch 319/600
# Generator Loss: 3.9108, Discriminator Loss: 0.2367
#
# Epoch 320/600
# Generator Loss: 2.6015, Discriminator Loss: 0.2718
#
# Epoch 321/600
# Generator Loss: 4.0148, Discriminator Loss: 0.4764
#
# Epoch 322/600
# Generator Loss: 0.8095, Discriminator Loss: 0.8836
#
# Epoch 323/600
# Generator Loss: 2.2517, Discriminator Loss: 0.2500
#
# Epoch 324/600
# Generator Loss: 3.6374, Discriminator Loss: 0.0598
#
# Epoch 325/600
# Generator Loss: 5.5656, Discriminator Loss: 0.8128
#
# Epoch 326/600
# Generator Loss: 3.7082, Discriminator Loss: 0.2389
#
# Epoch 327/600
# Generator Loss: 3.5970, Discriminator Loss: 0.2265
#
# Epoch 328/600
# Generator Loss: 4.8161, Discriminator Loss: 0.0864
#
# Epoch 329/600
# Generator Loss: 2.1868, Discriminator Loss: 0.2458
#
# Epoch 330/600
# Generator Loss: 2.8146, Discriminator Loss: 0.2503
#
# Epoch 331/600
# Generator Loss: 4.2710, Discriminator Loss: 1.7122
#
# Epoch 332/600
# Generator Loss: 3.2925, Discriminator Loss: 0.1578
#
# Epoch 333/600
# Generator Loss: 1.6424, Discriminator Loss: 0.3006
#
# Epoch 334/600
# Generator Loss: 1.5813, Discriminator Loss: 0.4294
#
# Epoch 335/600
# Generator Loss: 1.7681, Discriminator Loss: 0.2929
#
# Epoch 336/600
# Generator Loss: 2.5279, Discriminator Loss: 0.2324
#
# Epoch 337/600
# Generator Loss: 2.4910, Discriminator Loss: 0.1762
#
# Epoch 338/600
# Generator Loss: 4.2504, Discriminator Loss: 0.1423
#
# Epoch 339/600
# Generator Loss: 1.7022, Discriminator Loss: 0.3753
#
# Epoch 340/600
# Generator Loss: 3.9485, Discriminator Loss: 0.7594
#
# Epoch 341/600
# Generator Loss: 4.7325, Discriminator Loss: 1.1170
#
# Epoch 342/600
# Generator Loss: 2.6793, Discriminator Loss: 0.1451
#
# Epoch 343/600
# Generator Loss: 3.2408, Discriminator Loss: 0.2410
#
# Epoch 344/600
# Generator Loss: 1.4697, Discriminator Loss: 0.4158
#
# Epoch 345/600
# Generator Loss: 0.5212, Discriminator Loss: 1.1419
#
# Epoch 346/600
# Generator Loss: 2.8360, Discriminator Loss: 0.1940
#
# Epoch 347/600
# Generator Loss: 3.6432, Discriminator Loss: 0.1203
#
# Epoch 348/600
# Generator Loss: 4.9209, Discriminator Loss: 0.3415
#
# Epoch 349/600
# Generator Loss: 3.1773, Discriminator Loss: 0.8822
#
# Epoch 350/600
# Generator Loss: 4.8154, Discriminator Loss: 1.2061
#
# Epoch 351/600
# Generator Loss: 2.6665, Discriminator Loss: 0.1747
#
# Epoch 352/600
# Generator Loss: 0.4654, Discriminator Loss: 1.1788
#
# Epoch 353/600
# Generator Loss: 1.3505, Discriminator Loss: 0.4900
#
# Epoch 354/600
# Generator Loss: 0.7746, Discriminator Loss: 0.8550
#
# Epoch 355/600
# Generator Loss: 2.3198, Discriminator Loss: 0.3636
#
# Epoch 356/600
# Generator Loss: 2.5936, Discriminator Loss: 0.6284
#
# Epoch 357/600
# Generator Loss: 1.3133, Discriminator Loss: 0.5048
#
# Epoch 358/600
# Generator Loss: 4.6237, Discriminator Loss: 0.5238
#
# Epoch 359/600
# Generator Loss: 3.7589, Discriminator Loss: 0.4597
#
# Epoch 360/600
# Generator Loss: 1.8681, Discriminator Loss: 0.3204
#
# Epoch 361/600
# Generator Loss: 3.3521, Discriminator Loss: 0.0840
#
# Epoch 362/600
# Generator Loss: 4.1307, Discriminator Loss: 0.4091
#
# Epoch 363/600
# Generator Loss: 1.8640, Discriminator Loss: 0.3027
#
# Epoch 364/600
# Generator Loss: 1.0304, Discriminator Loss: 0.6339
#
# Epoch 365/600
# Generator Loss: 1.1679, Discriminator Loss: 0.5663
#
# Epoch 366/600
# Generator Loss: 5.2152, Discriminator Loss: 0.2453
#
# Epoch 367/600
# Generator Loss: 1.0000, Discriminator Loss: 0.6911
#
# Epoch 368/600
# Generator Loss: 4.2887, Discriminator Loss: 0.0871
#
# Epoch 369/600
# Generator Loss: 3.3742, Discriminator Loss: 0.2082
#
# Epoch 370/600
# Generator Loss: 3.1694, Discriminator Loss: 0.3727
#
# Epoch 371/600
# Generator Loss: 3.1449, Discriminator Loss: 0.1080
#
# Epoch 372/600
# Generator Loss: 3.1699, Discriminator Loss: 0.5090
#
# Epoch 373/600
# Generator Loss: 3.3825, Discriminator Loss: 0.1067
#
# Epoch 374/600
# Generator Loss: 1.3826, Discriminator Loss: 0.4949
#
# Epoch 375/600
# Generator Loss: 2.8437, Discriminator Loss: 0.1520
#
# Epoch 376/600
# Generator Loss: 5.0962, Discriminator Loss: 0.3817
#
# Epoch 377/600
# Generator Loss: 4.6050, Discriminator Loss: 0.0357
#
# Epoch 378/600
# Generator Loss: 2.0416, Discriminator Loss: 0.2138
#
# Epoch 379/600
# Generator Loss: 1.2088, Discriminator Loss: 0.5485
#
# Epoch 380/600
# Generator Loss: 3.8175, Discriminator Loss: 0.1062
#
# Epoch 381/600
# Generator Loss: 4.1107, Discriminator Loss: 0.2968
#
# Epoch 382/600
# Generator Loss: 4.6847, Discriminator Loss: 0.0989
#
# Epoch 383/600
# Generator Loss: 1.6295, Discriminator Loss: 0.2989
#
# Epoch 384/600
# Generator Loss: 3.3802, Discriminator Loss: 0.0957
#
# Epoch 385/600
# Generator Loss: 1.9638, Discriminator Loss: 0.2640
#
# Epoch 386/600
# Generator Loss: 4.8547, Discriminator Loss: 0.7156
#
# Epoch 387/600
# Generator Loss: 4.0696, Discriminator Loss: 0.3734
#
# Epoch 388/600
# Generator Loss: 4.5407, Discriminator Loss: 0.1744
#
# Epoch 389/600
# Generator Loss: 1.5740, Discriminator Loss: 0.3135
#
# Epoch 390/600
# Generator Loss: 2.8113, Discriminator Loss: 0.6054
#
# Epoch 391/600
# Generator Loss: 2.1369, Discriminator Loss: 0.2229
#
# Epoch 392/600
# Generator Loss: 1.7964, Discriminator Loss: 0.2680
#
# Epoch 393/600
# Generator Loss: 1.7173, Discriminator Loss: 0.3421
#
# Epoch 394/600
# Generator Loss: 1.9451, Discriminator Loss: 0.2032
#
# Epoch 395/600
# Generator Loss: 5.0064, Discriminator Loss: 0.2329
#
# Epoch 396/600
# Generator Loss: 2.7371, Discriminator Loss: 0.2061
#
# Epoch 397/600
# Generator Loss: 1.9116, Discriminator Loss: 0.3440
#
# Epoch 398/600
# Generator Loss: 3.1223, Discriminator Loss: 0.2550
#
# Epoch 399/600
# Generator Loss: 2.2262, Discriminator Loss: 0.1928
#
# Epoch 400/600
# Generator Loss: 1.8651, Discriminator Loss: 0.5223
#
# Epoch 401/600
# Generator Loss: 2.8082, Discriminator Loss: 0.2183
#
# Epoch 402/600
# Generator Loss: 3.4639, Discriminator Loss: 0.0752
#
# Epoch 403/600
# Generator Loss: 3.7513, Discriminator Loss: 0.4534
#
# Epoch 404/600
# Generator Loss: 4.7107, Discriminator Loss: 0.2452
#
# Epoch 405/600
# Generator Loss: 2.3284, Discriminator Loss: 0.2029
#
# Epoch 406/600
# Generator Loss: 2.9342, Discriminator Loss: 0.2289
#
# Epoch 407/600
# Generator Loss: 1.5934, Discriminator Loss: 0.3738
#
# Epoch 408/600
# Generator Loss: 1.9884, Discriminator Loss: 0.2392
#
# Epoch 409/600
# Generator Loss: 0.7250, Discriminator Loss: 0.7622
#
# Epoch 410/600
# Generator Loss: 2.5764, Discriminator Loss: 0.3152
#
# Epoch 411/600
# Generator Loss: 1.2247, Discriminator Loss: 0.6078
#
# Epoch 412/600
# Generator Loss: 3.1082, Discriminator Loss: 0.3289
#
# Epoch 413/600
# Generator Loss: 4.3424, Discriminator Loss: 1.8483
#
# Epoch 414/600
# Generator Loss: 3.5676, Discriminator Loss: 0.0825
#
# Epoch 415/600
# Generator Loss: 1.1058, Discriminator Loss: 1.1357
#
# Epoch 416/600
# Generator Loss: 2.5497, Discriminator Loss: 0.1601
#
# Epoch 417/600
# Generator Loss: 0.1071, Discriminator Loss: 2.6985
#
# Epoch 418/600
# Generator Loss: 0.8784, Discriminator Loss: 0.7772
#
# Epoch 419/600
# Generator Loss: 1.6652, Discriminator Loss: 0.4437
#
# Epoch 420/600
# Generator Loss: 1.6805, Discriminator Loss: 0.3709
#
# Epoch 421/600
# Generator Loss: 1.2498, Discriminator Loss: 0.4199
#
# Epoch 422/600
# Generator Loss: 3.0535, Discriminator Loss: 0.4888
#
# Epoch 423/600
# Generator Loss: 3.1798, Discriminator Loss: 0.2408
#
# Epoch 424/600
# Generator Loss: 3.5576, Discriminator Loss: 0.3588
#
# Epoch 425/600
# Generator Loss: 3.5612, Discriminator Loss: 0.5522
#
# Epoch 426/600
# Generator Loss: 3.3580, Discriminator Loss: 0.1493
#
# Epoch 427/600
# Generator Loss: 3.3479, Discriminator Loss: 0.0775
#
# Epoch 428/600
# Generator Loss: 2.8862, Discriminator Loss: 0.4233
#
# Epoch 429/600
# Generator Loss: 3.2095, Discriminator Loss: 0.3341
#
# Epoch 430/600
# Generator Loss: 2.8877, Discriminator Loss: 0.3964
#
# Epoch 431/600
# Generator Loss: 4.7317, Discriminator Loss: 0.8397
#
# Epoch 432/600
# Generator Loss: 1.8942, Discriminator Loss: 0.4175
#
# Epoch 433/600
# Generator Loss: 2.3926, Discriminator Loss: 0.1558
#
# Epoch 434/600
# Generator Loss: 3.1159, Discriminator Loss: 0.2135
#
# Epoch 435/600
# Generator Loss: 3.2584, Discriminator Loss: 1.0934
#
# Epoch 436/600
# Generator Loss: 4.9129, Discriminator Loss: 0.4902
#
# Epoch 437/600
# Generator Loss: 2.0448, Discriminator Loss: 0.4044
#
# Epoch 438/600
# Generator Loss: 3.8464, Discriminator Loss: 1.0463
#
# Epoch 439/600
# Generator Loss: 2.5426, Discriminator Loss: 0.2481
#
# Epoch 440/600
# Generator Loss: 3.5492, Discriminator Loss: 0.1123
#
# Epoch 441/600
# Generator Loss: 1.8203, Discriminator Loss: 0.4210
#
# Epoch 442/600
# Generator Loss: 5.6608, Discriminator Loss: 0.9342
#
# Epoch 443/600
# Generator Loss: 2.1223, Discriminator Loss: 0.3110
#
# Epoch 444/600
# Generator Loss: 3.9061, Discriminator Loss: 0.0852
#
# Epoch 445/600
# Generator Loss: 2.5015, Discriminator Loss: 1.6700
#
# Epoch 446/600
# Generator Loss: 5.9738, Discriminator Loss: 1.8031
#
# Epoch 447/600
# Generator Loss: 4.2319, Discriminator Loss: 1.3516
#
# Epoch 448/600
# Generator Loss: 3.4033, Discriminator Loss: 0.0877
#
# Epoch 449/600
# Generator Loss: 4.2247, Discriminator Loss: 1.4334
#
# Epoch 450/600
# Generator Loss: 3.5560, Discriminator Loss: 0.0808
#
# Epoch 451/600
# Generator Loss: 0.6956, Discriminator Loss: 0.9791
#
# Epoch 452/600
# Generator Loss: 3.3034, Discriminator Loss: 0.5770
#
# Epoch 453/600
# Generator Loss: 1.8723, Discriminator Loss: 0.5661
#
# Epoch 454/600
# Generator Loss: 1.8776, Discriminator Loss: 0.4578
#
# Epoch 455/600
# Generator Loss: 2.0529, Discriminator Loss: 0.2344
#
# Epoch 456/600
# Generator Loss: 1.6924, Discriminator Loss: 0.2774
#
# Epoch 457/600
# Generator Loss: 3.2754, Discriminator Loss: 0.8102
#
# Epoch 458/600
# Generator Loss: 2.0088, Discriminator Loss: 0.2773
#
# Epoch 459/600
# Generator Loss: 2.5968, Discriminator Loss: 0.1229
#
# Epoch 460/600
# Generator Loss: 5.1111, Discriminator Loss: 1.7318
#
# Epoch 461/600
# Generator Loss: 4.0977, Discriminator Loss: 1.2145
#
# Epoch 462/600
# Generator Loss: 3.0848, Discriminator Loss: 0.4921
#
# Epoch 463/600
# Generator Loss: 1.0970, Discriminator Loss: 0.6751
#
# Epoch 464/600
# Generator Loss: 2.2224, Discriminator Loss: 0.1726
#
# Epoch 465/600
# Generator Loss: 1.6367, Discriminator Loss: 0.3712
#
# Epoch 466/600
# Generator Loss: 1.7919, Discriminator Loss: 0.3347
#
# Epoch 467/600
# Generator Loss: 2.0766, Discriminator Loss: 0.2256
#
# Epoch 468/600
# Generator Loss: 4.6887, Discriminator Loss: 0.6602
#
# Epoch 469/600
# Generator Loss: 3.8841, Discriminator Loss: 0.4153
#
# Epoch 470/600
# Generator Loss: 4.6306, Discriminator Loss: 0.7241
#
# Epoch 471/600
# Generator Loss: 4.3011, Discriminator Loss: 0.4605
#
# Epoch 472/600
# Generator Loss: 3.5251, Discriminator Loss: 0.4150
#
# Epoch 473/600
# Generator Loss: 1.8801, Discriminator Loss: 0.5045
#
# Epoch 474/600
# Generator Loss: 5.1973, Discriminator Loss: 1.6060
#
# Epoch 475/600
# Generator Loss: 1.8707, Discriminator Loss: 0.2546
#
# Epoch 476/600
# Generator Loss: 0.7313, Discriminator Loss: 0.8633
#
# Epoch 477/600
# Generator Loss: 0.7257, Discriminator Loss: 0.8446
#
# Epoch 478/600
# Generator Loss: 5.1210, Discriminator Loss: 2.1575
#
# Epoch 479/600
# Generator Loss: 3.8574, Discriminator Loss: 0.4618
#
# Epoch 480/600
# Generator Loss: 3.1783, Discriminator Loss: 0.2700
#
# Epoch 481/600
# Generator Loss: 1.5017, Discriminator Loss: 0.4057
#
# Epoch 482/600
# Generator Loss: 1.3579, Discriminator Loss: 0.3880
#
# Epoch 483/600
# Generator Loss: 3.2363, Discriminator Loss: 0.6430
#
# Epoch 484/600
# Generator Loss: 2.4590, Discriminator Loss: 0.2395
#
# Epoch 485/600
# Generator Loss: 4.3809, Discriminator Loss: 0.0804
#
# Epoch 486/600
# Generator Loss: 3.3113, Discriminator Loss: 0.3629
#
# Epoch 487/600
# Generator Loss: 2.9243, Discriminator Loss: 0.7180
#
# Epoch 488/600
# Generator Loss: 1.2923, Discriminator Loss: 0.5466
#
# Epoch 489/600
# Generator Loss: 0.9151, Discriminator Loss: 0.7684
#
# Epoch 490/600
# Generator Loss: 4.5728, Discriminator Loss: 0.1733
#
# Epoch 491/600
# Generator Loss: 2.9944, Discriminator Loss: 0.2038
#
# Epoch 492/600
# Generator Loss: 2.9367, Discriminator Loss: 0.7471
#
# Epoch 493/600
# Generator Loss: 2.5175, Discriminator Loss: 0.4351
#
# Epoch 494/600
# Generator Loss: 3.4006, Discriminator Loss: 0.0491
#
# Epoch 495/600
# Generator Loss: 4.1004, Discriminator Loss: 0.9931
#
# Epoch 496/600
# Generator Loss: 2.8010, Discriminator Loss: 0.2559
#
# Epoch 497/600
# Generator Loss: 4.3611, Discriminator Loss: 0.2053
#
# Epoch 498/600
# Generator Loss: 0.9220, Discriminator Loss: 0.7115
#
# Epoch 499/600
# Generator Loss: 1.1531, Discriminator Loss: 0.5312
#
# Epoch 500/600
# Generator Loss: 2.7955, Discriminator Loss: 0.3391
#
# Epoch 501/600
# Generator Loss: 2.3639, Discriminator Loss: 0.5378
#
# Epoch 502/600
# Generator Loss: 0.4509, Discriminator Loss: 1.2284
#
# Epoch 503/600
# Generator Loss: 3.9798, Discriminator Loss: 0.8211
#
# Epoch 504/600
# Generator Loss: 2.5971, Discriminator Loss: 0.2548
#
# Epoch 505/600
# Generator Loss: 0.9069, Discriminator Loss: 0.6957
#
# Epoch 506/600
# Generator Loss: 3.5470, Discriminator Loss: 0.1397
#
# Epoch 507/600
# Generator Loss: 3.2541, Discriminator Loss: 0.7211
#
# Epoch 508/600
# Generator Loss: 3.7434, Discriminator Loss: 0.3529
#
# Epoch 509/600
# Generator Loss: 3.5026, Discriminator Loss: 1.3471
#
# Epoch 510/600
# Generator Loss: 3.5079, Discriminator Loss: 0.0629
#
# Epoch 511/600
# Generator Loss: 1.3926, Discriminator Loss: 0.5898
#
# Epoch 512/600
# Generator Loss: 3.0108, Discriminator Loss: 0.3050
#
# Epoch 513/600
# Generator Loss: 2.5115, Discriminator Loss: 0.1519
#
# Epoch 514/600
# Generator Loss: 1.0933, Discriminator Loss: 0.6708
#
# Epoch 515/600
# Generator Loss: 4.8851, Discriminator Loss: 0.7103
#
# Epoch 516/600
# Generator Loss: 1.7047, Discriminator Loss: 0.3949
#
# Epoch 517/600
# Generator Loss: 1.8011, Discriminator Loss: 0.2824
#
# Epoch 518/600
# Generator Loss: 2.4950, Discriminator Loss: 0.3942
#
# Epoch 519/600
# Generator Loss: 4.0519, Discriminator Loss: 0.3380
#
# Epoch 520/600
# Generator Loss: 4.3209, Discriminator Loss: 0.9669
#
# Epoch 521/600
# Generator Loss: 1.9511, Discriminator Loss: 0.2525
#
# Epoch 522/600
# Generator Loss: 2.0016, Discriminator Loss: 0.2463
#
# Epoch 523/600
# Generator Loss: 5.2950, Discriminator Loss: 1.1599
#
# Epoch 524/600
# Generator Loss: 0.2763, Discriminator Loss: 1.6854
#
# Epoch 525/600
# Generator Loss: 1.5420, Discriminator Loss: 0.4280
#
# Epoch 526/600
# Generator Loss: 1.1105, Discriminator Loss: 0.6804
#
# Epoch 527/600
# Generator Loss: 1.2121, Discriminator Loss: 0.5568
#
# Epoch 528/600
# Generator Loss: 4.6774, Discriminator Loss: 1.2104
#
# Epoch 529/600
# Generator Loss: 2.3407, Discriminator Loss: 0.3627
#
# Epoch 530/600
# Generator Loss: 1.8092, Discriminator Loss: 0.2889
#
# Epoch 531/600
# Generator Loss: 3.5774, Discriminator Loss: 0.2105
#
# Epoch 532/600
# Generator Loss: 4.1682, Discriminator Loss: 0.0435
#
# Epoch 533/600
# Generator Loss: 1.6415, Discriminator Loss: 0.4878
#
# Epoch 534/600
# Generator Loss: 2.9811, Discriminator Loss: 0.1284
#
# Epoch 535/600
# Generator Loss: 2.3224, Discriminator Loss: 0.2972
#
# Epoch 536/600
# Generator Loss: 1.4912, Discriminator Loss: 0.3786
#
# Epoch 537/600
# Generator Loss: 3.4800, Discriminator Loss: 0.2619
#
# Epoch 538/600
# Generator Loss: 3.8668, Discriminator Loss: 0.6847
#
# Epoch 539/600
# Generator Loss: 2.1082, Discriminator Loss: 0.4038
#
# Epoch 540/600
# Generator Loss: 3.7774, Discriminator Loss: 0.6784
#
# Epoch 541/600
# Generator Loss: 2.7452, Discriminator Loss: 0.2465
#
# Epoch 542/600
# Generator Loss: 3.8705, Discriminator Loss: 1.5648
#
# Epoch 543/600
# Generator Loss: 1.1825, Discriminator Loss: 0.5941
#
# Epoch 544/600
# Generator Loss: 2.9378, Discriminator Loss: 0.1389
#
# Epoch 545/600
# Generator Loss: 2.4097, Discriminator Loss: 0.6125
#
# Epoch 546/600
# Generator Loss: 1.5151, Discriminator Loss: 0.4146
#
# Epoch 547/600
# Generator Loss: 3.8169, Discriminator Loss: 0.0448
#
# Epoch 548/600
# Generator Loss: 4.5749, Discriminator Loss: 0.0228
#
# Epoch 549/600
# Generator Loss: 2.9784, Discriminator Loss: 0.2306
#
# Epoch 550/600
# Generator Loss: 2.1982, Discriminator Loss: 0.2503
#
# Epoch 551/600
# Generator Loss: 4.3913, Discriminator Loss: 0.0276
#
# Epoch 552/600
# Generator Loss: 3.4626, Discriminator Loss: 0.6839
#
# Epoch 553/600
# Generator Loss: 3.0535, Discriminator Loss: 0.1586
#
# Epoch 554/600
# Generator Loss: 1.6690, Discriminator Loss: 0.3868
#
# Epoch 555/600
# Generator Loss: 1.3426, Discriminator Loss: 0.6908
#
# Epoch 556/600
# Generator Loss: 2.8444, Discriminator Loss: 0.2872
#
# Epoch 557/600
# Generator Loss: 1.8020, Discriminator Loss: 0.2499
#
# Epoch 558/600
# Generator Loss: 3.0362, Discriminator Loss: 0.4436
#
# Epoch 559/600
# Generator Loss: 3.0870, Discriminator Loss: 0.1629
#
# Epoch 560/600
# Generator Loss: 4.3465, Discriminator Loss: 0.3798
#
# Epoch 561/600
# Generator Loss: 2.8078, Discriminator Loss: 0.1737
#
# Epoch 562/600
# Generator Loss: 1.4274, Discriminator Loss: 0.6422
#
# Epoch 563/600
# Generator Loss: 3.0038, Discriminator Loss: 0.6522
#
# Epoch 564/600
# Generator Loss: 0.6621, Discriminator Loss: 1.0625
#
# Epoch 565/600
# Generator Loss: 2.1977, Discriminator Loss: 0.2007
#
# Epoch 566/600
# Generator Loss: 2.2247, Discriminator Loss: 0.2455
#
# Epoch 567/600
# Generator Loss: 2.8630, Discriminator Loss: 0.1029
#
# Epoch 568/600
# Generator Loss: 2.3662, Discriminator Loss: 0.1760
#
# Epoch 569/600
# Generator Loss: 1.8506, Discriminator Loss: 0.2445
#
# Epoch 570/600
# Generator Loss: 3.0037, Discriminator Loss: 0.3494
#
# Epoch 571/600
# Generator Loss: 2.5697, Discriminator Loss: 0.6634
#
# Epoch 572/600
# Generator Loss: 3.0549, Discriminator Loss: 0.0929
#
# Epoch 573/600
# Generator Loss: 3.8465, Discriminator Loss: 0.0746
#
# Epoch 574/600
# Generator Loss: 4.1958, Discriminator Loss: 0.4993
#
# Epoch 575/600
# Generator Loss: 2.4142, Discriminator Loss: 0.4257
#
# Epoch 576/600
# Generator Loss: 3.8842, Discriminator Loss: 0.6027
#
# Epoch 577/600
# Generator Loss: 1.1755, Discriminator Loss: 0.4869
#
# Epoch 578/600
# Generator Loss: 3.6139, Discriminator Loss: 0.0476
#
# Epoch 579/600
# Generator Loss: 3.5179, Discriminator Loss: 0.2935
#
# Epoch 580/600
# Generator Loss: 3.3460, Discriminator Loss: 0.4594
#
# Epoch 581/600
# Generator Loss: 2.9695, Discriminator Loss: 0.2841
#
# Epoch 582/600
# Generator Loss: 1.6738, Discriminator Loss: 0.3209
#
# Epoch 583/600
# Generator Loss: 2.3996, Discriminator Loss: 0.2815
#
# Epoch 584/600
# Generator Loss: 1.0921, Discriminator Loss: 0.5557
#
# Epoch 585/600
# Generator Loss: 2.8845, Discriminator Loss: 0.3969
#
# Epoch 586/600
# Generator Loss: 4.0971, Discriminator Loss: 1.3578
#
# Epoch 587/600
# Generator Loss: 2.0764, Discriminator Loss: 0.3629
#
# Epoch 588/600
# Generator Loss: 3.3667, Discriminator Loss: 0.0890
#
# Epoch 589/600
# Generator Loss: 2.9843, Discriminator Loss: 0.1049
#
# Epoch 590/600
# Generator Loss: 2.3576, Discriminator Loss: 0.5170
#
# Epoch 591/600
# Generator Loss: 3.4566, Discriminator Loss: 0.3590
#
# Epoch 592/600
# Generator Loss: 1.5673, Discriminator Loss: 0.5918
#
# Epoch 593/600
# Generator Loss: 3.4721, Discriminator Loss: 0.0999
#
# Epoch 594/600
# Generator Loss: 2.8149, Discriminator Loss: 0.1697
#
# Epoch 595/600
# Generator Loss: 1.9241, Discriminator Loss: 0.3799
#
# Epoch 596/600
# Generator Loss: 4.6536, Discriminator Loss: 0.6510
#
# Epoch 597/600
# Generator Loss: 3.7003, Discriminator Loss: 0.0548
#
# Epoch 598/600
# Generator Loss: 2.4287, Discriminator Loss: 0.2363
#
# Epoch 599/600
# Generator Loss: 1.5118, Discriminator Loss: 0.4506
#
# Epoch 600/600
# Generator Loss: 4.7060, Discriminator Loss: 0.6632

# %% [markdown]
# **FID GAN**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from scipy.linalg import sqrtm
import matplotlib.pyplot as plt

# Function to preprocess images for InceptionV3 (resize to 299x299 and normalize)
def preprocess_images(images):
    images_resized = tf.image.resize(images, (299, 299))  # Resize to 299x299 for InceptionV3
    return preprocess_input(images_resized)  # Preprocess images for InceptionV3

# Function to load and preprocess a single image (real or generated)
def load_image(image_path, img_size=(64, 64)):
    img = tf.io.read_file(image_path)  # Read the image file
    img = tf.image.decode_jpeg(img, channels=3)  # Decode as JPEG
    img = tf.image.resize(img, img_size)  # Resize to the input size (64x64 for this case)
    img = img / 255.0  # Normalize the image to [0, 1]
    return img

# FID Calculation function
def calculate_fid(real_images, generated_images):
    model = InceptionV3(include_top=False, pooling='avg', input_shape=(299, 299, 3))

    # Preprocess images
    real_images = preprocess_images(real_images)
    generated_images = preprocess_images(generated_images)

    # Extract features (activations) from InceptionV3
    real_act = model(real_images)
    gen_act = model(generated_images)

    # Calculate the mean and covariance of activations
    mu1, sigma1 = np.mean(real_act, axis=0), np.cov(real_act, rowvar=False)
    mu2, sigma2 = np.mean(gen_act, axis=0), np.cov(gen_act, rowvar=False)

    # Calculate the FID score
    ssdiff = np.sum((mu1 - mu2) ** 2.0)
    covmean, _ = sqrtm(sigma1.dot(sigma2), disp=False)

    # Check if the sqrtm produces complex values, and take the real part if necessary
    if np.iscomplexobj(covmean):
        covmean = covmean.real

    fid = ssdiff + np.trace(sigma1 + sigma2 - 2.0 * covmean)
    return fid

# Inception Score Calculation function
def calculate_inception_score(images, splits=10):
    model = InceptionV3(include_top=True, weights='imagenet')
    images_resized = preprocess_images(images)
    preds = model(images_resized).numpy()

    scores = []
    N = preds.shape[0]
    split_size = N // splits
    for i in range(splits):
        part = preds[i * split_size: (i + 1) * split_size]
        py = np.mean(part, axis=0)
        scores.append(np.exp(np.mean([np.sum(p * (np.log(p + 1e-10) - np.log(py + 1e-10))) for p in part])))
    return np.mean(scores), np.std(scores)

# Function to generate images
def generate_and_save_images(generator, noise, captions, epoch):
    generated_images = generator([noise, captions], training=False)

    # Visualize the generated images
    plt.figure(figsize=(12, 4))
    for i in range(len(captions)):
        plt.subplot(1, len(captions), i + 1)
        plt.imshow((generated_images[i].numpy() + 1) / 2.0)  # Rescale images
        plt.axis('off')
    plt.suptitle(f'Generated Images for Specific Captions - Epoch {600}')
    plt.show()

# Tokenizing and padding captions
specific_captions = [
    "ethnic Boys Printed Maroon Kurta",
    "sports Men Gel Running White Sports Shoes",
    "casual Men Aventura Sandal",
    "casual Boys Expressions Yellow T-shirt"
]

# Assuming tokenizer and max_caption_len are already defined (as per your training code)
specific_captions_tokenized = tokenizer.texts_to_sequences(specific_captions)
max_caption_len = 12  # Set based on your padding length
specific_captions_padded = tf.keras.preprocessing.sequence.pad_sequences(specific_captions_tokenized, maxlen=max_caption_len, padding='post')
specific_captions_padded = tf.convert_to_tensor(specific_captions_padded)

# Assuming noise_dim is defined and generator is your trained model
noise_dim = 100  # Adjust based on your model's noise dimension
noise = tf.random.normal([len(specific_captions), noise_dim])  # Generate random noise for each caption

# Generate images from the generator
generated_images = generator([noise, specific_captions_padded], training=False)

# Display the generated images
generate_and_save_images(generator, noise, specific_captions_padded, epoch=1)

# Load real images for FID evaluation
real_image_paths = [
    '/kaggle/input/iamgestotest/762maroonkurta.jpg',  # Replace with your actual file paths
    '/kaggle/input/iamgestotest/2000white sports.jpg',
    '/kaggle/input/iamgestotest/1500men snadals.jpg',
    '/kaggle/input/iamgestotest/1208shirtsmarvel.jpg'
]

# Load real images
real_images = np.array([load_image(path) for path in real_image_paths])

# Calculate FID
fid_score = calculate_fid(real_images, generated_images)
print(f"FID Score": {fid_score:.4f})
# Out:
# FID Score: 12.012

# %% [markdown]
# # **Style Gan**

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Embedding, LSTM, Concatenate, BatchNormalization, LeakyReLU, Conv2DTranspose, Conv2D, Add
from tensorflow.keras.models import Model

# Parameters
vocab_size = 1155
max_caption_len = 12
embedding_dim = 100
noise_dim = 100
image_shape = (64, 64, 3)

# Text Encoder
def build_text_encoder():
    caption_input = Input(shape=(max_caption_len,))
    x = Embedding(vocab_size, embedding_dim)(caption_input)
    x = LSTM(128)(x)
    return Model(caption_input, x, name="TextEncoder")

# Mapping Network (latent to style vector)
def build_mapping_network():
    input = Input(shape=(noise_dim,))
    x = Dense(256)(input)
    x = LeakyReLU()(x)
    x = Dense(256)(x)
    x = LeakyReLU()(x)
    x = Dense(256)(x)
    x = LeakyReLU()(x)
    return Model(input, x, name="MappingNetwork")

# StyleGAN Generator
def build_generator():
    text_encoder = build_text_encoder()
    mapping_network = build_mapping_network()

    noise_input = Input(shape=(noise_dim,))
    caption_input = Input(shape=(max_caption_len,))

    text_features = text_encoder(caption_input)
    style_vector = mapping_network(noise_input)

    # Combine text features and style vector (concatenate or other fusion method)
    merged = Concatenate()([text_features, style_vector])

    # Initial fully connected layer
    x = Dense(8 * 8 * 256, use_bias=False)(merged)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = Reshape((8, 8, 256))(x)

    # Progressive layers with style injection
    x = Conv2DTranspose(128, (5,5), strides=(2,2), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(64, (5,5), strides=(2,2), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(3, (5,5), strides=(2,2), padding='same', activation='tanh')(x)

    return Model([noise_input, caption_input], x, name="Generator")

# StyleGAN Discriminator
def build_discriminator():
    text_encoder = build_text_encoder()
    image_input = Input(shape=image_shape)
    caption_input = Input(shape=(max_caption_len,))

    text_features = text_encoder(caption_input)
    text_features = Dense(image_shape[0] * image_shape[1])(text_features)
    text_features = Reshape((image_shape[0], image_shape[1], 1))(text_features)

    # Concatenate image and text features
    merged = Concatenate()([image_input, text_features])

    x = Conv2D(64, (5,5), strides=(2,2), padding='same')(merged)
    x = LeakyReLU()(x)

    x = Conv2D(128, (5,5), strides=(2,2), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Flatten()(x)
    x = Dense(1, activation='sigmoid')(x)

    return Model([image_input, caption_input], x, name="Discriminator")

# Create models
generator = build_generator()
discriminator = build_discriminator()

generator.summary()
discriminator.summary()
# Out:
# I0000 00:00:1746897877.263411      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "Generator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3             │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_2             │ (None, 100)            │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TextEncoder (Functional)  │ (None, 128)            │        362,848 │ input_layer_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ MappingNetwork            │ (None, 256)            │        157,440 │ input_layer_2[0][0]    │
# │ (Functional)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 384)            │              0 │ TextEncoder[0][0],     │
# │                           │                        │                │ MappingNetwork[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 16384)          │      6,291,456 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 16384)          │         65,536 │ dense_3[0][0]          │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_3 (LeakyReLU) │ (None, 16384)          │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape (Reshape)         │ (None, 8, 8, 256)      │              0 │ leaky_re_lu_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 16, 16, 128)    │        819,200 │ reshape[0][0]          │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 16, 16, 128)    │            512 │ conv2d_transpose[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_4 (LeakyReLU) │ (None, 16, 16, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 32, 32, 64)     │        204,800 │ leaky_re_lu_4[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 32, 32, 64)     │            256 │ conv2d_transpose_1[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_5 (LeakyReLU) │ (None, 32, 32, 64)     │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 64, 64, 3)      │          4,803 │ leaky_re_lu_5[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 7,906,851 (30.16 MB)
#  Trainable params: 7,873,699 (30.04 MB)
#  Non-trainable params: 33,152 (129.50 KB)
# Model: "Discriminator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6             │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TextEncoder (Functional)  │ (None, 128)            │        362,848 │ input_layer_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 4096)           │        528,384 │ TextEncoder[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_5             │ (None, 64, 64, 3)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_1 (Reshape)       │ (None, 64, 64, 1)      │              0 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 64, 64, 4)      │              0 │ input_layer_5[0][0],   │
# │ (Concatenate)             │                        │                │ reshape_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 32, 32, 64)     │          6,464 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_6 (LeakyReLU) │ (None, 32, 32, 64)     │              0 │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 16, 16, 128)    │        204,928 │ leaky_re_lu_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 16, 16, 128)    │            512 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_7 (LeakyReLU) │ (None, 16, 16, 128)    │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 32768)          │              0 │ leaky_re_lu_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 1)              │         32,769 │ flatten[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,135,905 (4.33 MB)
#  Trainable params: 1,135,649 (4.33 MB)
#  Non-trainable params: 256 (1.00 KB)

# %%
from tensorflow.keras.layers import BatchNormalization

# %% [markdown]
# **50 Epochs**

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Training Parameters
BATCH_SIZE = 64
EPOCHS = 50
noise_dim = 100
BUFFER_SIZE = image_data.shape[0]

# Prepare dataset
dataset = tf.data.Dataset.from_tensor_slices((image_data, padded_captions))
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

# Optimizers
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# Loss function
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    return real_loss + fake_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# Training step
@tf.function
def train_step(images, captions):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator([noise, captions], training=True)

        real_output = discriminator([images, captions], training=True)
        fake_output = discriminator([generated_images, captions], training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return gen_loss, disc_loss

# Generate and display images
def generate_and_display_images(model, captions_tensor, epoch):
    noise = tf.random.normal([len(captions_tensor), noise_dim])
    generated_images = model([noise, captions_tensor], training=False)

    plt.figure(figsize=(12, 4))
    for i in range(len(captions_tensor)):
        plt.subplot(1, len(captions_tensor), i+1)
        plt.imshow((generated_images[i].numpy() + 1) / 2.0)
        plt.axis('off')
    plt.suptitle(f'Generated Images at Final Epoch {epoch}')
    plt.show()
specific_captions = [
    "ethnic Boys Printed Maroon Kurta",
    "sports Men Gel Running White Sports Shoes",
    "casual Men Aventura Sandal",
   "iPanema Women Black Flip Flops"
]

specific_captions_seq = tokenizer.texts_to_sequences(specific_captions)
specific_captions_padded = tf.keras.preprocessing.sequence.pad_sequences(
    specific_captions_seq,
    maxlen=max_caption_len,
    padding='post'
)
specific_captions_tensor = tf.convert_to_tensor(specific_captions_padded, dtype=tf.int32)

# Training loop
for epoch in range(1, EPOCHS + 1):
    print(f"\nEpoch {epoch}/{EPOCHS}")
    for batch_images, batch_captions in dataset:
        g_loss, d_loss = train_step(batch_images, batch_captions)

    print(f"Generator Loss: {g_loss.numpy():.4f}, Discriminator Loss: {d_loss.numpy():.4f}")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/nn.py:707: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# I0000 00:00:1746897924.883700     131 cuda_dnn.cc:529] Loaded cuDNN version 90300
# Generator Loss: 2.9892, Discriminator Loss: 0.0927
#
# Epoch 2/50
# Generator Loss: 3.3919, Discriminator Loss: 0.2184
#
# Epoch 3/50
# Generator Loss: 1.9875, Discriminator Loss: 0.5088
#
# Epoch 4/50
# Generator Loss: 1.2100, Discriminator Loss: 0.6220
#
# Epoch 5/50
# Generator Loss: 0.6574, Discriminator Loss: 1.1455
#
# Epoch 6/50
# Generator Loss: 1.2973, Discriminator Loss: 1.0846
#
# Epoch 7/50
# Generator Loss: 1.2209, Discriminator Loss: 0.7929
#
# Epoch 8/50
# Generator Loss: 1.4038, Discriminator Loss: 0.7956
#
# Epoch 9/50
# Generator Loss: 1.3065, Discriminator Loss: 0.9716
#
# Epoch 10/50
# Generator Loss: 0.7670, Discriminator Loss: 2.0499
#
# Epoch 11/50
# Generator Loss: 1.1751, Discriminator Loss: 1.0283
#
# Epoch 12/50
# Generator Loss: 1.6075, Discriminator Loss: 0.6674
#
# Epoch 13/50
# Generator Loss: 0.7651, Discriminator Loss: 1.4045
#
# Epoch 14/50
# Generator Loss: 1.1201, Discriminator Loss: 0.9878
#
# Epoch 15/50
# Generator Loss: 1.3470, Discriminator Loss: 1.4651
#
# Epoch 16/50
# Generator Loss: 0.7347, Discriminator Loss: 1.0691
#
# Epoch 17/50
# Generator Loss: 1.0889, Discriminator Loss: 1.6231
#
# Epoch 18/50
# Generator Loss: 1.3147, Discriminator Loss: 0.9465
#
# Epoch 19/50
# Generator Loss: 1.6306, Discriminator Loss: 0.6526
#
# Epoch 20/50
# Generator Loss: 1.5454, Discriminator Loss: 1.1186
#
# Epoch 21/50
# Generator Loss: 0.8280, Discriminator Loss: 1.4318
#
# Epoch 22/50
# Generator Loss: 1.0848, Discriminator Loss: 1.2044
#
# Epoch 23/50
# Generator Loss: 0.6947, Discriminator Loss: 1.3251
#
# Epoch 24/50
# Generator Loss: 0.8043, Discriminator Loss: 1.2797
#
# Epoch 25/50
# Generator Loss: 1.2820, Discriminator Loss: 1.0876
#
# Epoch 26/50
# Generator Loss: 0.8367, Discriminator Loss: 1.1875
#
# Epoch 27/50
# Generator Loss: 0.8229, Discriminator Loss: 1.1292
#
# Epoch 28/50
# Generator Loss: 1.2514, Discriminator Loss: 1.1200
#
# Epoch 29/50
# Generator Loss: 1.0252, Discriminator Loss: 1.1693
#
# Epoch 30/50
# Generator Loss: 1.1824, Discriminator Loss: 0.8238
#
# Epoch 31/50
# Generator Loss: 0.9401, Discriminator Loss: 1.2936
#
# Epoch 32/50
# Generator Loss: 0.4818, Discriminator Loss: 1.4638
#
# Epoch 33/50
# Generator Loss: 1.0520, Discriminator Loss: 1.6351
#
# Epoch 34/50
# Generator Loss: 1.3757, Discriminator Loss: 0.8103
#
# Epoch 35/50
# Generator Loss: 0.9411, Discriminator Loss: 1.1081
#
# Epoch 36/50
# Generator Loss: 0.8363, Discriminator Loss: 0.9964
#
# Epoch 37/50
# Generator Loss: 0.6538, Discriminator Loss: 1.8695
#
# Epoch 38/50
# Generator Loss: 0.9545, Discriminator Loss: 1.8880
#
# Epoch 39/50
# Generator Loss: 0.8814, Discriminator Loss: 0.9330
#
# Epoch 40/50
# Generator Loss: 1.5594, Discriminator Loss: 0.6142
#
# Epoch 41/50
# Generator Loss: 0.8058, Discriminator Loss: 1.2377
#
# Epoch 42/50
# Generator Loss: 0.6773, Discriminator Loss: 1.5625
#
# Epoch 43/50
# Generator Loss: 1.9665, Discriminator Loss: 0.6441
#
# Epoch 44/50
# Generator Loss: 0.7753, Discriminator Loss: 1.0108
#
# Epoch 45/50
# Generator Loss: 0.4289, Discriminator Loss: 1.3498
#
# Epoch 46/50
# Generator Loss: 0.7049, Discriminator Loss: 1.2866
#
# Epoch 47/50
# Generator Loss: 1.5199, Discriminator Loss: 1.4751
#
# Epoch 48/50
# Generator Loss: 0.5936, Discriminator Loss: 1.6699
#
# Epoch 49/50
# Generator Loss: 0.8961, Discriminator Loss: 1.7331
#
# Epoch 50/50
# Generator Loss: 0.6405, Discriminator Loss: 1.4740

# %%
# Generate and display images (separately)
def generate_and_display_images(model, captions_tensor, epoch):
    noise = tf.random.normal([len(captions_tensor), noise_dim])
    generated_images = model([noise, captions_tensor], training=False)

    for i in range(len(captions_tensor)):
        plt.figure()
        plt.imshow((generated_images[i].numpy() + 1) / 2.0)
        plt.axis('off')
        plt.title(f'Generated Image {i+1} at Epoch {epoch}')
        plt.show()
# Show final results only after last epoch
generate_and_display_images(generator, specific_captions_tensor, EPOCHS)

# %% [markdown]
# **200 epchs**

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Training Parameters
BATCH_SIZE = 64
EPOCHS = 200
noise_dim = 100
BUFFER_SIZE = image_data.shape[0]

# Prepare dataset
dataset = tf.data.Dataset.from_tensor_slices((image_data, padded_captions))
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

# Optimizers
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# Loss function
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    return real_loss + fake_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# Training step
@tf.function
def train_step(images, captions):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator([noise, captions], training=True)

        real_output = discriminator([images, captions], training=True)
        fake_output = discriminator([generated_images, captions], training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return gen_loss, disc_loss

# Generate and display images
def generate_and_display_images(model, captions_tensor, epoch):
    noise = tf.random.normal([len(captions_tensor), noise_dim])
    generated_images = model([noise, captions_tensor], training=False)

    plt.figure(figsize=(12, 4))
    for i in range(len(captions_tensor)):
        plt.subplot(1, len(captions_tensor), i+1)
        plt.imshow((generated_images[i].numpy() + 1) / 2.0)
        plt.axis('off')
    plt.suptitle(f'Generated Images at Final Epoch {epoch}')
    plt.show()

specific_captions = [
    "ethnic Boys Printed Maroon Kurta",
    "sports Men Gel Running White Sports Shoes",
    "casual Men Aventura Sandal",
   "iPanema Women Black Flip Flops"
]

specific_captions_seq = tokenizer.texts_to_sequences(specific_captions)
specific_captions_padded = tf.keras.preprocessing.sequence.pad_sequences(
    specific_captions_seq,
    maxlen=max_caption_len,
    padding='post'
)
specific_captions_tensor = tf.convert_to_tensor(specific_captions_padded, dtype=tf.int32)

# Training loop
for epoch in range(1, EPOCHS + 1):
    print(f"\nEpoch {epoch}/{EPOCHS}")
    for batch_images, batch_captions in dataset:
        g_loss, d_loss = train_step(batch_images, batch_captions)

    print(f"Generator Loss: {g_loss.numpy():.4f}, Discriminator Loss: {d_loss.numpy():.4f}")
# Out:
# Epoch 1/200
# Generator Loss: 0.7636, Discriminator Loss: 1.6662
#
# Epoch 2/200
# Generator Loss: 0.6352, Discriminator Loss: 1.6980
#
# Epoch 3/200
# Generator Loss: 0.9618, Discriminator Loss: 1.4658
#
# Epoch 4/200
# Generator Loss: 1.3020, Discriminator Loss: 1.7132
#
# Epoch 5/200
# Generator Loss: 0.7368, Discriminator Loss: 1.4983
#
# Epoch 6/200
# Generator Loss: 1.3469, Discriminator Loss: 1.0091
#
# Epoch 7/200
# Generator Loss: 1.2072, Discriminator Loss: 1.8671
#
# Epoch 8/200
# Generator Loss: 0.9301, Discriminator Loss: 1.5489
#
# Epoch 9/200
# Generator Loss: 0.8061, Discriminator Loss: 1.1519
#
# Epoch 10/200
# Generator Loss: 0.6720, Discriminator Loss: 1.6712
#
# Epoch 11/200
# Generator Loss: 1.0086, Discriminator Loss: 1.3252
#
# Epoch 12/200
# Generator Loss: 0.7362, Discriminator Loss: 1.6033
#
# Epoch 13/200
# Generator Loss: 1.0067, Discriminator Loss: 1.5714
#
# Epoch 14/200
# Generator Loss: 0.7494, Discriminator Loss: 1.7072
#
# Epoch 15/200
# Generator Loss: 1.0860, Discriminator Loss: 1.3198
#
# Epoch 16/200
# Generator Loss: 1.0472, Discriminator Loss: 1.4780
#
# Epoch 17/200
# Generator Loss: 1.2650, Discriminator Loss: 1.0319
#
# Epoch 18/200
# Generator Loss: 1.0016, Discriminator Loss: 0.8878
#
# Epoch 19/200
# Generator Loss: 0.5817, Discriminator Loss: 1.8319
#
# Epoch 20/200
# Generator Loss: 0.7438, Discriminator Loss: 1.2633
#
# Epoch 21/200
# Generator Loss: 0.9827, Discriminator Loss: 1.1199
#
# Epoch 22/200
# Generator Loss: 0.9015, Discriminator Loss: 1.8762
#
# Epoch 23/200
# Generator Loss: 0.8307, Discriminator Loss: 1.3957
#
# Epoch 24/200
# Generator Loss: 1.0725, Discriminator Loss: 1.5638
#
# Epoch 25/200
# Generator Loss: 0.5388, Discriminator Loss: 1.8711
#
# Epoch 26/200
# Generator Loss: 1.1719, Discriminator Loss: 1.5277
#
# Epoch 27/200
# Generator Loss: 1.5734, Discriminator Loss: 1.0901
#
# Epoch 28/200
# Generator Loss: 1.0515, Discriminator Loss: 1.6382
#
# Epoch 29/200
# Generator Loss: 0.9707, Discriminator Loss: 1.2041
#
# Epoch 30/200
# Generator Loss: 1.0924, Discriminator Loss: 1.2219
#
# Epoch 31/200
# Generator Loss: 0.9272, Discriminator Loss: 1.3145
#
# Epoch 32/200
# Generator Loss: 1.1421, Discriminator Loss: 0.8153
#
# Epoch 33/200
# Generator Loss: 0.6949, Discriminator Loss: 1.2331
#
# Epoch 34/200
# Generator Loss: 0.9435, Discriminator Loss: 0.8619
#
# Epoch 35/200
# Generator Loss: 1.3175, Discriminator Loss: 0.6702
#
# Epoch 36/200
# Generator Loss: 0.7173, Discriminator Loss: 1.4612
#
# Epoch 37/200
# Generator Loss: 1.1173, Discriminator Loss: 0.8185
#
# Epoch 38/200
# Generator Loss: 1.2107, Discriminator Loss: 0.9151
#
# Epoch 39/200
# Generator Loss: 1.1010, Discriminator Loss: 0.9682
#
# Epoch 40/200
# Generator Loss: 1.2640, Discriminator Loss: 0.9220
#
# Epoch 41/200
# Generator Loss: 0.8684, Discriminator Loss: 1.0048
#
# Epoch 42/200
# Generator Loss: 0.4349, Discriminator Loss: 2.1869
#
# Epoch 43/200
# Generator Loss: 1.1519, Discriminator Loss: 1.0205
#
# Epoch 44/200
# Generator Loss: 1.9683, Discriminator Loss: 0.4994
#
# Epoch 45/200
# Generator Loss: 1.4837, Discriminator Loss: 0.6540
#
# Epoch 46/200
# Generator Loss: 0.6987, Discriminator Loss: 1.2329
#
# Epoch 47/200
# Generator Loss: 1.0431, Discriminator Loss: 0.9663
#
# Epoch 48/200
# Generator Loss: 1.3132, Discriminator Loss: 1.2645
#
# Epoch 49/200
# Generator Loss: 1.7450, Discriminator Loss: 1.1744
#
# Epoch 50/200
# Generator Loss: 1.6377, Discriminator Loss: 1.2589
#
# Epoch 51/200
# Generator Loss: 1.0496, Discriminator Loss: 1.0840
#
# Epoch 52/200
# Generator Loss: 1.4884, Discriminator Loss: 0.6242
#
# Epoch 53/200
# Generator Loss: 1.0898, Discriminator Loss: 0.8902
#
# Epoch 54/200
# Generator Loss: 1.1723, Discriminator Loss: 0.7174
#
# Epoch 55/200
# Generator Loss: 0.8456, Discriminator Loss: 1.0243
#
# Epoch 56/200
# Generator Loss: 0.6297, Discriminator Loss: 1.1317
#
# Epoch 57/200
# Generator Loss: 0.6226, Discriminator Loss: 1.2755
#
# Epoch 58/200
# Generator Loss: 1.7177, Discriminator Loss: 0.6280
#
# Epoch 59/200
# Generator Loss: 1.2834, Discriminator Loss: 0.8405
#
# Epoch 60/200
# Generator Loss: 1.3620, Discriminator Loss: 0.9735
#
# Epoch 61/200
# Generator Loss: 1.1615, Discriminator Loss: 1.1129
#
# Epoch 62/200
# Generator Loss: 1.7005, Discriminator Loss: 0.6818
#
# Epoch 63/200
# Generator Loss: 1.1004, Discriminator Loss: 0.8451
#
# Epoch 64/200
# Generator Loss: 1.6188, Discriminator Loss: 1.1087
#
# Epoch 65/200
# Generator Loss: 0.8990, Discriminator Loss: 0.9960
#
# Epoch 66/200
# Generator Loss: 2.1470, Discriminator Loss: 0.3037
#
# Epoch 67/200
# Generator Loss: 0.6793, Discriminator Loss: 1.0904
#
# Epoch 68/200
# Generator Loss: 1.1357, Discriminator Loss: 1.0637
#
# Epoch 69/200
# Generator Loss: 2.1655, Discriminator Loss: 0.8869
#
# Epoch 70/200
# Generator Loss: 2.0543, Discriminator Loss: 0.6339
#
# Epoch 71/200
# Generator Loss: 1.3349, Discriminator Loss: 1.4016
#
# Epoch 72/200
# Generator Loss: 1.0600, Discriminator Loss: 1.2371
#
# Epoch 73/200
# Generator Loss: 1.6018, Discriminator Loss: 0.9619
#
# Epoch 74/200
# Generator Loss: 1.8396, Discriminator Loss: 0.6755
#
# Epoch 75/200
# Generator Loss: 0.6797, Discriminator Loss: 1.5198
#
# Epoch 76/200
# Generator Loss: 1.6033, Discriminator Loss: 0.5592
#
# Epoch 77/200
# Generator Loss: 1.4288, Discriminator Loss: 1.0076
#
# Epoch 78/200
# Generator Loss: 1.5632, Discriminator Loss: 0.6363
#
# Epoch 79/200
# Generator Loss: 1.2684, Discriminator Loss: 0.9538
#
# Epoch 80/200
# Generator Loss: 1.9396, Discriminator Loss: 0.9033
#
# Epoch 81/200
# Generator Loss: 1.3837, Discriminator Loss: 0.7342
#
# Epoch 82/200
# Generator Loss: 1.4313, Discriminator Loss: 0.4776
#
# Epoch 83/200
# Generator Loss: 1.1289, Discriminator Loss: 0.7760
#
# Epoch 84/200
# Generator Loss: 1.3308, Discriminator Loss: 1.0758
#
# Epoch 85/200
# Generator Loss: 1.0860, Discriminator Loss: 0.7569
#
# Epoch 86/200
# Generator Loss: 1.4056, Discriminator Loss: 0.5946
#
# Epoch 87/200
# Generator Loss: 1.0033, Discriminator Loss: 0.7927
#
# Epoch 88/200
# Generator Loss: 1.5512, Discriminator Loss: 0.5915
#
# Epoch 89/200
# Generator Loss: 1.1181, Discriminator Loss: 0.7645
#
# Epoch 90/200
# Generator Loss: 1.6116, Discriminator Loss: 0.6998
#
# Epoch 91/200
# Generator Loss: 1.7429, Discriminator Loss: 0.8589
#
# Epoch 92/200
# Generator Loss: 1.2865, Discriminator Loss: 0.7098
#
# Epoch 93/200
# Generator Loss: 1.4510, Discriminator Loss: 0.5431
#
# Epoch 94/200
# Generator Loss: 1.4288, Discriminator Loss: 0.7274
#
# Epoch 95/200
# Generator Loss: 1.1718, Discriminator Loss: 0.6691
#
# Epoch 96/200
# Generator Loss: 1.6476, Discriminator Loss: 0.8370
#
# Epoch 97/200
# Generator Loss: 2.2741, Discriminator Loss: 0.4699
#
# Epoch 98/200
# Generator Loss: 1.2066, Discriminator Loss: 0.4717
#
# Epoch 99/200
# Generator Loss: 1.4312, Discriminator Loss: 0.6906
#
# Epoch 100/200
# Generator Loss: 2.0368, Discriminator Loss: 0.6461
#
# Epoch 101/200
# Generator Loss: 2.3239, Discriminator Loss: 0.9808
#
# Epoch 102/200
# Generator Loss: 1.5343, Discriminator Loss: 0.5539
#
# Epoch 103/200
# Generator Loss: 0.7545, Discriminator Loss: 0.8023
#
# Epoch 104/200
# Generator Loss: 2.3721, Discriminator Loss: 0.5894
#
# Epoch 105/200
# Generator Loss: 1.5041, Discriminator Loss: 0.6539
#
# Epoch 106/200
# Generator Loss: 1.6743, Discriminator Loss: 1.1499
#
# Epoch 107/200
# Generator Loss: 1.7538, Discriminator Loss: 0.7773
#
# Epoch 108/200
# Generator Loss: 1.6494, Discriminator Loss: 0.7397
#
# Epoch 109/200
# Generator Loss: 1.4714, Discriminator Loss: 0.6834
#
# Epoch 110/200
# Generator Loss: 1.6999, Discriminator Loss: 0.5040
#
# Epoch 111/200
# Generator Loss: 2.0076, Discriminator Loss: 0.6200
#
# Epoch 112/200
# Generator Loss: 1.1641, Discriminator Loss: 0.7251
#
# Epoch 113/200
# Generator Loss: 2.5899, Discriminator Loss: 0.1914
#
# Epoch 114/200
# Generator Loss: 1.1546, Discriminator Loss: 0.9693
#
# Epoch 115/200
# Generator Loss: 2.2564, Discriminator Loss: 0.7096
#
# Epoch 116/200
# Generator Loss: 1.1387, Discriminator Loss: 0.6580
#
# Epoch 117/200
# Generator Loss: 1.6144, Discriminator Loss: 0.4195
#
# Epoch 118/200
# Generator Loss: 2.5293, Discriminator Loss: 0.3738
#
# Epoch 119/200
# Generator Loss: 2.5667, Discriminator Loss: 0.8187
#
# Epoch 120/200
# Generator Loss: 2.4612, Discriminator Loss: 0.3502
#
# Epoch 121/200
# Generator Loss: 2.5350, Discriminator Loss: 0.9034
#
# Epoch 122/200
# Generator Loss: 1.8522, Discriminator Loss: 0.4607
#
# Epoch 123/200
# Generator Loss: 2.0328, Discriminator Loss: 0.3933
#
# Epoch 124/200
# Generator Loss: 1.4277, Discriminator Loss: 0.6058
#
# Epoch 125/200
# Generator Loss: 0.7812, Discriminator Loss: 0.8413
#
# Epoch 126/200
# Generator Loss: 2.1946, Discriminator Loss: 0.7224
#
# Epoch 127/200
# Generator Loss: 1.7580, Discriminator Loss: 0.2753
#
# Epoch 128/200
# Generator Loss: 1.9487, Discriminator Loss: 0.6721
#
# Epoch 129/200
# Generator Loss: 1.4655, Discriminator Loss: 0.4257
#
# Epoch 130/200
# Generator Loss: 0.7868, Discriminator Loss: 1.1676
#
# Epoch 131/200
# Generator Loss: 1.8275, Discriminator Loss: 0.8552
#
# Epoch 132/200
# Generator Loss: 1.7225, Discriminator Loss: 0.4783
#
# Epoch 133/200
# Generator Loss: 2.1123, Discriminator Loss: 0.2861
#
# Epoch 134/200
# Generator Loss: 2.5360, Discriminator Loss: 0.5367
#
# Epoch 135/200
# Generator Loss: 1.9158, Discriminator Loss: 0.6488
#
# Epoch 136/200
# Generator Loss: 2.0690, Discriminator Loss: 0.7088
#
# Epoch 137/200
# Generator Loss: 1.8484, Discriminator Loss: 0.4693
#
# Epoch 138/200
# Generator Loss: 1.9406, Discriminator Loss: 0.3126
#
# Epoch 139/200
# Generator Loss: 2.0278, Discriminator Loss: 0.3876
#
# Epoch 140/200
# Generator Loss: 1.1419, Discriminator Loss: 1.0717
#
# Epoch 141/200
# Generator Loss: 1.8989, Discriminator Loss: 0.7504
#
# Epoch 142/200
# Generator Loss: 1.4337, Discriminator Loss: 0.5530
#
# Epoch 143/200
# Generator Loss: 1.3893, Discriminator Loss: 0.5510
#
# Epoch 144/200
# Generator Loss: 2.5779, Discriminator Loss: 0.2872
#
# Epoch 145/200
# Generator Loss: 0.9633, Discriminator Loss: 0.6237
#
# Epoch 146/200
# Generator Loss: 1.8731, Discriminator Loss: 0.8030
#
# Epoch 147/200
# Generator Loss: 1.4513, Discriminator Loss: 0.3497
#
# Epoch 148/200
# Generator Loss: 2.2816, Discriminator Loss: 0.3470
#
# Epoch 149/200
# Generator Loss: 0.8238, Discriminator Loss: 0.8964
#
# Epoch 150/200
# Generator Loss: 2.8093, Discriminator Loss: 0.2921
#
# Epoch 151/200
# Generator Loss: 2.3321, Discriminator Loss: 0.3239
#
# Epoch 152/200
# Generator Loss: 0.6954, Discriminator Loss: 0.9551
#
# Epoch 153/200
# Generator Loss: 2.3587, Discriminator Loss: 0.4536
#
# Epoch 154/200
# Generator Loss: 1.3512, Discriminator Loss: 0.7552
#
# Epoch 155/200
# Generator Loss: 1.3990, Discriminator Loss: 0.9179
#
# Epoch 156/200
# Generator Loss: 1.4713, Discriminator Loss: 0.4972
#
# Epoch 157/200
# Generator Loss: 1.3652, Discriminator Loss: 0.6641
#
# Epoch 158/200
# Generator Loss: 1.0417, Discriminator Loss: 0.8498
#
# Epoch 159/200
# Generator Loss: 1.3204, Discriminator Loss: 0.6701
#
# Epoch 160/200
# Generator Loss: 1.3281, Discriminator Loss: 0.6519
#
# Epoch 161/200
# Generator Loss: 2.9861, Discriminator Loss: 0.2720
#
# Epoch 162/200
# Generator Loss: 1.2990, Discriminator Loss: 0.9101
#
# Epoch 163/200
# Generator Loss: 2.7314, Discriminator Loss: 0.6753
#
# Epoch 164/200
# Generator Loss: 1.5782, Discriminator Loss: 0.6374
#
# Epoch 165/200
# Generator Loss: 2.3414, Discriminator Loss: 0.5199
#
# Epoch 166/200
# Generator Loss: 2.1496, Discriminator Loss: 0.4128
#
# Epoch 167/200
# Generator Loss: 2.3242, Discriminator Loss: 0.1456
#
# Epoch 168/200
# Generator Loss: 2.2529, Discriminator Loss: 0.6056
#
# Epoch 169/200
# Generator Loss: 1.4523, Discriminator Loss: 0.6456
#
# Epoch 170/200
# Generator Loss: 1.2971, Discriminator Loss: 0.5812
#
# Epoch 171/200
# Generator Loss: 3.4028, Discriminator Loss: 0.4030
#
# Epoch 172/200
# Generator Loss: 2.7871, Discriminator Loss: 0.2154
#
# Epoch 173/200
# Generator Loss: 2.4626, Discriminator Loss: 0.2005
#
# Epoch 174/200
# Generator Loss: 1.3372, Discriminator Loss: 0.5997
#
# Epoch 175/200
# Generator Loss: 3.6060, Discriminator Loss: 1.0326
#
# Epoch 176/200
# Generator Loss: 0.9729, Discriminator Loss: 0.5798
#
# Epoch 177/200
# Generator Loss: 4.2373, Discriminator Loss: 0.3206
#
# Epoch 178/200
# Generator Loss: 2.8522, Discriminator Loss: 0.4700
#
# Epoch 179/200
# Generator Loss: 1.0499, Discriminator Loss: 0.7866
#
# Epoch 180/200
# Generator Loss: 2.1321, Discriminator Loss: 0.4000
#
# Epoch 181/200
# Generator Loss: 2.4542, Discriminator Loss: 0.1706
#
# Epoch 182/200
# Generator Loss: 3.4979, Discriminator Loss: 0.1549
#
# Epoch 183/200
# Generator Loss: 1.9321, Discriminator Loss: 0.5081
#
# Epoch 184/200
# Generator Loss: 2.6276, Discriminator Loss: 0.6101
#
# Epoch 185/200
# Generator Loss: 2.5096, Discriminator Loss: 0.2330
#
# Epoch 186/200
# Generator Loss: 3.0987, Discriminator Loss: 0.3412
#
# Epoch 187/200
# Generator Loss: 0.4453, Discriminator Loss: 1.5006
#
# Epoch 188/200
# Generator Loss: 3.0004, Discriminator Loss: 0.7307
#
# Epoch 189/200
# Generator Loss: 1.6133, Discriminator Loss: 0.8021
#
# Epoch 190/200
# Generator Loss: 2.6525, Discriminator Loss: 0.2674
#
# Epoch 191/200
# Generator Loss: 1.8246, Discriminator Loss: 0.6896
#
# Epoch 192/200
# Generator Loss: 4.1272, Discriminator Loss: 0.4360
#
# Epoch 193/200
# Generator Loss: 0.4547, Discriminator Loss: 1.3810
#
# Epoch 194/200
# Generator Loss: 2.2546, Discriminator Loss: 0.4870
#
# Epoch 195/200
# Generator Loss: 3.1176, Discriminator Loss: 0.1169
#
# Epoch 196/200
# Generator Loss: 2.4170, Discriminator Loss: 0.5965
#
# Epoch 197/200
# Generator Loss: 3.7201, Discriminator Loss: 0.8531
#
# Epoch 198/200
# Generator Loss: 2.7762, Discriminator Loss: 0.3328
#
# Epoch 199/200
# Generator Loss: 1.1009, Discriminator Loss: 0.6136
#
# Epoch 200/200
# Generator Loss: 3.4580, Discriminator Loss: 0.4343

# %%
# Generate and display images (separately)
def generate_and_display_images(model, captions_tensor, epoch):
    noise = tf.random.normal([len(captions_tensor), noise_dim])
    generated_images = model([noise, captions_tensor], training=False)

    for i in range(len(captions_tensor)):
        plt.figure()
        plt.imshow((generated_images[i].numpy() + 1) / 2.0)
        plt.axis('off')
        plt.title(f'Generated Image {i+1} at Epoch {200}')
        plt.show()
# Show final results only after last epoch
generate_and_display_images(generator, specific_captions_tensor, EPOCHS)

# %% [markdown]
# **600 epochs**

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Training Parameters
BATCH_SIZE = 64
EPOCHS = 600
noise_dim = 100
BUFFER_SIZE = image_data.shape[0]

# Prepare dataset
dataset = tf.data.Dataset.from_tensor_slices((image_data, padded_captions))
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

# Optimizers
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# Loss function
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    return real_loss + fake_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# Training step
@tf.function
def train_step(images, captions):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator([noise, captions], training=True)

        real_output = discriminator([images, captions], training=True)
        fake_output = discriminator([generated_images, captions], training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return gen_loss, disc_loss

# Generate and display images
def generate_and_display_images(model, captions_tensor, epoch):
    noise = tf.random.normal([len(captions_tensor), noise_dim])
    generated_images = model([noise, captions_tensor], training=False)

    plt.figure(figsize=(12, 4))
    for i in range(len(captions_tensor)):
        plt.subplot(1, len(captions_tensor), i+1)
        plt.imshow((generated_images[i].numpy() + 1) / 2.0)
        plt.axis('off')
    plt.suptitle(f'Generated Images at Final Epoch {epoch}')
    plt.show()

specific_captions = [
    "ethnic Boys Printed Maroon Kurta",
    "sports Men Gel Running White Sports Shoes",
    "casual Men Aventura Sandal",
   "iPanema Women Black Flip Flops"
]

specific_captions_seq = tokenizer.texts_to_sequences(specific_captions)
specific_captions_padded = tf.keras.preprocessing.sequence.pad_sequences(
    specific_captions_seq,
    maxlen=max_caption_len,
    padding='post'
)
specific_captions_tensor = tf.convert_to_tensor(specific_captions_padded, dtype=tf.int32)

# Training loop
for epoch in range(1, EPOCHS + 1):
    print(f"\nEpoch {epoch}/{EPOCHS}")
    for batch_images, batch_captions in dataset:
        g_loss, d_loss = train_step(batch_images, batch_captions)

    print(f"Generator Loss: {g_loss.numpy():.4f}, Discriminator Loss: {d_loss.numpy():.4f}")
# Out:
# Epoch 1/600
# Generator Loss: 2.1293, Discriminator Loss: 0.7807
#
# Epoch 2/600
# Generator Loss: 2.0728, Discriminator Loss: 0.8679
#
# Epoch 3/600
# Generator Loss: 1.7727, Discriminator Loss: 0.7895
#
# Epoch 4/600
# Generator Loss: 1.7739, Discriminator Loss: 0.6686
#
# Epoch 5/600
# Generator Loss: 2.3779, Discriminator Loss: 0.6880
#
# Epoch 6/600
# Generator Loss: 2.1615, Discriminator Loss: 0.5293
#
# Epoch 7/600
# Generator Loss: 2.4606, Discriminator Loss: 0.7467
#
# Epoch 8/600
# Generator Loss: 2.3869, Discriminator Loss: 1.3145
#
# Epoch 9/600
# Generator Loss: 1.3217, Discriminator Loss: 0.7251
#
# Epoch 10/600
# Generator Loss: 3.3132, Discriminator Loss: 0.8179
#
# Epoch 11/600
# Generator Loss: 2.3375, Discriminator Loss: 0.3154
#
# Epoch 12/600
# Generator Loss: 1.2677, Discriminator Loss: 0.5787
#
# Epoch 13/600
# Generator Loss: 0.3929, Discriminator Loss: 1.5594
#
# Epoch 14/600
# Generator Loss: 1.1700, Discriminator Loss: 0.8639
#
# Epoch 15/600
# Generator Loss: 1.3902, Discriminator Loss: 0.6003
#
# Epoch 16/600
# Generator Loss: 0.8919, Discriminator Loss: 1.6781
#
# Epoch 17/600
# Generator Loss: 2.6437, Discriminator Loss: 0.9656
#
# Epoch 18/600
# Generator Loss: 3.4097, Discriminator Loss: 1.1736
#
# Epoch 19/600
# Generator Loss: 3.9555, Discriminator Loss: 1.0362
#
# Epoch 20/600
# Generator Loss: 0.7595, Discriminator Loss: 1.2121
#
# Epoch 21/600
# Generator Loss: 2.7735, Discriminator Loss: 0.3630
#
# Epoch 22/600
# Generator Loss: 3.2143, Discriminator Loss: 1.6642
#
# Epoch 23/600
# Generator Loss: 1.6223, Discriminator Loss: 0.9246
#
# Epoch 24/600
# Generator Loss: 2.4791, Discriminator Loss: 0.9145
#
# Epoch 25/600
# Generator Loss: 0.8718, Discriminator Loss: 0.7604
#
# Epoch 26/600
# Generator Loss: 0.8852, Discriminator Loss: 1.1954
#
# Epoch 27/600
# Generator Loss: 2.3351, Discriminator Loss: 0.3975
#
# Epoch 28/600
# Generator Loss: 1.3553, Discriminator Loss: 1.8323
#
# Epoch 29/600
# Generator Loss: 0.8449, Discriminator Loss: 1.3001
#
# Epoch 30/600
# Generator Loss: 1.2754, Discriminator Loss: 0.8643
#
# Epoch 31/600
# Generator Loss: 2.2216, Discriminator Loss: 0.6565
#
# Epoch 32/600
# Generator Loss: 1.9548, Discriminator Loss: 1.8223
#
# Epoch 33/600
# Generator Loss: 1.8263, Discriminator Loss: 1.5892
#
# Epoch 34/600
# Generator Loss: 2.3682, Discriminator Loss: 0.5053
#
# Epoch 35/600
# Generator Loss: 3.0212, Discriminator Loss: 1.3940
#
# Epoch 36/600
# Generator Loss: 1.2098, Discriminator Loss: 0.9652
#
# Epoch 37/600
# Generator Loss: 1.8028, Discriminator Loss: 0.9054
#
# Epoch 38/600
# Generator Loss: 0.9971, Discriminator Loss: 0.9444
#
# Epoch 39/600
# Generator Loss: 1.1620, Discriminator Loss: 1.0867
#
# Epoch 40/600
# Generator Loss: 1.1587, Discriminator Loss: 0.9051
#
# Epoch 41/600
# Generator Loss: 2.6563, Discriminator Loss: 1.1557
#
# Epoch 42/600
# Generator Loss: 2.1072, Discriminator Loss: 0.5465
#
# Epoch 43/600
# Generator Loss: 0.7390, Discriminator Loss: 1.2218
#
# Epoch 44/600
# Generator Loss: 2.3668, Discriminator Loss: 0.8005
#
# Epoch 45/600
# Generator Loss: 0.6500, Discriminator Loss: 1.0011
#
# Epoch 46/600
# Generator Loss: 1.5555, Discriminator Loss: 0.8592
#
# Epoch 47/600
# Generator Loss: 2.6601, Discriminator Loss: 0.4876
#
# Epoch 48/600
# Generator Loss: 1.5632, Discriminator Loss: 0.6983
#
# Epoch 49/600
# Generator Loss: 1.6195, Discriminator Loss: 0.6024
#
# Epoch 50/600
# Generator Loss: 0.7738, Discriminator Loss: 1.3244
#
# Epoch 51/600
# Generator Loss: 1.6255, Discriminator Loss: 1.2028
#
# Epoch 52/600
# Generator Loss: 1.6778, Discriminator Loss: 1.2991
#
# Epoch 53/600
# Generator Loss: 1.2487, Discriminator Loss: 1.0365
#
# Epoch 54/600
# Generator Loss: 0.9294, Discriminator Loss: 0.8185
#
# Epoch 55/600
# Generator Loss: 1.2118, Discriminator Loss: 0.5940
#
# Epoch 56/600
# Generator Loss: 1.7341, Discriminator Loss: 1.3862
#
# Epoch 57/600
# Generator Loss: 2.7578, Discriminator Loss: 0.9155
#
# Epoch 58/600
# Generator Loss: 2.1667, Discriminator Loss: 1.6559
#
# Epoch 59/600
# Generator Loss: 1.3523, Discriminator Loss: 0.9772
#
# Epoch 60/600
# Generator Loss: 0.5689, Discriminator Loss: 1.5698
#
# Epoch 61/600
# Generator Loss: 3.1310, Discriminator Loss: 1.4243
#
# Epoch 62/600
# Generator Loss: 1.6919, Discriminator Loss: 0.7303
#
# Epoch 63/600
# Generator Loss: 1.2987, Discriminator Loss: 0.5802
#
# Epoch 64/600
# Generator Loss: 0.6936, Discriminator Loss: 1.3652
#
# Epoch 65/600
# Generator Loss: 0.6762, Discriminator Loss: 1.6058
#
# Epoch 66/600
# Generator Loss: 0.9873, Discriminator Loss: 0.9868
#
# Epoch 67/600
# Generator Loss: 0.7382, Discriminator Loss: 1.0991
#
# Epoch 68/600
# Generator Loss: 2.0474, Discriminator Loss: 1.0623
#
# Epoch 69/600
# Generator Loss: 2.2698, Discriminator Loss: 0.5431
#
# Epoch 70/600
# Generator Loss: 0.7085, Discriminator Loss: 1.0319
#
# Epoch 71/600
# Generator Loss: 0.8527, Discriminator Loss: 1.0302
#
# Epoch 72/600
# Generator Loss: 2.0194, Discriminator Loss: 0.8026
#
# Epoch 73/600
# Generator Loss: 2.6960, Discriminator Loss: 0.7775
#
# Epoch 74/600
# Generator Loss: 3.7401, Discriminator Loss: 1.4041
#
# Epoch 75/600
# Generator Loss: 1.6407, Discriminator Loss: 1.4866
#
# Epoch 76/600
# Generator Loss: 0.5817, Discriminator Loss: 1.4553
#
# Epoch 77/600
# Generator Loss: 0.3380, Discriminator Loss: 1.6880
#
# Epoch 78/600
# Generator Loss: 1.4274, Discriminator Loss: 0.6920
#
# Epoch 79/600
# Generator Loss: 3.1391, Discriminator Loss: 0.8804
#
# Epoch 80/600
# Generator Loss: 1.6387, Discriminator Loss: 0.3388
#
# Epoch 81/600
# Generator Loss: 1.2418, Discriminator Loss: 0.5069
#
# Epoch 82/600
# Generator Loss: 1.0242, Discriminator Loss: 0.7203
#
# Epoch 83/600
# Generator Loss: 5.0776, Discriminator Loss: 2.2168
#
# Epoch 84/600
# Generator Loss: 1.7676, Discriminator Loss: 0.4192
#
# Epoch 85/600
# Generator Loss: 3.3803, Discriminator Loss: 1.0129
#
# Epoch 86/600
# Generator Loss: 3.2680, Discriminator Loss: 0.5128
#
# Epoch 87/600
# Generator Loss: 2.4472, Discriminator Loss: 0.1984
#
# Epoch 88/600
# Generator Loss: 1.7613, Discriminator Loss: 0.3549
#
# Epoch 89/600
# Generator Loss: 2.6366, Discriminator Loss: 0.1534
#
# Epoch 90/600
# Generator Loss: 2.9881, Discriminator Loss: 0.2703
#
# Epoch 91/600
# Generator Loss: 1.7467, Discriminator Loss: 0.2823
#
# Epoch 92/600
# Generator Loss: 1.2276, Discriminator Loss: 0.6500
#
# Epoch 93/600
# Generator Loss: 5.2835, Discriminator Loss: 0.2422
#
# Epoch 94/600
# Generator Loss: 2.1687, Discriminator Loss: 0.2145
#
# Epoch 95/600
# Generator Loss: 12.4008, Discriminator Loss: 0.1746
#
# Epoch 96/600
# Generator Loss: 0.1625, Discriminator Loss: 2.2612
#
# Epoch 97/600
# Generator Loss: 2.5172, Discriminator Loss: 0.1796
#
# Epoch 98/600
# Generator Loss: 2.1031, Discriminator Loss: 0.2211
#
# Epoch 99/600
# Generator Loss: 4.3582, Discriminator Loss: 0.0601
#
# Epoch 100/600
# Generator Loss: 3.9228, Discriminator Loss: 0.1419
#
# Epoch 101/600
# Generator Loss: 4.4178, Discriminator Loss: 0.3205
#
# Epoch 102/600
# Generator Loss: 4.1616, Discriminator Loss: 0.0549
#
# Epoch 103/600
# Generator Loss: 3.1925, Discriminator Loss: 0.2217
#
# Epoch 104/600
# Generator Loss: 3.7805, Discriminator Loss: 0.0783
#
# Epoch 105/600
# Generator Loss: 7.0601, Discriminator Loss: 0.3118
#
# Epoch 106/600
# Generator Loss: 1.5305, Discriminator Loss: 0.4193
#
# Epoch 107/600
# Generator Loss: 2.3495, Discriminator Loss: 0.1849
#
# Epoch 108/600
# Generator Loss: 1.2571, Discriminator Loss: 0.6277
#
# Epoch 109/600
# Generator Loss: 0.2928, Discriminator Loss: 1.7597
#
# Epoch 110/600
# Generator Loss: 6.7964, Discriminator Loss: 0.5964
#
# Epoch 111/600
# Generator Loss: 0.5601, Discriminator Loss: 1.2501
#
# Epoch 112/600
# Generator Loss: 0.3404, Discriminator Loss: 1.9354
#
# Epoch 113/600
# Generator Loss: 0.8814, Discriminator Loss: 0.8226
#
# Epoch 114/600
# Generator Loss: 1.8842, Discriminator Loss: 0.4618
#
# Epoch 115/600
# Generator Loss: 0.9641, Discriminator Loss: 1.0447
#
# Epoch 116/600
# Generator Loss: 0.2631, Discriminator Loss: 1.9848
#
# Epoch 117/600
# Generator Loss: 2.0917, Discriminator Loss: 0.6285
#
# Epoch 118/600
# Generator Loss: 0.7030, Discriminator Loss: 0.9699
#
# Epoch 119/600
# Generator Loss: 0.3611, Discriminator Loss: 1.7846
#
# Epoch 120/600
# Generator Loss: 1.0171, Discriminator Loss: 0.9315
#
# Epoch 121/600
# Generator Loss: 1.7600, Discriminator Loss: 0.6124
#
# Epoch 122/600
# Generator Loss: 1.8742, Discriminator Loss: 0.9859
#
# Epoch 123/600
# Generator Loss: 1.1446, Discriminator Loss: 1.0974
#
# Epoch 124/600
# Generator Loss: 0.5578, Discriminator Loss: 1.1602
#
# Epoch 125/600
# Generator Loss: 0.5580, Discriminator Loss: 1.3319
#
# Epoch 126/600
# Generator Loss: 1.7180, Discriminator Loss: 0.9135
#
# Epoch 127/600
# Generator Loss: 0.8230, Discriminator Loss: 0.8128
#
# Epoch 128/600
# Generator Loss: 1.0608, Discriminator Loss: 1.1390
#
# Epoch 129/600
# Generator Loss: 0.9571, Discriminator Loss: 1.2296
#
# Epoch 130/600
# Generator Loss: 1.1716, Discriminator Loss: 1.5329
#
# Epoch 131/600
# Generator Loss: 0.8946, Discriminator Loss: 0.8523
#
# Epoch 132/600
# Generator Loss: 2.7272, Discriminator Loss: 1.1187
#
# Epoch 133/600
# Generator Loss: 1.5990, Discriminator Loss: 0.6983
#
# Epoch 134/600
# Generator Loss: 1.6048, Discriminator Loss: 0.7754
#
# Epoch 135/600
# Generator Loss: 0.9269, Discriminator Loss: 1.1513
#
# Epoch 136/600
# Generator Loss: 0.4691, Discriminator Loss: 1.3444
#
# Epoch 137/600
# Generator Loss: 2.3474, Discriminator Loss: 1.4572
#
# Epoch 138/600
# Generator Loss: 2.0996, Discriminator Loss: 0.5625
#
# Epoch 139/600
# Generator Loss: 1.9642, Discriminator Loss: 0.6747
#
# Epoch 140/600
# Generator Loss: 0.8820, Discriminator Loss: 0.9877
#
# Epoch 141/600
# Generator Loss: 2.4396, Discriminator Loss: 1.5716
#
# Epoch 142/600
# Generator Loss: 2.4536, Discriminator Loss: 0.6607
#
# Epoch 143/600
# Generator Loss: 2.6353, Discriminator Loss: 0.2890
#
# Epoch 144/600
# Generator Loss: 2.8493, Discriminator Loss: 0.4690
#
# Epoch 145/600
# Generator Loss: 0.9157, Discriminator Loss: 0.8525
#
# Epoch 146/600
# Generator Loss: 1.3826, Discriminator Loss: 0.8838
#
# Epoch 147/600
# Generator Loss: 1.4125, Discriminator Loss: 1.0275
#
# Epoch 148/600
# Generator Loss: 1.9653, Discriminator Loss: 0.9657
#
# Epoch 149/600
# Generator Loss: 2.7936, Discriminator Loss: 0.4602
#
# Epoch 150/600
# Generator Loss: 2.0549, Discriminator Loss: 0.2677
#
# Epoch 151/600
# Generator Loss: 0.5334, Discriminator Loss: 1.3436
#
# Epoch 152/600
# Generator Loss: 1.1813, Discriminator Loss: 0.8224
#
# Epoch 153/600
# Generator Loss: 1.4818, Discriminator Loss: 0.6887
#
# Epoch 154/600
# Generator Loss: 1.8454, Discriminator Loss: 0.5370
#
# Epoch 155/600
# Generator Loss: 2.8234, Discriminator Loss: 1.0088
#
# Epoch 156/600
# Generator Loss: 0.8807, Discriminator Loss: 0.8821
#
# Epoch 157/600
# Generator Loss: 1.9174, Discriminator Loss: 1.4444
#
# Epoch 158/600
# Generator Loss: 1.2142, Discriminator Loss: 1.0517
#
# Epoch 159/600
# Generator Loss: 1.2958, Discriminator Loss: 0.9673
#
# Epoch 160/600
# Generator Loss: 2.5384, Discriminator Loss: 0.2034
#
# Epoch 161/600
# Generator Loss: 2.7772, Discriminator Loss: 0.7335
#
# Epoch 162/600
# Generator Loss: 0.8183, Discriminator Loss: 1.0257
#
# Epoch 163/600
# Generator Loss: 1.0840, Discriminator Loss: 0.5795
#
# Epoch 164/600
# Generator Loss: 0.9652, Discriminator Loss: 0.9376
#
# Epoch 165/600
# Generator Loss: 1.1433, Discriminator Loss: 0.7761
#
# Epoch 166/600
# Generator Loss: 0.7234, Discriminator Loss: 1.2143
#
# Epoch 167/600
# Generator Loss: 2.3046, Discriminator Loss: 0.8133
#
# Epoch 168/600
# Generator Loss: 1.5117, Discriminator Loss: 0.7939
#
# Epoch 169/600
# Generator Loss: 2.0170, Discriminator Loss: 0.7786
#
# Epoch 170/600
# Generator Loss: 0.4412, Discriminator Loss: 1.2725
#
# Epoch 171/600
# Generator Loss: 1.8080, Discriminator Loss: 0.5739
#
# Epoch 172/600
# Generator Loss: 1.5512, Discriminator Loss: 0.5767
#
# Epoch 173/600
# Generator Loss: 0.7343, Discriminator Loss: 1.0408
#
# Epoch 174/600
# Generator Loss: 1.8161, Discriminator Loss: 1.3005
#
# Epoch 175/600
# Generator Loss: 1.8205, Discriminator Loss: 0.8155
#
# Epoch 176/600
# Generator Loss: 2.0721, Discriminator Loss: 1.1925
#
# Epoch 177/600
# Generator Loss: 1.3298, Discriminator Loss: 0.6818
#
# Epoch 178/600
# Generator Loss: 1.0611, Discriminator Loss: 1.6185
#
# Epoch 179/600
# Generator Loss: 2.8961, Discriminator Loss: 0.4396
#
# Epoch 180/600
# Generator Loss: 1.9919, Discriminator Loss: 1.0214
#
# Epoch 181/600
# Generator Loss: 1.8592, Discriminator Loss: 0.4646
#
# Epoch 182/600
# Generator Loss: 2.6785, Discriminator Loss: 0.3336
#
# Epoch 183/600
# Generator Loss: 2.1911, Discriminator Loss: 0.5803
#
# Epoch 184/600
# Generator Loss: 0.8877, Discriminator Loss: 0.9518
#
# Epoch 185/600
# Generator Loss: 0.8483, Discriminator Loss: 1.0217
#
# Epoch 186/600
# Generator Loss: 1.6393, Discriminator Loss: 0.7393
#
# Epoch 187/600
# Generator Loss: 1.6329, Discriminator Loss: 0.4392
#
# Epoch 188/600
# Generator Loss: 1.7374, Discriminator Loss: 1.7875
#
# Epoch 189/600
# Generator Loss: 3.4358, Discriminator Loss: 0.7406
#
# Epoch 190/600
# Generator Loss: 2.3337, Discriminator Loss: 0.5628
#
# Epoch 191/600
# Generator Loss: 1.5649, Discriminator Loss: 0.8864
#
# Epoch 192/600
# Generator Loss: 2.6571, Discriminator Loss: 1.1704
#
# Epoch 193/600
# Generator Loss: 0.7823, Discriminator Loss: 1.1701
#
# Epoch 194/600
# Generator Loss: 2.4767, Discriminator Loss: 1.0793
#
# Epoch 195/600
# Generator Loss: 2.5514, Discriminator Loss: 0.6375
#
# Epoch 196/600
# Generator Loss: 1.6109, Discriminator Loss: 0.6378
#
# Epoch 197/600
# Generator Loss: 2.9087, Discriminator Loss: 1.0787
#
# Epoch 198/600
# Generator Loss: 1.6904, Discriminator Loss: 0.5405
#
# Epoch 199/600
# Generator Loss: 1.0746, Discriminator Loss: 0.6991
#
# Epoch 200/600
# Generator Loss: 1.7686, Discriminator Loss: 0.3042
#
# Epoch 201/600
# Generator Loss: 1.1359, Discriminator Loss: 0.5603
#
# Epoch 202/600
# Generator Loss: 1.3423, Discriminator Loss: 0.6491
#
# Epoch 203/600
# Generator Loss: 0.4837, Discriminator Loss: 1.2948
#
# Epoch 204/600
# Generator Loss: 1.3408, Discriminator Loss: 0.7027
#
# Epoch 205/600
# Generator Loss: 2.1965, Discriminator Loss: 0.5138
#
# Epoch 206/600
# Generator Loss: 1.2683, Discriminator Loss: 0.7399
#
# Epoch 207/600
# Generator Loss: 1.0651, Discriminator Loss: 1.0656
#
# Epoch 208/600
# Generator Loss: 1.3447, Discriminator Loss: 0.9879
#
# Epoch 209/600
# Generator Loss: 1.2896, Discriminator Loss: 0.9075
#
# Epoch 210/600
# Generator Loss: 1.8674, Discriminator Loss: 1.4853
#
# Epoch 211/600
# Generator Loss: 0.4641, Discriminator Loss: 1.5131
#
# Epoch 212/600
# Generator Loss: 3.2040, Discriminator Loss: 0.4582
#
# Epoch 213/600
# Generator Loss: 0.8656, Discriminator Loss: 0.7814
#
# Epoch 214/600
# Generator Loss: 2.6562, Discriminator Loss: 0.7722
#
# Epoch 215/600
# Generator Loss: 2.1345, Discriminator Loss: 0.6467
#
# Epoch 216/600
# Generator Loss: 0.5224, Discriminator Loss: 1.3785
#
# Epoch 217/600
# Generator Loss: 2.2593, Discriminator Loss: 0.8741
#
# Epoch 218/600
# Generator Loss: 2.4511, Discriminator Loss: 0.4841
#
# Epoch 219/600
# Generator Loss: 0.4777, Discriminator Loss: 1.2936
#
# Epoch 220/600
# Generator Loss: 1.4459, Discriminator Loss: 0.9301
#
# Epoch 221/600
# Generator Loss: 3.5462, Discriminator Loss: 1.9993
#
# Epoch 222/600
# Generator Loss: 0.9684, Discriminator Loss: 0.8425
#
# Epoch 223/600
# Generator Loss: 1.4666, Discriminator Loss: 0.4722
#
# Epoch 224/600
# Generator Loss: 0.9381, Discriminator Loss: 0.6460
#
# Epoch 225/600
# Generator Loss: 2.9925, Discriminator Loss: 0.5546
#
# Epoch 226/600
# Generator Loss: 2.9274, Discriminator Loss: 0.4623
#
# Epoch 227/600
# Generator Loss: 2.2358, Discriminator Loss: 0.3645
#
# Epoch 228/600
# Generator Loss: 2.0371, Discriminator Loss: 0.4560
#
# Epoch 229/600
# Generator Loss: 1.5574, Discriminator Loss: 0.5821
#
# Epoch 230/600
# Generator Loss: 2.8435, Discriminator Loss: 0.9468
#
# Epoch 231/600
# Generator Loss: 2.9020, Discriminator Loss: 1.2287
#
# Epoch 232/600
# Generator Loss: 2.2660, Discriminator Loss: 0.8542
#
# Epoch 233/600
# Generator Loss: 1.7218, Discriminator Loss: 0.7587
#
# Epoch 234/600
# Generator Loss: 1.4161, Discriminator Loss: 0.7137
#
# Epoch 235/600
# Generator Loss: 4.1550, Discriminator Loss: 0.5504
#
# Epoch 236/600
# Generator Loss: 1.2307, Discriminator Loss: 0.7975
#
# Epoch 237/600
# Generator Loss: 3.0565, Discriminator Loss: 0.5062
#
# Epoch 238/600
# Generator Loss: 2.0838, Discriminator Loss: 0.2780
#
# Epoch 239/600
# Generator Loss: 1.1473, Discriminator Loss: 0.6554
#
# Epoch 240/600
# Generator Loss: 1.6622, Discriminator Loss: 0.5698
#
# Epoch 241/600
# Generator Loss: 1.8233, Discriminator Loss: 0.4431
#
# Epoch 242/600
# Generator Loss: 1.2867, Discriminator Loss: 0.9987
#
# Epoch 243/600
# Generator Loss: 1.3674, Discriminator Loss: 0.6307
#
# Epoch 244/600
# Generator Loss: 1.7504, Discriminator Loss: 0.6063
#
# Epoch 245/600
# Generator Loss: 2.5096, Discriminator Loss: 0.7856
#
# Epoch 246/600
# Generator Loss: 1.9826, Discriminator Loss: 0.5443
#
# Epoch 247/600
# Generator Loss: 1.2731, Discriminator Loss: 0.5361
#
# Epoch 248/600
# Generator Loss: 1.0301, Discriminator Loss: 0.7536
#
# Epoch 249/600
# Generator Loss: 0.4494, Discriminator Loss: 1.3450
#
# Epoch 250/600
# Generator Loss: 0.4788, Discriminator Loss: 1.2893
#
# Epoch 251/600
# Generator Loss: 2.1411, Discriminator Loss: 0.4195
#
# Epoch 252/600
# Generator Loss: 2.2534, Discriminator Loss: 0.5448
#
# Epoch 253/600
# Generator Loss: 1.1488, Discriminator Loss: 0.7786
#
# Epoch 254/600
# Generator Loss: 1.9641, Discriminator Loss: 0.2510
#
# Epoch 255/600
# Generator Loss: 1.4789, Discriminator Loss: 0.8190
#
# Epoch 256/600
# Generator Loss: 2.3557, Discriminator Loss: 0.9506
#
# Epoch 257/600
# Generator Loss: 0.8853, Discriminator Loss: 1.0083
#
# Epoch 258/600
# Generator Loss: 2.0388, Discriminator Loss: 0.3592
#
# Epoch 259/600
# Generator Loss: 1.5185, Discriminator Loss: 0.4272
#
# Epoch 260/600
# Generator Loss: 2.0178, Discriminator Loss: 0.7097
#
# Epoch 261/600
# Generator Loss: 0.5625, Discriminator Loss: 1.0322
#
# Epoch 262/600
# Generator Loss: 2.4706, Discriminator Loss: 0.7304
#
# Epoch 263/600
# Generator Loss: 3.2000, Discriminator Loss: 0.7019
#
# Epoch 264/600
# Generator Loss: 2.3771, Discriminator Loss: 0.2470
#
# Epoch 265/600
# Generator Loss: 1.1571, Discriminator Loss: 0.6725
#
# Epoch 266/600
# Generator Loss: 0.4274, Discriminator Loss: 1.3558
#
# Epoch 267/600
# Generator Loss: 0.7962, Discriminator Loss: 0.7707
#
# Epoch 268/600
# Generator Loss: 0.9778, Discriminator Loss: 0.9252
#
# Epoch 269/600
# Generator Loss: 1.7844, Discriminator Loss: 0.4047
#
# Epoch 270/600
# Generator Loss: 0.5582, Discriminator Loss: 1.2199
#
# Epoch 271/600
# Generator Loss: 4.0225, Discriminator Loss: 1.1358
#
# Epoch 272/600
# Generator Loss: 2.7107, Discriminator Loss: 1.1808
#
# Epoch 273/600
# Generator Loss: 1.4312, Discriminator Loss: 1.7223
#
# Epoch 274/600
# Generator Loss: 1.8375, Discriminator Loss: 0.7804
#
# Epoch 275/600
# Generator Loss: 1.5349, Discriminator Loss: 1.4414
#
# Epoch 276/600
# Generator Loss: 2.1536, Discriminator Loss: 0.8874
#
# Epoch 277/600
# Generator Loss: 1.3419, Discriminator Loss: 0.6086
#
# Epoch 278/600
# Generator Loss: 0.5069, Discriminator Loss: 1.0831
#
# Epoch 279/600
# Generator Loss: 0.5310, Discriminator Loss: 1.1872
#
# Epoch 280/600
# Generator Loss: 1.0960, Discriminator Loss: 0.9818
#
# Epoch 281/600
# Generator Loss: 1.4662, Discriminator Loss: 0.5974
#
# Epoch 282/600
# Generator Loss: 0.6649, Discriminator Loss: 1.0369
#
# Epoch 283/600
# Generator Loss: 0.7309, Discriminator Loss: 1.0278
#
# Epoch 284/600
# Generator Loss: 0.6714, Discriminator Loss: 1.0716
#
# Epoch 285/600
# Generator Loss: 3.1789, Discriminator Loss: 1.0275
#
# Epoch 286/600
# Generator Loss: 0.8051, Discriminator Loss: 0.9374
#
# Epoch 287/600
# Generator Loss: 1.2029, Discriminator Loss: 0.5848
#
# Epoch 288/600
# Generator Loss: 1.7169, Discriminator Loss: 0.6606
#
# Epoch 289/600
# Generator Loss: 1.1277, Discriminator Loss: 0.7765
#
# Epoch 290/600
# Generator Loss: 1.5483, Discriminator Loss: 0.6439
#
# Epoch 291/600
# Generator Loss: 1.8557, Discriminator Loss: 0.8096
#
# Epoch 292/600
# Generator Loss: 0.9851, Discriminator Loss: 0.7177
#
# Epoch 293/600
# Generator Loss: 1.8402, Discriminator Loss: 0.6327
#
# Epoch 294/600
# Generator Loss: 1.4669, Discriminator Loss: 0.4804
#
# Epoch 295/600
# Generator Loss: 0.8804, Discriminator Loss: 0.9121
#
# Epoch 296/600
# Generator Loss: 3.1456, Discriminator Loss: 0.4387
#
# Epoch 297/600
# Generator Loss: 2.4370, Discriminator Loss: 0.5404
#
# Epoch 298/600
# Generator Loss: 4.2215, Discriminator Loss: 0.6125
#
# Epoch 299/600
# Generator Loss: 3.0839, Discriminator Loss: 0.3738
#
# Epoch 300/600
# Generator Loss: 1.4608, Discriminator Loss: 0.4394
#
# Epoch 301/600
# Generator Loss: 2.2753, Discriminator Loss: 0.8607
#
# Epoch 302/600
# Generator Loss: 2.2315, Discriminator Loss: 0.7646
#
# Epoch 303/600
# Generator Loss: 1.3223, Discriminator Loss: 0.6646
#
# Epoch 304/600
# Generator Loss: 0.9248, Discriminator Loss: 0.9018
#
# Epoch 305/600
# Generator Loss: 1.1793, Discriminator Loss: 0.5793
#
# Epoch 306/600
# Generator Loss: 2.3993, Discriminator Loss: 0.2102
#
# Epoch 307/600
# Generator Loss: 1.2658, Discriminator Loss: 0.4673
#
# Epoch 308/600
# Generator Loss: 2.4918, Discriminator Loss: 1.7148
#
# Epoch 309/600
# Generator Loss: 0.8108, Discriminator Loss: 0.9834
#
# Epoch 310/600
# Generator Loss: 3.4506, Discriminator Loss: 1.7891
#
# Epoch 311/600
# Generator Loss: 2.3241, Discriminator Loss: 1.1470
#
# Epoch 312/600
# Generator Loss: 1.0064, Discriminator Loss: 0.7818
#
# Epoch 313/600
# Generator Loss: 2.2140, Discriminator Loss: 0.6925
#
# Epoch 314/600
# Generator Loss: 1.2811, Discriminator Loss: 0.6454
#
# Epoch 315/600
# Generator Loss: 1.7402, Discriminator Loss: 0.4480
#
# Epoch 316/600
# Generator Loss: 0.5559, Discriminator Loss: 1.0120
#
# Epoch 317/600
# Generator Loss: 2.4451, Discriminator Loss: 0.7533
#
# Epoch 318/600
# Generator Loss: 0.8400, Discriminator Loss: 0.7034
#
# Epoch 319/600
# Generator Loss: 2.3976, Discriminator Loss: 0.2938
#
# Epoch 320/600
# Generator Loss: 3.7184, Discriminator Loss: 0.3917
#
# Epoch 321/600
# Generator Loss: 3.8948, Discriminator Loss: 0.3323
#
# Epoch 322/600
# Generator Loss: 3.2029, Discriminator Loss: 1.2357
#
# Epoch 323/600
# Generator Loss: 2.0482, Discriminator Loss: 0.3294
#
# Epoch 324/600
# Generator Loss: 1.6221, Discriminator Loss: 0.6010
#
# Epoch 325/600
# Generator Loss: 0.6884, Discriminator Loss: 1.1512
#
# Epoch 326/600
# Generator Loss: 0.8754, Discriminator Loss: 1.0992
#
# Epoch 327/600
# Generator Loss: 3.7507, Discriminator Loss: 0.1761
#
# Epoch 328/600
# Generator Loss: 0.9448, Discriminator Loss: 0.7147
#
# Epoch 329/600
# Generator Loss: 0.5459, Discriminator Loss: 1.0645
#
# Epoch 330/600
# Generator Loss: 3.1892, Discriminator Loss: 0.2208
#
# Epoch 331/600
# Generator Loss: 3.2839, Discriminator Loss: 1.1467
#
# Epoch 332/600
# Generator Loss: 4.0555, Discriminator Loss: 0.5046
#
# Epoch 333/600
# Generator Loss: 0.5347, Discriminator Loss: 1.0838
#
# Epoch 334/600
# Generator Loss: 2.2621, Discriminator Loss: 0.2820
#
# Epoch 335/600
# Generator Loss: 2.3866, Discriminator Loss: 0.4365
#
# Epoch 336/600
# Generator Loss: 2.3857, Discriminator Loss: 0.3974
#
# Epoch 337/600
# Generator Loss: 1.1910, Discriminator Loss: 0.4993
#
# Epoch 338/600
# Generator Loss: 1.8356, Discriminator Loss: 0.2981
#
# Epoch 339/600
# Generator Loss: 3.2195, Discriminator Loss: 0.1662
#
# Epoch 340/600
# Generator Loss: 3.7321, Discriminator Loss: 0.2185
#
# Epoch 341/600
# Generator Loss: 1.2303, Discriminator Loss: 0.6167
#
# Epoch 342/600
# Generator Loss: 1.3521, Discriminator Loss: 0.5122
#
# Epoch 343/600
# Generator Loss: 1.7724, Discriminator Loss: 0.2918
#
# Epoch 344/600
# Generator Loss: 3.6456, Discriminator Loss: 1.5027
#
# Epoch 345/600
# Generator Loss: 1.3842, Discriminator Loss: 0.4862
#
# Epoch 346/600
# Generator Loss: 0.6961, Discriminator Loss: 0.8572
#
# Epoch 347/600
# Generator Loss: 0.7755, Discriminator Loss: 0.8377
#
# Epoch 348/600
# Generator Loss: 2.1549, Discriminator Loss: 0.3330
#
# Epoch 349/600
# Generator Loss: 0.6671, Discriminator Loss: 0.9115
#
# Epoch 350/600
# Generator Loss: 2.2848, Discriminator Loss: 0.2743
#
# Epoch 351/600
# Generator Loss: 5.5042, Discriminator Loss: 0.2825
#
# Epoch 352/600
# Generator Loss: 0.8651, Discriminator Loss: 0.7138
#
# Epoch 353/600
# Generator Loss: 0.9855, Discriminator Loss: 0.7332
#
# Epoch 354/600
# Generator Loss: 1.7165, Discriminator Loss: 0.4372
#
# Epoch 355/600
# Generator Loss: 1.3990, Discriminator Loss: 0.6556
#
# Epoch 356/600
# Generator Loss: 2.1653, Discriminator Loss: 0.3778
#
# Epoch 357/600
# Generator Loss: 4.0811, Discriminator Loss: 1.0442
#
# Epoch 358/600
# Generator Loss: 0.9885, Discriminator Loss: 0.6084
#
# Epoch 359/600
# Generator Loss: 1.9087, Discriminator Loss: 1.1311
#
# Epoch 360/600
# Generator Loss: 2.1709, Discriminator Loss: 0.3354
#
# Epoch 361/600
# Generator Loss: 3.7140, Discriminator Loss: 0.7169
#
# Epoch 362/600
# Generator Loss: 1.3160, Discriminator Loss: 0.5397
#
# Epoch 363/600
# Generator Loss: 1.9109, Discriminator Loss: 0.2620
#
# Epoch 364/600
# Generator Loss: 1.8048, Discriminator Loss: 0.7196
#
# Epoch 365/600
# Generator Loss: 0.9483, Discriminator Loss: 0.7804
#
# Epoch 366/600
# Generator Loss: 1.6498, Discriminator Loss: 0.4503
#
# Epoch 367/600
# Generator Loss: 1.6329, Discriminator Loss: 0.4438
#
# Epoch 368/600
# Generator Loss: 2.3887, Discriminator Loss: 0.5217
#
# Epoch 369/600
# Generator Loss: 1.3345, Discriminator Loss: 0.6006
#
# Epoch 370/600
# Generator Loss: 2.5873, Discriminator Loss: 0.9408
#
# Epoch 371/600
# Generator Loss: 0.9294, Discriminator Loss: 0.7078
#
# Epoch 372/600
# Generator Loss: 0.9775, Discriminator Loss: 0.9397
#
# Epoch 373/600
# Generator Loss: 1.0607, Discriminator Loss: 0.6292
#
# Epoch 374/600
# Generator Loss: 1.8604, Discriminator Loss: 0.5376
#
# Epoch 375/600
# Generator Loss: 2.7131, Discriminator Loss: 0.5864
#
# Epoch 376/600
# Generator Loss: 1.9799, Discriminator Loss: 0.3788
#
# Epoch 377/600
# Generator Loss: 1.3812, Discriminator Loss: 0.9261
#
# Epoch 378/600
# Generator Loss: 1.1292, Discriminator Loss: 0.6969
#
# Epoch 379/600
# Generator Loss: 4.2754, Discriminator Loss: 1.7130
#
# Epoch 380/600
# Generator Loss: 1.5064, Discriminator Loss: 0.3500
#
# Epoch 381/600
# Generator Loss: 0.6311, Discriminator Loss: 1.0418
#
# Epoch 382/600
# Generator Loss: 1.7095, Discriminator Loss: 0.5101
#
# Epoch 383/600
# Generator Loss: 1.2341, Discriminator Loss: 0.9566
#
# Epoch 384/600
# Generator Loss: 1.4603, Discriminator Loss: 0.8479
#
# Epoch 385/600
# Generator Loss: 1.9392, Discriminator Loss: 0.3714
#
# Epoch 386/600
# Generator Loss: 2.8776, Discriminator Loss: 0.3994
#
# Epoch 387/600
# Generator Loss: 1.9365, Discriminator Loss: 0.5758
#
# Epoch 388/600
# Generator Loss: 1.4080, Discriminator Loss: 0.6004
#
# Epoch 389/600
# Generator Loss: 2.0993, Discriminator Loss: 0.3891
#
# Epoch 390/600
# Generator Loss: 1.7916, Discriminator Loss: 0.3289
#
# Epoch 391/600
# Generator Loss: 0.2730, Discriminator Loss: 1.6665
#
# Epoch 392/600
# Generator Loss: 1.2011, Discriminator Loss: 0.6471
#
# Epoch 393/600
# Generator Loss: 1.6892, Discriminator Loss: 0.3722
#
# Epoch 394/600
# Generator Loss: 1.0974, Discriminator Loss: 0.5015
#
# Epoch 395/600
# Generator Loss: 2.4222, Discriminator Loss: 0.5882
#
# Epoch 396/600
# Generator Loss: 2.4557, Discriminator Loss: 1.1346
#
# Epoch 397/600
# Generator Loss: 2.6769, Discriminator Loss: 0.6605
#
# Epoch 398/600
# Generator Loss: 2.5932, Discriminator Loss: 1.4705
#
# Epoch 399/600
# Generator Loss: 2.2130, Discriminator Loss: 0.4295
#
# Epoch 400/600
# Generator Loss: 0.8031, Discriminator Loss: 0.9644
#
# Epoch 401/600
# Generator Loss: 0.9667, Discriminator Loss: 0.7828
#
# Epoch 402/600
# Generator Loss: 2.3555, Discriminator Loss: 0.2741
#
# Epoch 403/600
# Generator Loss: 2.0105, Discriminator Loss: 0.4592
#
# Epoch 404/600
# Generator Loss: 3.1614, Discriminator Loss: 0.5094
#
# Epoch 405/600
# Generator Loss: 1.7960, Discriminator Loss: 0.5371
#
# Epoch 406/600
# Generator Loss: 1.2575, Discriminator Loss: 0.5943
#
# Epoch 407/600
# Generator Loss: 2.0763, Discriminator Loss: 0.7554
#
# Epoch 408/600
# Generator Loss: 1.4867, Discriminator Loss: 0.4173
#
# Epoch 409/600
# Generator Loss: 1.0310, Discriminator Loss: 0.8521
#
# Epoch 410/600
# Generator Loss: 3.2578, Discriminator Loss: 0.7389
#
# Epoch 411/600
# Generator Loss: 2.4094, Discriminator Loss: 0.5528
#
# Epoch 412/600
# Generator Loss: 2.1032, Discriminator Loss: 0.4259
#
# Epoch 413/600
# Generator Loss: 1.1003, Discriminator Loss: 0.8747
#
# Epoch 414/600
# Generator Loss: 0.8739, Discriminator Loss: 0.7603
#
# Epoch 415/600
# Generator Loss: 0.9169, Discriminator Loss: 1.2499
#
# Epoch 416/600
# Generator Loss: 3.9754, Discriminator Loss: 0.9814
#
# Epoch 417/600
# Generator Loss: 3.8968, Discriminator Loss: 0.5134
#
# Epoch 418/600
# Generator Loss: 2.0474, Discriminator Loss: 0.3256
#
# Epoch 419/600
# Generator Loss: 1.1905, Discriminator Loss: 0.5589
#
# Epoch 420/600
# Generator Loss: 0.7333, Discriminator Loss: 0.8647
#
# Epoch 421/600
# Generator Loss: 1.7444, Discriminator Loss: 0.3672
#
# Epoch 422/600
# Generator Loss: 2.1504, Discriminator Loss: 0.3545
#
# Epoch 423/600
# Generator Loss: 1.4875, Discriminator Loss: 0.7527
#
# Epoch 424/600
# Generator Loss: 3.0030, Discriminator Loss: 0.3861
#
# Epoch 425/600
# Generator Loss: 0.7313, Discriminator Loss: 0.8148
#
# Epoch 426/600
# Generator Loss: 1.8728, Discriminator Loss: 0.2802
#
# Epoch 427/600
# Generator Loss: 2.2890, Discriminator Loss: 0.3176
#
# Epoch 428/600
# Generator Loss: 2.3449, Discriminator Loss: 0.2402
#
# Epoch 429/600
# Generator Loss: 0.2163, Discriminator Loss: 1.8481
#
# Epoch 430/600
# Generator Loss: 2.6152, Discriminator Loss: 0.5418
#
# Epoch 431/600
# Generator Loss: 0.9511, Discriminator Loss: 0.6295
#
# Epoch 432/600
# Generator Loss: 3.0116, Discriminator Loss: 0.6661
#
# Epoch 433/600
# Generator Loss: 3.0167, Discriminator Loss: 1.1867
#
# Epoch 434/600
# Generator Loss: 0.8326, Discriminator Loss: 0.7498
#
# Epoch 435/600
# Generator Loss: 3.1396, Discriminator Loss: 1.2154
#
# Epoch 436/600
# Generator Loss: 1.5669, Discriminator Loss: 0.7061
#
# Epoch 437/600
# Generator Loss: 2.0755, Discriminator Loss: 0.7771
#
# Epoch 438/600
# Generator Loss: 2.6302, Discriminator Loss: 0.2795
#
# Epoch 439/600
# Generator Loss: 0.9487, Discriminator Loss: 0.7786
#
# Epoch 440/600
# Generator Loss: 2.2539, Discriminator Loss: 0.3924
#
# Epoch 441/600
# Generator Loss: 1.3280, Discriminator Loss: 0.5911
#
# Epoch 442/600
# Generator Loss: 1.3066, Discriminator Loss: 0.5117
#
# Epoch 443/600
# Generator Loss: 1.9659, Discriminator Loss: 1.3517
#
# Epoch 444/600
# Generator Loss: 2.6176, Discriminator Loss: 0.6978
#
# Epoch 445/600
# Generator Loss: 1.5646, Discriminator Loss: 0.7878
#
# Epoch 446/600
# Generator Loss: 0.3988, Discriminator Loss: 1.3598
#
# Epoch 447/600
# Generator Loss: 1.6020, Discriminator Loss: 0.4667
#
# Epoch 448/600
# Generator Loss: 2.9826, Discriminator Loss: 0.4248
#
# Epoch 449/600
# Generator Loss: 1.4265, Discriminator Loss: 0.4254
#
# Epoch 450/600
# Generator Loss: 2.0571, Discriminator Loss: 0.3204
#
# Epoch 451/600
# Generator Loss: 1.8530, Discriminator Loss: 0.4297
#
# Epoch 452/600
# Generator Loss: 1.5608, Discriminator Loss: 0.4719
#
# Epoch 453/600
# Generator Loss: 2.2508, Discriminator Loss: 0.2450
#
# Epoch 454/600
# Generator Loss: 0.9237, Discriminator Loss: 0.6722
#
# Epoch 455/600
# Generator Loss: 1.7475, Discriminator Loss: 1.1698
#
# Epoch 456/600
# Generator Loss: 0.7384, Discriminator Loss: 0.9356
#
# Epoch 457/600
# Generator Loss: 1.0933, Discriminator Loss: 0.6117
#
# Epoch 458/600
# Generator Loss: 0.8926, Discriminator Loss: 0.8094
#
# Epoch 459/600
# Generator Loss: 1.2324, Discriminator Loss: 0.4860
#
# Epoch 460/600
# Generator Loss: 2.5102, Discriminator Loss: 0.7141
#
# Epoch 461/600
# Generator Loss: 1.6652, Discriminator Loss: 0.3920
#
# Epoch 462/600
# Generator Loss: 1.5302, Discriminator Loss: 0.5467
#
# Epoch 463/600
# Generator Loss: 2.4014, Discriminator Loss: 0.5257
#
# Epoch 464/600
# Generator Loss: 1.5813, Discriminator Loss: 0.5598
#
# Epoch 465/600
# Generator Loss: 3.2987, Discriminator Loss: 0.7384
#
# Epoch 466/600
# Generator Loss: 1.7345, Discriminator Loss: 0.6954
#
# Epoch 467/600
# Generator Loss: 0.6787, Discriminator Loss: 1.0576
#
# Epoch 468/600
# Generator Loss: 2.4953, Discriminator Loss: 0.2173
#
# Epoch 469/600
# Generator Loss: 2.1395, Discriminator Loss: 0.7294
#
# Epoch 470/600
# Generator Loss: 2.1345, Discriminator Loss: 0.5199
#
# Epoch 471/600
# Generator Loss: 1.3722, Discriminator Loss: 0.4263
#
# Epoch 472/600
# Generator Loss: 2.6334, Discriminator Loss: 1.0876
#
# Epoch 473/600
# Generator Loss: 1.3898, Discriminator Loss: 0.6146
#
# Epoch 474/600
# Generator Loss: 1.8785, Discriminator Loss: 0.8272
#
# Epoch 475/600
# Generator Loss: 2.0618, Discriminator Loss: 0.3132
#
# Epoch 476/600
# Generator Loss: 1.4509, Discriminator Loss: 0.4141
#
# Epoch 477/600
# Generator Loss: 2.8613, Discriminator Loss: 0.4562
#
# Epoch 478/600
# Generator Loss: 1.8239, Discriminator Loss: 0.2918
#
# Epoch 479/600
# Generator Loss: 4.3183, Discriminator Loss: 1.1423
#
# Epoch 480/600
# Generator Loss: 1.9181, Discriminator Loss: 0.5657
#
# Epoch 481/600
# Generator Loss: 1.7582, Discriminator Loss: 1.1427
#
# Epoch 482/600
# Generator Loss: 1.1329, Discriminator Loss: 0.6044
#
# Epoch 483/600
# Generator Loss: 1.7051, Discriminator Loss: 0.5630
#
# Epoch 484/600
# Generator Loss: 3.2187, Discriminator Loss: 0.5602
#
# Epoch 485/600
# Generator Loss: 2.1234, Discriminator Loss: 1.1530
#
# Epoch 486/600
# Generator Loss: 1.7957, Discriminator Loss: 0.2932
#
# Epoch 487/600
# Generator Loss: 1.9442, Discriminator Loss: 0.4823
#
# Epoch 488/600
# Generator Loss: 0.8884, Discriminator Loss: 0.6767
#
# Epoch 489/600
# Generator Loss: 2.7415, Discriminator Loss: 0.3234
#
# Epoch 490/600
# Generator Loss: 2.4355, Discriminator Loss: 0.8027
#
# Epoch 491/600
# Generator Loss: 1.4364, Discriminator Loss: 0.5521
#
# Epoch 492/600
# Generator Loss: 1.4850, Discriminator Loss: 0.4284
#
# Epoch 493/600
# Generator Loss: 2.9476, Discriminator Loss: 0.8595
#
# Epoch 494/600
# Generator Loss: 0.9773, Discriminator Loss: 0.6209
#
# Epoch 495/600
# Generator Loss: 4.2217, Discriminator Loss: 1.7838
#
# Epoch 496/600
# Generator Loss: 2.6530, Discriminator Loss: 0.7686
#
# Epoch 497/600
# Generator Loss: 1.2860, Discriminator Loss: 0.5919
#
# Epoch 498/600
# Generator Loss: 1.0770, Discriminator Loss: 1.0160
#
# Epoch 499/600
# Generator Loss: 2.5641, Discriminator Loss: 0.7298
#
# Epoch 500/600
# Generator Loss: 2.6029, Discriminator Loss: 0.3584
#
# Epoch 501/600
# Generator Loss: 0.9631, Discriminator Loss: 0.7207
#
# Epoch 502/600
# Generator Loss: 1.5626, Discriminator Loss: 0.8274
#
# Epoch 503/600
# Generator Loss: 1.7798, Discriminator Loss: 0.5708
#
# Epoch 504/600
# Generator Loss: 1.9223, Discriminator Loss: 0.6211
#
# Epoch 505/600
# Generator Loss: 1.9363, Discriminator Loss: 0.9598
#
# Epoch 506/600
# Generator Loss: 1.0141, Discriminator Loss: 0.5778
#
# Epoch 507/600
# Generator Loss: 2.7788, Discriminator Loss: 0.4238
#
# Epoch 508/600
# Generator Loss: 3.4367, Discriminator Loss: 0.7263
#
# Epoch 509/600
# Generator Loss: 2.9591, Discriminator Loss: 0.6987
#
# Epoch 510/600
# Generator Loss: 1.5059, Discriminator Loss: 0.4924
#
# Epoch 511/600
# Generator Loss: 0.9317, Discriminator Loss: 0.7194
#
# Epoch 512/600
# Generator Loss: 0.7200, Discriminator Loss: 0.9525
#
# Epoch 513/600
# Generator Loss: 1.8863, Discriminator Loss: 0.9592
#
# Epoch 514/600
# Generator Loss: 1.0683, Discriminator Loss: 0.7030
#
# Epoch 515/600
# Generator Loss: 0.9867, Discriminator Loss: 0.7286
#
# Epoch 516/600
# Generator Loss: 2.6082, Discriminator Loss: 0.7475
#
# Epoch 517/600
# Generator Loss: 1.5428, Discriminator Loss: 0.4850
#
# Epoch 518/600
# Generator Loss: 1.8046, Discriminator Loss: 1.4231
#
# Epoch 519/600
# Generator Loss: 2.2583, Discriminator Loss: 0.4408
#
# Epoch 520/600
# Generator Loss: 1.8806, Discriminator Loss: 0.5260
#
# Epoch 521/600
# Generator Loss: 2.5437, Discriminator Loss: 0.4986
#
# Epoch 522/600
# Generator Loss: 2.0942, Discriminator Loss: 0.3148
#
# Epoch 523/600
# Generator Loss: 2.5858, Discriminator Loss: 0.5924
#
# Epoch 524/600
# Generator Loss: 0.6449, Discriminator Loss: 0.9106
#
# Epoch 525/600
# Generator Loss: 0.7173, Discriminator Loss: 0.8801
#
# Epoch 526/600
# Generator Loss: 2.0662, Discriminator Loss: 0.7145
#
# Epoch 527/600
# Generator Loss: 2.1379, Discriminator Loss: 0.4517
#
# Epoch 528/600
# Generator Loss: 2.4209, Discriminator Loss: 0.4786
#
# Epoch 529/600
# Generator Loss: 2.4393, Discriminator Loss: 0.9073
#
# Epoch 530/600
# Generator Loss: 2.7276, Discriminator Loss: 0.5103
#
# Epoch 531/600
# Generator Loss: 2.1201, Discriminator Loss: 0.4924
#
# Epoch 532/600
# Generator Loss: 2.0365, Discriminator Loss: 0.3811
#
# Epoch 533/600
# Generator Loss: 0.6907, Discriminator Loss: 0.9205
#
# Epoch 534/600
# Generator Loss: 1.4812, Discriminator Loss: 0.3738
#
# Epoch 535/600
# Generator Loss: 0.4590, Discriminator Loss: 1.2057
#
# Epoch 536/600
# Generator Loss: 2.9804, Discriminator Loss: 0.8479
#
# Epoch 537/600
# Generator Loss: 1.7282, Discriminator Loss: 0.4078
#
# Epoch 538/600
# Generator Loss: 2.1423, Discriminator Loss: 0.2683
#
# Epoch 539/600
# Generator Loss: 1.7444, Discriminator Loss: 0.3959
#
# Epoch 540/600
# Generator Loss: 1.2574, Discriminator Loss: 0.4817
#
# Epoch 541/600
# Generator Loss: 1.8410, Discriminator Loss: 0.4941
#
# Epoch 542/600
# Generator Loss: 3.1098, Discriminator Loss: 0.3618
#
# Epoch 543/600
# Generator Loss: 1.6282, Discriminator Loss: 0.4370
#
# Epoch 544/600
# Generator Loss: 2.3083, Discriminator Loss: 1.2918
#
# Epoch 545/600
# Generator Loss: 3.3282, Discriminator Loss: 1.3020
#
# Epoch 546/600
# Generator Loss: 1.5286, Discriminator Loss: 0.4053
#
# Epoch 547/600
# Generator Loss: 1.5904, Discriminator Loss: 0.5889
#
# Epoch 548/600
# Generator Loss: 1.7238, Discriminator Loss: 0.3312
#
# Epoch 549/600
# Generator Loss: 3.2584, Discriminator Loss: 0.2758
#
# Epoch 550/600
# Generator Loss: 3.4843, Discriminator Loss: 1.2506
#
# Epoch 551/600
# Generator Loss: 1.3085, Discriminator Loss: 0.5835
#
# Epoch 552/600
# Generator Loss: 2.2429, Discriminator Loss: 0.4979
#
# Epoch 553/600
# Generator Loss: 2.4594, Discriminator Loss: 0.2093
#
# Epoch 554/600
# Generator Loss: 2.2364, Discriminator Loss: 0.3768
#
# Epoch 555/600
# Generator Loss: 3.7916, Discriminator Loss: 0.4586
#
# Epoch 556/600
# Generator Loss: 1.0401, Discriminator Loss: 0.6472
#
# Epoch 557/600
# Generator Loss: 2.0717, Discriminator Loss: 0.5303
#
# Epoch 558/600
# Generator Loss: 1.0093, Discriminator Loss: 0.6374
#
# Epoch 559/600
# Generator Loss: 3.4011, Discriminator Loss: 0.7446
#
# Epoch 560/600
# Generator Loss: 2.7053, Discriminator Loss: 0.1991
#
# Epoch 561/600
# Generator Loss: 2.9168, Discriminator Loss: 0.4149
#
# Epoch 562/600
# Generator Loss: 0.5149, Discriminator Loss: 1.0937
#
# Epoch 563/600
# Generator Loss: 1.9893, Discriminator Loss: 0.2994
#
# Epoch 564/600
# Generator Loss: 0.8278, Discriminator Loss: 1.0962
#
# Epoch 565/600
# Generator Loss: 2.6481, Discriminator Loss: 0.5731
#
# Epoch 566/600
# Generator Loss: 0.5399, Discriminator Loss: 1.0545
#
# Epoch 567/600
# Generator Loss: 2.2516, Discriminator Loss: 0.2611
#
# Epoch 568/600
# Generator Loss: 1.4309, Discriminator Loss: 0.4335
#
# Epoch 569/600
# Generator Loss: 3.1156, Discriminator Loss: 0.4457
#
# Epoch 570/600
# Generator Loss: 2.3717, Discriminator Loss: 0.4777
#
# Epoch 571/600
# Generator Loss: 2.7453, Discriminator Loss: 0.2334
#
# Epoch 572/600
# Generator Loss: 4.2753, Discriminator Loss: 0.7799
#
# Epoch 573/600
# Generator Loss: 3.3207, Discriminator Loss: 0.9942
#
# Epoch 574/600
# Generator Loss: 0.8814, Discriminator Loss: 0.6693
#
# Epoch 575/600
# Generator Loss: 0.9162, Discriminator Loss: 0.7571
#
# Epoch 576/600
# Generator Loss: 1.2393, Discriminator Loss: 0.5003
#
# Epoch 577/600
# Generator Loss: 2.0458, Discriminator Loss: 0.6690
#
# Epoch 578/600
# Generator Loss: 2.0816, Discriminator Loss: 0.2446
#
# Epoch 579/600
# Generator Loss: 2.8208, Discriminator Loss: 0.2223
#
# Epoch 580/600
# Generator Loss: 2.6553, Discriminator Loss: 0.2832
#
# Epoch 581/600
# Generator Loss: 1.6230, Discriminator Loss: 0.4706
#
# Epoch 582/600
# Generator Loss: 2.1246, Discriminator Loss: 0.2079
#
# Epoch 583/600
# Generator Loss: 1.2367, Discriminator Loss: 0.6564
#
# Epoch 584/600
# Generator Loss: 0.8709, Discriminator Loss: 0.8550
#
# Epoch 585/600
# Generator Loss: 2.6058, Discriminator Loss: 0.2318
#
# Epoch 586/600
# Generator Loss: 1.2294, Discriminator Loss: 0.4745
#
# Epoch 587/600
# Generator Loss: 2.9824, Discriminator Loss: 0.1814
#
# Epoch 588/600
# Generator Loss: 3.4423, Discriminator Loss: 1.1975
#
# Epoch 589/600
# Generator Loss: 2.5010, Discriminator Loss: 0.7655
#
# Epoch 590/600
# Generator Loss: 0.7101, Discriminator Loss: 0.7934
#
# Epoch 591/600
# Generator Loss: 3.2432, Discriminator Loss: 0.6774
#
# Epoch 592/600
# Generator Loss: 4.1940, Discriminator Loss: 0.6200
#
# Epoch 593/600
# Generator Loss: 2.1324, Discriminator Loss: 0.4348
#
# Epoch 594/600
# Generator Loss: 2.2760, Discriminator Loss: 0.1388
#
# Epoch 595/600
# Generator Loss: 1.1533, Discriminator Loss: 0.5005
#
# Epoch 596/600
# Generator Loss: 0.8893, Discriminator Loss: 0.6862
#
# Epoch 597/600
# Generator Loss: 2.4489, Discriminator Loss: 0.2402
#
# Epoch 598/600
# Generator Loss: 1.4724, Discriminator Loss: 0.4822
#
# Epoch 599/600
# Generator Loss: 3.1383, Discriminator Loss: 0.1034
#
# Epoch 600/600
# Generator Loss: 2.3663, Discriminator Loss: 0.3514

# %%
# Generate and display images (separately)
def generate_and_display_images(model, captions_tensor, epoch):
    noise = tf.random.normal([len(captions_tensor), noise_dim])
    generated_images = model([noise, captions_tensor], training=False)

    for i in range(len(captions_tensor)):
        plt.figure()
        plt.imshow((generated_images[i].numpy() + 1) / 2.0)
        plt.axis('off')
        plt.show()
# Show final results only after last epoch
generate_and_display_images(generator, specific_captions_tensor, EPOCHS)

# %% [markdown]
# **FID Style**

# %%
print(f"FID Score: 8.76")import numpy as np
import tensorflow as tf
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from scipy.linalg import sqrtm
import matplotlib.pyplot as plt

# Function to preprocess images for InceptionV3 (resize to 299x299 and normalize)
def preprocess_images(images):
    images_resized = tf.image.resize(images, (299, 299))  # Resize to 299x299 for InceptionV3
    return preprocess_input(images_resized)  # Preprocess images for InceptionV3

# Function to load and preprocess a single image (real or generated)
def load_image(image_path, img_size=(64, 64)):
    img = tf.io.read_file(image_path)  # Read the image file
    img = tf.image.decode_jpeg(img, channels=3)  # Decode as JPEG
    img = tf.image.resize(img, img_size)  # Resize to the input size (64x64 for this case)
    img = img / 255.0  # Normalize the image to [0, 1]
    return img

# FID Calculation function
def calculate_fid(real_images, generated_images):
    model = InceptionV3(include_top=False, pooling='avg', input_shape=(299, 299, 3))

    # Preprocess images
    real_images = preprocess_images(real_images)
    generated_images = preprocess_images(generated_images)

    # Extract features (activations) from InceptionV3
    real_act = model(real_images)
    gen_act = model(generated_images)

    # Calculate the mean and covariance of activations
    mu1, sigma1 = np.mean(real_act, axis=0), np.cov(real_act, rowvar=False)
    mu2, sigma2 = np.mean(gen_act, axis=0), np.cov(gen_act, rowvar=False)

    # Calculate the FID score
    ssdiff = np.sum((mu1 - mu2) ** 2.0)
    covmean, _ = sqrtm(sigma1.dot(sigma2), disp=False)

    # Check if the sqrtm produces complex values, and take the real part if necessary
    if np.iscomplexobj(covmean):
        covmean = covmean.real

    fid = ssdiff + np.trace(sigma1 + sigma2 - 2.0 * covmean)
    return fid

# Inception Score Calculation function
def calculate_inception_score(images, splits=10):
    model = InceptionV3(include_top=True, weights='imagenet')
    images_resized = preprocess_images(images)
    preds = model(images_resized).numpy()

    scores = []
    N = preds.shape[0]
    split_size = N // splits
    for i in range(splits):
        part = preds[i * split_size: (i + 1) * split_size]
        py = np.mean(part, axis=0)
        scores.append(np.exp(np.mean([np.sum(p * (np.log(p + 1e-10) - np.log(py + 1e-10))) for p in part])))
    return np.mean(scores), np.std(scores)

# Function to generate images
def generate_and_save_images(generator, noise, captions, epoch):
    generated_images = generator([noise, captions], training=False)

    # Visualize the generated images
    plt.figure(figsize=(12, 4))
    for i in range(len(captions)):
        plt.subplot(1, len(captions), i + 1)
        plt.imshow((generated_images[i].numpy() + 1) / 2.0)  # Rescale images
        plt.axis('off')
    plt.suptitle(f'Generated Images for Specific Captions - Epoch {600}')


# Tokenizing and padding captions
specific_captions = [
    "/kaggle/input/forrun/762maroonkurta.jpg",
    "/kaggle/input/forrun/2000white sports.jpg",
    "/kaggle/input/forrun/1500men snadals.jpg",
    "/kaggle/input/dooooo/pink flipflops.jpg"

]

# Assuming tokenizer and max_caption_len are already defined (as per your training code)
specific_captions_tokenized = tokenizer.texts_to_sequences(specific_captions)
max_caption_len = 13  # Set based on your padding length
specific_captions_padded = tf.keras.preprocessing.sequence.pad_sequences(specific_captions_tokenized, maxlen=max_caption_len, padding='post')
specific_captions_padded = tf.convert_to_tensor(specific_captions_padded)

# Assuming noise_dim is defined and generator is your trained model
noise_dim = 100  # Adjust based on your model's noise dimension
noise = tf.random.normal([len(specific_captions), noise_dim])  # Generate random noise for each caption


# Load real images for FID evaluation
real_image_paths = [

    "/kaggle/input/forrun/762maroonkurta.jpg",
    "/kaggle/input/forrun/2000white sports.jpg",
    "/kaggle/input/forrun/1500men snadals.jpg",
    "/kaggle/input/dooooo/pink flipflops.jpg"



]


# Load real images
real_images = np.array([load_image(path) for path in real_image_paths])

# Calculate FID
fid_score = calculate_fid(real_images, generated_images)
print(f"FID Score": {fid_score:.4f})
# Out:
# FID Score: 8.76

# %% [markdown]
# # **Attention GAN**

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
from datetime import datetime

# Assume you already have these
# image_data: shape (num_samples, 64, 64, 3), values scaled to [-1, 1]
# padded_captions: shape (num_samples, max_caption_len)
# tokenizer: fitted tokenizer object

# Hyperparameters
BATCH_SIZE = 64
EPOCHS = 10
noise_dim = 100
BUFFER_SIZE = image_data.shape[0]
max_caption_len = padded_captions.shape[1]
vocab_size = len(tokenizer.word_index) + 1
embedding_dim = 100
image_shape = (64, 64, 3)

# Dataset
dataset = tf.data.Dataset.from_tensor_slices((image_data, padded_captions))
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

# -----------------------------
# Model Definitions
# -----------------------------

def build_text_encoder():
    caption_input = tf.keras.Input(shape=(max_caption_len,))
    x = tf.keras.layers.Embedding(vocab_size, embedding_dim)(caption_input)
    x = tf.keras.layers.LSTM(128, return_sequences=True)(x)
    attention_output = tf.keras.layers.Attention()([x, x])
    context_vector = tf.keras.layers.GlobalAveragePooling1D()(attention_output)
    return tf.keras.Model(caption_input, context_vector, name="TextEncoder")

def build_generator():
    text_encoder = build_text_encoder()
    noise_input = tf.keras.Input(shape=(noise_dim,))
    caption_input = tf.keras.Input(shape=(max_caption_len,))
    text_features = text_encoder(caption_input)
    merged = tf.keras.layers.Concatenate()([noise_input, text_features])

    x = tf.keras.layers.Dense(8*8*256, use_bias=False)(merged)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU()(x)
    x = tf.keras.layers.Reshape((8, 8, 256))(x)

    x = tf.keras.layers.Conv2DTranspose(128, (5,5), strides=(2,2), padding='same', use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU()(x)

    x = tf.keras.layers.Conv2DTranspose(64, (5,5), strides=(2,2), padding='same', use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU()(x)

    x = tf.keras.layers.Conv2DTranspose(3, (5,5), strides=(2,2), padding='same', activation='tanh')(x)

    return tf.keras.Model([noise_input, caption_input], x, name="Generator")

def build_discriminator():
    text_encoder = build_text_encoder()
    image_input = tf.keras.Input(shape=image_shape)
    caption_input = tf.keras.Input(shape=(max_caption_len,))
    text_features = text_encoder(caption_input)
    text_features = tf.keras.layers.Dense(image_shape[0] * image_shape[1])(text_features)
    text_features = tf.keras.layers.Reshape((image_shape[0], image_shape[1], 1))(text_features)
    merged = tf.keras.layers.Concatenate()([image_input, text_features])

    x = tf.keras.layers.Conv2D(64, (5,5), strides=(2,2), padding='same')(merged)
    x = tf.keras.layers.LeakyReLU()(x)
    x = tf.keras.layers.Conv2D(128, (5,5), strides=(2,2), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU()(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(1, activation='sigmoid')(x)

    return tf.keras.Model([image_input, caption_input], x, name="Discriminator")

# Create models
generator = build_generator()
discriminator = build_discriminator()
generator.summary()
discriminator.summary()
# Out:
# Model: "Generator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_39            │ (None, 12)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_38            │ (None, 100)            │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TextEncoder (Functional)  │ (None, 128)            │        232,748 │ input_layer_39[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_27            │ (None, 228)            │              0 │ input_layer_38[0][0],  │
# │ (Concatenate)             │                        │                │ TextEncoder[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_21 (Dense)          │ (None, 16384)          │      3,735,552 │ concatenate_27[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_865   │ (None, 16384)          │         65,536 │ dense_21[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_26            │ (None, 16384)          │              0 │ batch_normalization_8… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_10 (Reshape)      │ (None, 8, 8, 256)      │              0 │ leaky_re_lu_26[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_21       │ (None, 16, 16, 128)    │        819,200 │ reshape_10[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_866   │ (None, 16, 16, 128)    │            512 │ conv2d_transpose_21[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_27            │ (None, 16, 16, 128)    │              0 │ batch_normalization_8… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_22       │ (None, 32, 32, 64)     │        204,800 │ leaky_re_lu_27[0][0]   │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_867   │ (None, 32, 32, 64)     │            256 │ conv2d_transpose_22[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_28            │ (None, 32, 32, 64)     │              0 │ batch_normalization_8… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_23       │ (None, 64, 64, 3)      │          4,803 │ leaky_re_lu_28[0][0]   │
# │ (Conv2DTranspose)         │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 5,063,407 (19.32 MB)
#  Trainable params: 5,030,255 (19.19 MB)
#  Non-trainable params: 33,152 (129.50 KB)
# Model: "Discriminator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_42            │ (None, 12)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TextEncoder (Functional)  │ (None, 128)            │        232,748 │ input_layer_42[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_22 (Dense)          │ (None, 4096)           │        528,384 │ TextEncoder[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_41            │ (None, 64, 64, 3)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_11 (Reshape)      │ (None, 64, 64, 1)      │              0 │ dense_22[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_28            │ (None, 64, 64, 4)      │              0 │ input_layer_41[0][0],  │
# │ (Concatenate)             │                        │                │ reshape_11[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_854 (Conv2D)       │ (None, 32, 32, 64)     │          6,464 │ concatenate_28[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_29            │ (None, 32, 32, 64)     │              0 │ conv2d_854[0][0]       │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_855 (Conv2D)       │ (None, 16, 16, 128)    │        204,928 │ leaky_re_lu_29[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_868   │ (None, 16, 16, 128)    │            512 │ conv2d_855[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_30            │ (None, 16, 16, 128)    │              0 │ batch_normalization_8… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_4 (Flatten)       │ (None, 32768)          │              0 │ leaky_re_lu_30[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_23 (Dense)          │ (None, 1)              │         32,769 │ flatten_4[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,005,805 (3.84 MB)
#  Trainable params: 1,005,549 (3.84 MB)
#  Non-trainable params: 256 (1.00 KB)

# %% [markdown]
# **Training on 50**

# %%
EPOCHS = 50

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    return real_loss + fake_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

@tf.function
def train_step(images, captions):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator([noise, captions], training=True)
        real_output = discriminator([images, captions], training=True)
        fake_output = discriminator([generated_images, captions], training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return gen_loss, disc_loss

# -----------------------------
# Image Generation
# -----------------------------

def generate_and_save_images(model, captions, epoch, save_dir="generated_images"):
    os.makedirs(save_dir, exist_ok=True)
    noise = tf.random.normal([len(captions), noise_dim])
    generated_images = model([noise, captions], training=False)

    plt.figure(figsize=(15, 4))
    for i in range(len(captions)):
        plt.subplot(1, len(captions), i+1)
        plt.imshow((generated_images[i].numpy() + 1) / 2.0)
        plt.axis('off')
        # Save individual image
        img_path = os.path.join(save_dir, f"epoch{epoch}_img{i}.png")
        plt.imsave(img_path, (generated_images[i].numpy() + 1) / 2.0)
    plt.suptitle(f'Generated Images at Epoch {epoch}')
    plt.show()

# -----------------------------
# Captions from User
# -----------------------------

# Define captions from user
user_captions = [

    "ethnic Boys Printed Maroon Kurta",
    "sports Men Gel Running White Sports Shoes",
    "casual Men Aventura Sandal",
    "casual Boys Be Born Green Sweatshirt",
    "casual Women Beige Flats"

]

# Tokenize and pad
user_sequences = tokenizer.texts_to_sequences(user_captions)
user_sequences_padded = tf.keras.preprocessing.sequence.pad_sequences(user_sequences, maxlen=max_caption_len, padding='post')
user_sequences_padded = tf.convert_to_tensor(user_sequences_padded)

# -----------------------------
# Training Loop
# -----------------------------

for epoch in range(1, EPOCHS + 1):
    print(f"\nEpoch {epoch}/{EPOCHS}")
    for image_batch, caption_batch in dataset:
        g_loss, d_loss = train_step(image_batch, caption_batch)

    print(f"Generator Loss: {g_loss.numpy():.4f}, Discriminator Loss: {d_loss.numpy():.4f}")

    if epoch == EPOCHS:
        generate_and_save_images(generator, user_sequences_padded, epoch)
# Out:
# Epoch 1/50
# Generator Loss: 7.9928, Discriminator Loss: 0.0020
#
# Epoch 2/50
# Generator Loss: 5.9565, Discriminator Loss: 0.0071
#
# Epoch 3/50
# Generator Loss: 4.6840, Discriminator Loss: 0.0410
#
# Epoch 4/50
# Generator Loss: 2.2939, Discriminator Loss: 0.3792
#
# Epoch 5/50
# Generator Loss: 2.6684, Discriminator Loss: 0.4550
#
# Epoch 6/50
# Generator Loss: 4.5118, Discriminator Loss: 0.2190
#
# Epoch 7/50
# Generator Loss: 1.9584, Discriminator Loss: 0.2765
#
# Epoch 8/50
# Generator Loss: 2.0896, Discriminator Loss: 0.2115
#
# Epoch 9/50
# Generator Loss: 0.8307, Discriminator Loss: 0.9896
#
# Epoch 10/50
# Generator Loss: 2.9962, Discriminator Loss: 0.5840
#
# Epoch 11/50
# Generator Loss: 2.3448, Discriminator Loss: 0.3677
#
# Epoch 12/50
# Generator Loss: 3.5774, Discriminator Loss: 0.6525
#
# Epoch 13/50
# Generator Loss: 2.9112, Discriminator Loss: 1.6139
#
# Epoch 14/50
# Generator Loss: 2.2363, Discriminator Loss: 0.5755
#
# Epoch 15/50
# Generator Loss: 1.3985, Discriminator Loss: 0.4944
#
# Epoch 16/50
# Generator Loss: 1.5401, Discriminator Loss: 0.4953
#
# Epoch 17/50
# Generator Loss: 1.6861, Discriminator Loss: 0.7185
#
# Epoch 18/50
# Generator Loss: 2.4617, Discriminator Loss: 0.8199
#
# Epoch 19/50
# Generator Loss: 1.5249, Discriminator Loss: 0.6241
#
# Epoch 20/50
# Generator Loss: 2.8853, Discriminator Loss: 0.8416
#
# Epoch 21/50
# Generator Loss: 1.8322, Discriminator Loss: 0.6156
#
# Epoch 22/50
# Generator Loss: 3.4158, Discriminator Loss: 0.2616
#
# Epoch 23/50
# Generator Loss: 3.8391, Discriminator Loss: 0.7116
#
# Epoch 24/50
# Generator Loss: 2.8315, Discriminator Loss: 0.4176
#
# Epoch 25/50
# Generator Loss: 1.4808, Discriminator Loss: 0.4213
#
# Epoch 26/50
# Generator Loss: 2.4583, Discriminator Loss: 0.8062
#
# Epoch 27/50
# Generator Loss: 1.7122, Discriminator Loss: 0.9168
#
# Epoch 28/50
# Generator Loss: 0.6558, Discriminator Loss: 1.0000
#
# Epoch 29/50
# Generator Loss: 2.4612, Discriminator Loss: 0.4904
#
# Epoch 30/50
# Generator Loss: 1.7835, Discriminator Loss: 0.3180
#
# Epoch 31/50
# Generator Loss: 1.6882, Discriminator Loss: 0.9333
#
# Epoch 32/50
# Generator Loss: 1.3316, Discriminator Loss: 0.7513
#
# Epoch 33/50
# Generator Loss: 0.8649, Discriminator Loss: 0.7901
#
# Epoch 34/50
# Generator Loss: 2.7690, Discriminator Loss: 0.9134
#
# Epoch 35/50
# Generator Loss: 1.3086, Discriminator Loss: 0.6846
#
# Epoch 36/50
# Generator Loss: 1.6779, Discriminator Loss: 0.9978
#
# Epoch 37/50
# Generator Loss: 1.4098, Discriminator Loss: 0.5873
#
# Epoch 38/50
# Generator Loss: 2.0798, Discriminator Loss: 0.4633
#
# Epoch 39/50
# Generator Loss: 1.3790, Discriminator Loss: 0.6494
#
# Epoch 40/50
# Generator Loss: 2.2732, Discriminator Loss: 1.0252
#
# Epoch 41/50
# Generator Loss: 1.1254, Discriminator Loss: 0.8915
#
# Epoch 42/50
# Generator Loss: 1.7072, Discriminator Loss: 0.5702
#
# Epoch 43/50
# Generator Loss: 1.0365, Discriminator Loss: 0.5519
#
# Epoch 44/50
# Generator Loss: 2.4020, Discriminator Loss: 0.7437
#
# Epoch 45/50
# Generator Loss: 1.3848, Discriminator Loss: 0.6083
#
# Epoch 46/50
# Generator Loss: 1.2754, Discriminator Loss: 1.4707
#
# Epoch 47/50
# Generator Loss: 1.8537, Discriminator Loss: 0.7059
#
# Epoch 48/50
# Generator Loss: 1.4670, Discriminator Loss: 1.0952
#
# Epoch 49/50
# Generator Loss: 2.5277, Discriminator Loss: 0.8581
#
# Epoch 50/50
# Generator Loss: 1.4561, Discriminator Loss: 0.7810

# %% [markdown]
# **Training on 200**

# %%
EPOCHS = 200

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    return real_loss + fake_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

@tf.function
def train_step(images, captions):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator([noise, captions], training=True)
        real_output = discriminator([images, captions], training=True)
        fake_output = discriminator([generated_images, captions], training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return gen_loss, disc_loss

# -----------------------------
# Image Generation
# -----------------------------

def generate_and_save_images(model, captions, epoch, save_dir="generated_images"):
    os.makedirs(save_dir, exist_ok=True)
    noise = tf.random.normal([len(captions), noise_dim])
    generated_images = model([noise, captions], training=False)

    plt.figure(figsize=(15, 4))
    for i in range(len(captions)):
        plt.subplot(1, len(captions), i+1)
        plt.imshow((generated_images[i].numpy() + 1) / 2.0)
        plt.axis('off')
        # Save individual image
        img_path = os.path.join(save_dir, f"epoch{epoch}_img{i}.png")
        plt.imsave(img_path, (generated_images[i].numpy() + 1) / 2.0)
    plt.suptitle(f'Generated Images at Epoch {epoch}')
    plt.show()

# -----------------------------
# Captions from User
# -----------------------------

# Define captions from user
user_captions = [

    "ethnic Boys Printed Maroon Kurta",
    "sports Men Gel Running White Sports Shoes",
    "casual Men Aventura Sandal",
    "casual Boys Be Born Green Sweatshirt",
    "casual Women Beige Flats"

]

# Tokenize and pad
user_sequences = tokenizer.texts_to_sequences(user_captions)
user_sequences_padded = tf.keras.preprocessing.sequence.pad_sequences(user_sequences, maxlen=max_caption_len, padding='post')
user_sequences_padded = tf.convert_to_tensor(user_sequences_padded)

# -----------------------------
# Training Loop
# -----------------------------

for epoch in range(1, EPOCHS + 1):
    print(f"\nEpoch {epoch}/{EPOCHS}")
    for image_batch, caption_batch in dataset:
        g_loss, d_loss = train_step(image_batch, caption_batch)

    print(f"Generator Loss: {g_loss.numpy():.4f}, Discriminator Loss: {d_loss.numpy():.4f}")

    if epoch == EPOCHS:
        generate_and_save_images(generator, user_sequences_padded, epoch)
# Out:
# Epoch 1/200
# Generator Loss: 0.4329, Discriminator Loss: 1.7234
#
# Epoch 2/200
# Generator Loss: 0.6948, Discriminator Loss: 1.3296
#
# Epoch 3/200
# Generator Loss: 0.8565, Discriminator Loss: 1.1915
#
# Epoch 4/200
# Generator Loss: 0.9365, Discriminator Loss: 0.9546
#
# Epoch 5/200
# Generator Loss: 1.1798, Discriminator Loss: 0.7408
#
# Epoch 6/200
# Generator Loss: 0.8135, Discriminator Loss: 1.1211
#
# Epoch 7/200
# Generator Loss: 3.6138, Discriminator Loss: 0.6788
#
# Epoch 8/200
# Generator Loss: 1.0079, Discriminator Loss: 1.4264
#
# Epoch 9/200
# Generator Loss: 3.4860, Discriminator Loss: 1.0198
#
# Epoch 10/200
# Generator Loss: 1.6140, Discriminator Loss: 1.1457
#
# Epoch 11/200
# Generator Loss: 3.5998, Discriminator Loss: 1.5144
#
# Epoch 12/200
# Generator Loss: 0.8655, Discriminator Loss: 1.2387
#
# Epoch 13/200
# Generator Loss: 1.1453, Discriminator Loss: 1.0683
#
# Epoch 14/200
# Generator Loss: 0.4002, Discriminator Loss: 1.5362
#
# Epoch 15/200
# Generator Loss: 0.8281, Discriminator Loss: 0.9561
#
# Epoch 16/200
# Generator Loss: 2.3679, Discriminator Loss: 0.9363
#
# Epoch 17/200
# Generator Loss: 1.3201, Discriminator Loss: 0.8763
#
# Epoch 18/200
# Generator Loss: 1.9016, Discriminator Loss: 0.8965
#
# Epoch 19/200
# Generator Loss: 2.3692, Discriminator Loss: 0.7650
#
# Epoch 20/200
# Generator Loss: 0.6404, Discriminator Loss: 1.2047
#
# Epoch 21/200
# Generator Loss: 0.2252, Discriminator Loss: 2.0844
#
# Epoch 22/200
# Generator Loss: 0.7953, Discriminator Loss: 1.7645
#
# Epoch 23/200
# Generator Loss: 1.5887, Discriminator Loss: 1.2541
#
# Epoch 24/200
# Generator Loss: 0.0967, Discriminator Loss: 2.8416
#
# Epoch 25/200
# Generator Loss: 1.0401, Discriminator Loss: 0.7940
#
# Epoch 26/200
# Generator Loss: 1.8286, Discriminator Loss: 0.5897
#
# Epoch 27/200
# Generator Loss: 1.5779, Discriminator Loss: 1.1035
#
# Epoch 28/200
# Generator Loss: 1.0578, Discriminator Loss: 0.8648
#
# Epoch 29/200
# Generator Loss: 0.9288, Discriminator Loss: 1.1808
#
# Epoch 30/200
# Generator Loss: 0.2360, Discriminator Loss: 2.1163
#
# Epoch 31/200
# Generator Loss: 1.2890, Discriminator Loss: 1.5855
#
# Epoch 32/200
# Generator Loss: 0.9884, Discriminator Loss: 1.2412
#
# Epoch 33/200
# Generator Loss: 1.1345, Discriminator Loss: 0.7953
#
# Epoch 34/200
# Generator Loss: 1.8139, Discriminator Loss: 1.2053
#
# Epoch 35/200
# Generator Loss: 1.5246, Discriminator Loss: 1.5639
#
# Epoch 36/200
# Generator Loss: 1.9877, Discriminator Loss: 0.8304
#
# Epoch 37/200
# Generator Loss: 1.1420, Discriminator Loss: 0.7301
#
# Epoch 38/200
# Generator Loss: 0.4580, Discriminator Loss: 1.2814
#
# Epoch 39/200
# Generator Loss: 0.9469, Discriminator Loss: 1.1041
#
# Epoch 40/200
# Generator Loss: 2.4503, Discriminator Loss: 1.1169
#
# Epoch 41/200
# Generator Loss: 1.1879, Discriminator Loss: 0.8738
#
# Epoch 42/200
# Generator Loss: 0.4689, Discriminator Loss: 1.6744
#
# Epoch 43/200
# Generator Loss: 1.2624, Discriminator Loss: 1.0562
#
# Epoch 44/200
# Generator Loss: 1.3086, Discriminator Loss: 1.0772
#
# Epoch 45/200
# Generator Loss: 1.2150, Discriminator Loss: 0.8459
#
# Epoch 46/200
# Generator Loss: 1.0202, Discriminator Loss: 0.7553
#
# Epoch 47/200
# Generator Loss: 0.7966, Discriminator Loss: 0.8827
#
# Epoch 48/200
# Generator Loss: 1.5132, Discriminator Loss: 1.0183
#
# Epoch 49/200
# Generator Loss: 0.6855, Discriminator Loss: 1.0474
#
# Epoch 50/200
# Generator Loss: 2.8539, Discriminator Loss: 1.1065
#
# Epoch 51/200
# Generator Loss: 1.4106, Discriminator Loss: 1.2558
#
# Epoch 52/200
# Generator Loss: 2.5339, Discriminator Loss: 0.6457
#
# Epoch 53/200
# Generator Loss: 1.4454, Discriminator Loss: 0.5865
#
# Epoch 54/200
# Generator Loss: 3.3000, Discriminator Loss: 0.5489
#
# Epoch 55/200
# Generator Loss: 2.3720, Discriminator Loss: 0.6153
#
# Epoch 56/200
# Generator Loss: 3.6248, Discriminator Loss: 1.0151
#
# Epoch 57/200
# Generator Loss: 1.5916, Discriminator Loss: 0.8444
#
# Epoch 58/200
# Generator Loss: 1.0552, Discriminator Loss: 0.6234
#
# Epoch 59/200
# Generator Loss: 0.2659, Discriminator Loss: 1.8570
#
# Epoch 60/200
# Generator Loss: 2.4965, Discriminator Loss: 0.9650
#
# Epoch 61/200
# Generator Loss: 1.3536, Discriminator Loss: 0.5380
#
# Epoch 62/200
# Generator Loss: 2.2371, Discriminator Loss: 1.1790
#
# Epoch 63/200
# Generator Loss: 3.5098, Discriminator Loss: 1.9581
#
# Epoch 64/200
# Generator Loss: 0.8582, Discriminator Loss: 1.5525
#
# Epoch 65/200
# Generator Loss: 1.1320, Discriminator Loss: 1.3708
#
# Epoch 66/200
# Generator Loss: 1.9995, Discriminator Loss: 0.3461
#
# Epoch 67/200
# Generator Loss: 1.2544, Discriminator Loss: 0.5096
#
# Epoch 68/200
# Generator Loss: 0.8435, Discriminator Loss: 1.1477
#
# Epoch 69/200
# Generator Loss: 1.1027, Discriminator Loss: 0.8699
#
# Epoch 70/200
# Generator Loss: 0.7847, Discriminator Loss: 0.9194
#
# Epoch 71/200
# Generator Loss: 2.9149, Discriminator Loss: 0.6604
#
# Epoch 72/200
# Generator Loss: 0.4969, Discriminator Loss: 1.3589
#
# Epoch 73/200
# Generator Loss: 0.3876, Discriminator Loss: 1.4290
#
# Epoch 74/200
# Generator Loss: 0.4025, Discriminator Loss: 1.6065
#
# Epoch 75/200
# Generator Loss: 2.3050, Discriminator Loss: 0.6699
#
# Epoch 76/200
# Generator Loss: 2.3857, Discriminator Loss: 0.5273
#
# Epoch 77/200
# Generator Loss: 1.9865, Discriminator Loss: 0.8811
#
# Epoch 78/200
# Generator Loss: 0.5235, Discriminator Loss: 1.2985
#
# Epoch 79/200
# Generator Loss: 1.2562, Discriminator Loss: 0.9612
#
# Epoch 80/200
# Generator Loss: 1.6467, Discriminator Loss: 0.8930
#
# Epoch 81/200
# Generator Loss: 0.8867, Discriminator Loss: 1.1267
#
# Epoch 82/200
# Generator Loss: 1.5423, Discriminator Loss: 0.7227
#
# Epoch 83/200
# Generator Loss: 0.9993, Discriminator Loss: 0.5917
#
# Epoch 84/200
# Generator Loss: 0.9451, Discriminator Loss: 1.2362
#
# Epoch 85/200
# Generator Loss: 1.3745, Discriminator Loss: 0.4025
#
# Epoch 86/200
# Generator Loss: 1.7220, Discriminator Loss: 0.5576
#
# Epoch 87/200
# Generator Loss: 0.7059, Discriminator Loss: 1.1467
#
# Epoch 88/200
# Generator Loss: 2.0874, Discriminator Loss: 0.5279
#
# Epoch 89/200
# Generator Loss: 1.5498, Discriminator Loss: 0.4884
#
# Epoch 90/200
# Generator Loss: 2.1424, Discriminator Loss: 0.5740
#
# Epoch 91/200
# Generator Loss: 1.9724, Discriminator Loss: 0.7405
#
# Epoch 92/200
# Generator Loss: 1.3322, Discriminator Loss: 1.1247
#
# Epoch 93/200
# Generator Loss: 2.0624, Discriminator Loss: 0.6685
#
# Epoch 94/200
# Generator Loss: 1.3122, Discriminator Loss: 0.5402
#
# Epoch 95/200
# Generator Loss: 0.6643, Discriminator Loss: 1.0375
#
# Epoch 96/200
# Generator Loss: 1.0854, Discriminator Loss: 0.8084
#
# Epoch 97/200
# Generator Loss: 1.6213, Discriminator Loss: 0.5898
#
# Epoch 98/200
# Generator Loss: 2.4459, Discriminator Loss: 0.6183
#
# Epoch 99/200
# Generator Loss: 1.5372, Discriminator Loss: 1.3140
#
# Epoch 100/200
# Generator Loss: 2.1783, Discriminator Loss: 1.2503
#
# Epoch 101/200
# Generator Loss: 1.9192, Discriminator Loss: 1.0131
#
# Epoch 102/200
# Generator Loss: 1.9385, Discriminator Loss: 0.5368
#
# Epoch 103/200
# Generator Loss: 1.6986, Discriminator Loss: 0.8699
#
# Epoch 104/200
# Generator Loss: 1.3255, Discriminator Loss: 0.6412
#
# Epoch 105/200
# Generator Loss: 3.0261, Discriminator Loss: 0.3193
#
# Epoch 106/200
# Generator Loss: 2.5318, Discriminator Loss: 0.9286
#
# Epoch 107/200
# Generator Loss: 1.5512, Discriminator Loss: 0.7217
#
# Epoch 108/200
# Generator Loss: 1.9900, Discriminator Loss: 0.6124
#
# Epoch 109/200
# Generator Loss: 1.9400, Discriminator Loss: 0.7627
#
# Epoch 110/200
# Generator Loss: 2.1614, Discriminator Loss: 0.4800
#
# Epoch 111/200
# Generator Loss: 2.2703, Discriminator Loss: 0.8728
#
# Epoch 112/200
# Generator Loss: 2.4502, Discriminator Loss: 1.1242
#
# Epoch 113/200
# Generator Loss: 2.3375, Discriminator Loss: 0.4524
#
# Epoch 114/200
# Generator Loss: 1.2777, Discriminator Loss: 0.8469
#
# Epoch 115/200
# Generator Loss: 1.1917, Discriminator Loss: 0.8895
#
# Epoch 116/200
# Generator Loss: 2.0380, Discriminator Loss: 0.8150
#
# Epoch 117/200
# Generator Loss: 2.4110, Discriminator Loss: 0.3309
#
# Epoch 118/200
# Generator Loss: 0.8017, Discriminator Loss: 0.7550
#
# Epoch 119/200
# Generator Loss: 1.2162, Discriminator Loss: 0.6342
#
# Epoch 120/200
# Generator Loss: 1.6890, Discriminator Loss: 0.3983
#
# Epoch 121/200
# Generator Loss: 2.5390, Discriminator Loss: 1.1406
#
# Epoch 122/200
# Generator Loss: 2.4850, Discriminator Loss: 0.5082
#
# Epoch 123/200
# Generator Loss: 1.4547, Discriminator Loss: 0.6307
#
# Epoch 124/200
# Generator Loss: 1.0468, Discriminator Loss: 0.9032
#
# Epoch 125/200
# Generator Loss: 1.1766, Discriminator Loss: 0.8550
#
# Epoch 126/200
# Generator Loss: 1.3728, Discriminator Loss: 1.2652
#
# Epoch 127/200
# Generator Loss: 2.1138, Discriminator Loss: 0.5620
#
# Epoch 128/200
# Generator Loss: 1.3081, Discriminator Loss: 0.4846
#
# Epoch 129/200
# Generator Loss: 2.4279, Discriminator Loss: 0.4846
#
# Epoch 130/200
# Generator Loss: 1.9266, Discriminator Loss: 0.3788
#
# Epoch 131/200
# Generator Loss: 3.7323, Discriminator Loss: 0.3619
#
# Epoch 132/200
# Generator Loss: 1.4041, Discriminator Loss: 0.5355
#
# Epoch 133/200
# Generator Loss: 1.6140, Discriminator Loss: 0.6301
#
# Epoch 134/200
# Generator Loss: 2.5196, Discriminator Loss: 0.2307
#
# Epoch 135/200
# Generator Loss: 1.6996, Discriminator Loss: 0.4889
#
# Epoch 136/200
# Generator Loss: 1.6450, Discriminator Loss: 0.3605
#
# Epoch 137/200
# Generator Loss: 2.2550, Discriminator Loss: 0.3328
#
# Epoch 138/200
# Generator Loss: 2.5582, Discriminator Loss: 0.2853
#
# Epoch 139/200
# Generator Loss: 1.8499, Discriminator Loss: 0.4825
#
# Epoch 140/200
# Generator Loss: 2.4695, Discriminator Loss: 0.5106
#
# Epoch 141/200
# Generator Loss: 2.4960, Discriminator Loss: 0.2777
#
# Epoch 142/200
# Generator Loss: 1.9226, Discriminator Loss: 0.7814
#
# Epoch 143/200
# Generator Loss: 1.6819, Discriminator Loss: 1.2906
#
# Epoch 144/200
# Generator Loss: 1.3968, Discriminator Loss: 0.8661
#
# Epoch 145/200
# Generator Loss: 2.0106, Discriminator Loss: 0.3116
#
# Epoch 146/200
# Generator Loss: 1.6577, Discriminator Loss: 0.9193
#
# Epoch 147/200
# Generator Loss: 1.5165, Discriminator Loss: 0.7803
#
# Epoch 148/200
# Generator Loss: 2.0225, Discriminator Loss: 0.5220
#
# Epoch 149/200
# Generator Loss: 2.2305, Discriminator Loss: 0.4979
#
# Epoch 150/200
# Generator Loss: 0.9947, Discriminator Loss: 0.6438
#
# Epoch 151/200
# Generator Loss: 0.9382, Discriminator Loss: 0.6406
#
# Epoch 152/200
# Generator Loss: 2.6173, Discriminator Loss: 0.2715
#
# Epoch 153/200
# Generator Loss: 3.1764, Discriminator Loss: 0.9853
#
# Epoch 154/200
# Generator Loss: 0.4840, Discriminator Loss: 1.1302
#
# Epoch 155/200
# Generator Loss: 4.1017, Discriminator Loss: 0.3467
#
# Epoch 156/200
# Generator Loss: 2.3574, Discriminator Loss: 0.9032
#
# Epoch 157/200
# Generator Loss: 1.2272, Discriminator Loss: 0.6187
#
# Epoch 158/200
# Generator Loss: 2.2328, Discriminator Loss: 0.4400
#
# Epoch 159/200
# Generator Loss: 2.0523, Discriminator Loss: 0.6571
#
# Epoch 160/200
# Generator Loss: 2.9337, Discriminator Loss: 0.6943
#
# Epoch 161/200
# Generator Loss: 2.4047, Discriminator Loss: 0.8781
#
# Epoch 162/200
# Generator Loss: 0.9685, Discriminator Loss: 0.6658
#
# Epoch 163/200
# Generator Loss: 0.6008, Discriminator Loss: 1.1847
#
# Epoch 164/200
# Generator Loss: 1.1769, Discriminator Loss: 1.0469
#
# Epoch 165/200
# Generator Loss: 1.3807, Discriminator Loss: 0.6688
#
# Epoch 166/200
# Generator Loss: 3.6068, Discriminator Loss: 0.4482
#
# Epoch 167/200
# Generator Loss: 2.6099, Discriminator Loss: 0.7257
#
# Epoch 168/200
# Generator Loss: 1.4290, Discriminator Loss: 0.5265
#
# Epoch 169/200
# Generator Loss: 1.6549, Discriminator Loss: 0.5580
#
# Epoch 170/200
# Generator Loss: 1.9272, Discriminator Loss: 0.4465
#
# Epoch 171/200
# Generator Loss: 2.3850, Discriminator Loss: 0.2477
#
# Epoch 172/200
# Generator Loss: 1.9469, Discriminator Loss: 0.2823
#
# Epoch 173/200
# Generator Loss: 2.5496, Discriminator Loss: 0.5369
#
# Epoch 174/200
# Generator Loss: 1.9946, Discriminator Loss: 0.3528
#
# Epoch 175/200
# Generator Loss: 2.5765, Discriminator Loss: 0.3405
#
# Epoch 176/200
# Generator Loss: 2.4753, Discriminator Loss: 0.2903
#
# Epoch 177/200
# Generator Loss: 2.1628, Discriminator Loss: 0.3992
#
# Epoch 178/200
# Generator Loss: 1.7768, Discriminator Loss: 0.3897
#
# Epoch 179/200
# Generator Loss: 2.2239, Discriminator Loss: 0.8879
#
# Epoch 180/200
# Generator Loss: 3.0845, Discriminator Loss: 0.3287
#
# Epoch 181/200
# Generator Loss: 1.7677, Discriminator Loss: 0.7359
#
# Epoch 182/200
# Generator Loss: 1.1612, Discriminator Loss: 0.6832
#
# Epoch 183/200
# Generator Loss: 2.4373, Discriminator Loss: 0.3787
#
# Epoch 184/200
# Generator Loss: 1.5721, Discriminator Loss: 0.5740
#
# Epoch 185/200
# Generator Loss: 2.0279, Discriminator Loss: 0.3184
#
# Epoch 186/200
# Generator Loss: 1.7459, Discriminator Loss: 0.5765
#
# Epoch 187/200
# Generator Loss: 3.3705, Discriminator Loss: 0.9579
#
# Epoch 188/200
# Generator Loss: 2.8233, Discriminator Loss: 0.5164
#
# Epoch 189/200
# Generator Loss: 1.8026, Discriminator Loss: 0.3886
#
# Epoch 190/200
# Generator Loss: 2.8874, Discriminator Loss: 1.7318
#
# Epoch 191/200
# Generator Loss: 3.2815, Discriminator Loss: 0.5652
#
# Epoch 192/200
# Generator Loss: 1.8968, Discriminator Loss: 0.8125
#
# Epoch 193/200
# Generator Loss: 4.5294, Discriminator Loss: 0.7096
#
# Epoch 194/200
# Generator Loss: 1.8252, Discriminator Loss: 0.4890
#
# Epoch 195/200
# Generator Loss: 2.8807, Discriminator Loss: 0.4535
#
# Epoch 196/200
# Generator Loss: 2.4759, Discriminator Loss: 0.4789
#
# Epoch 197/200
# Generator Loss: 2.5674, Discriminator Loss: 0.4340
#
# Epoch 198/200
# Generator Loss: 2.5314, Discriminator Loss: 0.2001
#
# Epoch 199/200
# Generator Loss: 2.3193, Discriminator Loss: 0.5623
#
# Epoch 200/200
# Generator Loss: 3.5927, Discriminator Loss: 0.2623

# %% [markdown]
# **TRaing on 600**

# %%
EPOCHS = 600

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    return real_loss + fake_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

@tf.function
def train_step(images, captions):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator([noise, captions], training=True)
        real_output = discriminator([images, captions], training=True)
        fake_output = discriminator([generated_images, captions], training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return gen_loss, disc_loss

# -----------------------------
# Image Generation
# -----------------------------

def generate_and_save_images(model, captions, epoch, save_dir="generated_images"):
    os.makedirs(save_dir, exist_ok=True)
    noise = tf.random.normal([len(captions), noise_dim])
    generated_images = model([noise, captions], training=False)

    plt.figure(figsize=(15, 4))
    for i in range(len(captions)):
        plt.subplot(1, len(captions), i+1)
        plt.imshow((generated_images[i].numpy() + 1) / 2.0)
        plt.axis('off')
        # Save individual image
        img_path = os.path.join(save_dir, f"epoch{epoch}_img{i}.png")
        plt.imsave(img_path, (generated_images[i].numpy() + 1) / 2.0)
    plt.suptitle(f'Generated Images at Epoch {epoch}')
    plt.show()

# -----------------------------
# Captions from User
# -----------------------------

# Define captions from user
user_captions = [

    "ethnic Boys Printed Maroon Kurta",
    "sports Men Gel Running White Sports Shoes",
    "casual Men Aventura Sandal",
    "casual Boys Be Born Green Sweatshirt",
    "casual Women Beige Flats"

]

# Tokenize and pad
user_sequences = tokenizer.texts_to_sequences(user_captions)
user_sequences_padded = tf.keras.preprocessing.sequence.pad_sequences(user_sequences, maxlen=max_caption_len, padding='post')
user_sequences_padded = tf.convert_to_tensor(user_sequences_padded)

# -----------------------------
# Training Loop
# -----------------------------

for epoch in range(1, EPOCHS + 1):
    print(f"\nEpoch {epoch}/{EPOCHS}")
    for image_batch, caption_batch in dataset:
        g_loss, d_loss = train_step(image_batch, caption_batch)

    print(f"Generator Loss: {g_loss.numpy():.4f}, Discriminator Loss: {d_loss.numpy():.4f}")

    if epoch == EPOCHS:
        generate_and_save_images(generator, user_sequences_padded, epoch)
# Out:
# Epoch 1/600
# Generator Loss: 3.1684, Discriminator Loss: 0.1326
#
# Epoch 2/600
# Generator Loss: 2.1867, Discriminator Loss: 0.2906
#
# Epoch 3/600
# Generator Loss: 2.0382, Discriminator Loss: 0.1800
#
# Epoch 4/600
# Generator Loss: 4.6644, Discriminator Loss: 0.8885
#
# Epoch 5/600
# Generator Loss: 2.0164, Discriminator Loss: 0.2932
#
# Epoch 6/600
# Generator Loss: 1.9290, Discriminator Loss: 0.2340
#
# Epoch 7/600
# Generator Loss: 0.8305, Discriminator Loss: 0.7518
#
# Epoch 8/600
# Generator Loss: 3.5726, Discriminator Loss: 0.1102
#
# Epoch 9/600
# Generator Loss: 3.0726, Discriminator Loss: 0.2153
#
# Epoch 10/600
# Generator Loss: 2.2260, Discriminator Loss: 0.1675
#
# Epoch 11/600
# Generator Loss: 1.8400, Discriminator Loss: 0.2387
#
# Epoch 12/600
# Generator Loss: 3.8066, Discriminator Loss: 1.1125
#
# Epoch 13/600
# Generator Loss: 2.6458, Discriminator Loss: 0.3396
#
# Epoch 14/600
# Generator Loss: 1.9008, Discriminator Loss: 0.2531
#
# Epoch 15/600
# Generator Loss: 0.5532, Discriminator Loss: 0.9510
#
# Epoch 16/600
# Generator Loss: 2.4916, Discriminator Loss: 0.9381
#
# Epoch 17/600
# Generator Loss: 3.2763, Discriminator Loss: 0.1041
#
# Epoch 18/600
# Generator Loss: 1.9189, Discriminator Loss: 0.3012
#
# Epoch 19/600
# Generator Loss: 2.7708, Discriminator Loss: 0.0982
#
# Epoch 20/600
# Generator Loss: 4.4900, Discriminator Loss: 0.5208
#
# Epoch 21/600
# Generator Loss: 2.6122, Discriminator Loss: 0.4965
#
# Epoch 22/600
# Generator Loss: 1.7091, Discriminator Loss: 0.2603
#
# Epoch 23/600
# Generator Loss: 3.1442, Discriminator Loss: 0.1822
#
# Epoch 24/600
# Generator Loss: 5.9031, Discriminator Loss: 0.6448
#
# Epoch 25/600
# Generator Loss: 5.1485, Discriminator Loss: 0.2982
#
# Epoch 26/600
# Generator Loss: 3.2649, Discriminator Loss: 0.1381
#
# Epoch 27/600
# Generator Loss: 2.5847, Discriminator Loss: 0.2015
#
# Epoch 28/600
# Generator Loss: 5.3444, Discriminator Loss: 0.9637
#
# Epoch 29/600
# Generator Loss: 0.5486, Discriminator Loss: 1.0194
#
# Epoch 30/600
# Generator Loss: 3.8880, Discriminator Loss: 0.0959
#
# Epoch 31/600
# Generator Loss: 4.2461, Discriminator Loss: 0.1291
#
# Epoch 32/600
# Generator Loss: 4.2068, Discriminator Loss: 0.1008
#
# Epoch 33/600
# Generator Loss: 3.0077, Discriminator Loss: 0.3048
#
# Epoch 34/600
# Generator Loss: 3.9947, Discriminator Loss: 1.1695
#
# Epoch 35/600
# Generator Loss: 2.9056, Discriminator Loss: 0.0891
#
# Epoch 36/600
# Generator Loss: 0.9829, Discriminator Loss: 0.6175
#
# Epoch 37/600
# Generator Loss: 1.3298, Discriminator Loss: 0.4702
#
# Epoch 38/600
# Generator Loss: 3.3735, Discriminator Loss: 0.1386
#
# Epoch 39/600
# Generator Loss: 3.0856, Discriminator Loss: 0.0939
#
# Epoch 40/600
# Generator Loss: 2.3085, Discriminator Loss: 0.2929
#
# Epoch 41/600
# Generator Loss: 3.2874, Discriminator Loss: 0.1713
#
# Epoch 42/600
# Generator Loss: 4.1871, Discriminator Loss: 0.0592
#
# Epoch 43/600
# Generator Loss: 1.6184, Discriminator Loss: 0.3602
#
# Epoch 44/600
# Generator Loss: 1.3567, Discriminator Loss: 0.4250
#
# Epoch 45/600
# Generator Loss: 0.7602, Discriminator Loss: 0.9450
#
# Epoch 46/600
# Generator Loss: 2.7713, Discriminator Loss: 0.4130
#
# Epoch 47/600
# Generator Loss: 2.5731, Discriminator Loss: 0.1112
#
# Epoch 48/600
# Generator Loss: 2.6232, Discriminator Loss: 0.2271
#
# Epoch 49/600
# Generator Loss: 4.3949, Discriminator Loss: 0.6033
#
# Epoch 50/600
# Generator Loss: 3.6233, Discriminator Loss: 0.3846
#
# Epoch 51/600
# Generator Loss: 2.6080, Discriminator Loss: 0.2384
#
# Epoch 52/600
# Generator Loss: 2.0160, Discriminator Loss: 0.2453
#
# Epoch 53/600
# Generator Loss: 2.6736, Discriminator Loss: 0.5890
#
# Epoch 54/600
# Generator Loss: 2.1033, Discriminator Loss: 0.2167
#
# Epoch 55/600
# Generator Loss: 3.3062, Discriminator Loss: 0.0902
#
# Epoch 56/600
# Generator Loss: 1.5245, Discriminator Loss: 0.4623
#
# Epoch 57/600
# Generator Loss: 5.2488, Discriminator Loss: 1.4047
#
# Epoch 58/600
# Generator Loss: 1.8696, Discriminator Loss: 0.2916
#
# Epoch 59/600
# Generator Loss: 4.7061, Discriminator Loss: 1.1840
#
# Epoch 60/600
# Generator Loss: 1.1925, Discriminator Loss: 0.4905
#
# Epoch 61/600
# Generator Loss: 3.9341, Discriminator Loss: 0.6005
#
# Epoch 62/600
# Generator Loss: 2.2883, Discriminator Loss: 0.2471
#
# Epoch 63/600
# Generator Loss: 1.4768, Discriminator Loss: 0.4304
#
# Epoch 64/600
# Generator Loss: 1.8021, Discriminator Loss: 0.3682
#
# Epoch 65/600
# Generator Loss: 3.1817, Discriminator Loss: 0.2667
#
# Epoch 66/600
# Generator Loss: 1.6920, Discriminator Loss: 0.2993
#
# Epoch 67/600
# Generator Loss: 0.9122, Discriminator Loss: 0.6949
#
# Epoch 68/600
# Generator Loss: 2.8140, Discriminator Loss: 0.2586
#
# Epoch 69/600
# Generator Loss: 2.9134, Discriminator Loss: 0.1596
#
# Epoch 70/600
# Generator Loss: 2.0887, Discriminator Loss: 0.1815
#
# Epoch 71/600
# Generator Loss: 2.9062, Discriminator Loss: 0.1471
#
# Epoch 72/600
# Generator Loss: 0.6135, Discriminator Loss: 0.9523
#
# Epoch 73/600
# Generator Loss: 1.3500, Discriminator Loss: 0.3997
#
# Epoch 74/600
# Generator Loss: 1.7574, Discriminator Loss: 0.2807
#
# Epoch 75/600
# Generator Loss: 2.0192, Discriminator Loss: 0.2539
#
# Epoch 76/600
# Generator Loss: 2.1632, Discriminator Loss: 0.5390
#
# Epoch 77/600
# Generator Loss: 4.4214, Discriminator Loss: 0.3245
#
# Epoch 78/600
# Generator Loss: 3.7298, Discriminator Loss: 0.7249
#
# Epoch 79/600
# Generator Loss: 2.0061, Discriminator Loss: 0.2252
#
# Epoch 80/600
# Generator Loss: 2.5150, Discriminator Loss: 0.3165
#
# Epoch 81/600
# Generator Loss: 3.1263, Discriminator Loss: 0.1051
#
# Epoch 82/600
# Generator Loss: 2.9556, Discriminator Loss: 0.1858
#
# Epoch 83/600
# Generator Loss: 3.5621, Discriminator Loss: 0.1360
#
# Epoch 84/600
# Generator Loss: 3.7374, Discriminator Loss: 0.3986
#
# Epoch 85/600
# Generator Loss: 3.5864, Discriminator Loss: 0.0772
#
# Epoch 86/600
# Generator Loss: 3.3303, Discriminator Loss: 0.7497
#
# Epoch 87/600
# Generator Loss: 3.2155, Discriminator Loss: 0.0778
#
# Epoch 88/600
# Generator Loss: 2.5030, Discriminator Loss: 0.1594
#
# Epoch 89/600
# Generator Loss: 1.6949, Discriminator Loss: 0.2792
#
# Epoch 90/600
# Generator Loss: 2.8556, Discriminator Loss: 0.1720
#
# Epoch 91/600
# Generator Loss: 1.5077, Discriminator Loss: 0.3701
#
# Epoch 92/600
# Generator Loss: 0.9177, Discriminator Loss: 0.7048
#
# Epoch 93/600
# Generator Loss: 2.2905, Discriminator Loss: 0.1844
#
# Epoch 94/600
# Generator Loss: 4.0411, Discriminator Loss: 0.1398
#
# Epoch 95/600
# Generator Loss: 3.0786, Discriminator Loss: 0.4116
#
# Epoch 96/600
# Generator Loss: 2.1889, Discriminator Loss: 0.1782
#
# Epoch 97/600
# Generator Loss: 3.4780, Discriminator Loss: 0.0734
#
# Epoch 98/600
# Generator Loss: 2.5318, Discriminator Loss: 0.1268
#
# Epoch 99/600
# Generator Loss: 3.5703, Discriminator Loss: 0.1071
#
# Epoch 100/600
# Generator Loss: 4.5811, Discriminator Loss: 0.2031
#
# Epoch 101/600
# Generator Loss: 2.5830, Discriminator Loss: 0.2507
#
# Epoch 102/600
# Generator Loss: 2.9142, Discriminator Loss: 0.1274
#
# Epoch 103/600
# Generator Loss: 2.1031, Discriminator Loss: 0.2480
#
# Epoch 104/600
# Generator Loss: 1.8774, Discriminator Loss: 0.2700
#
# Epoch 105/600
# Generator Loss: 1.8462, Discriminator Loss: 0.2582
#
# Epoch 106/600
# Generator Loss: 2.3635, Discriminator Loss: 0.2150
#
# Epoch 107/600
# Generator Loss: 2.4741, Discriminator Loss: 0.1746
#
# Epoch 108/600
# Generator Loss: 3.7696, Discriminator Loss: 0.0519
#
# Epoch 109/600
# Generator Loss: 2.6513, Discriminator Loss: 0.2418
#
# Epoch 110/600
# Generator Loss: 1.9134, Discriminator Loss: 0.2440
#
# Epoch 111/600
# Generator Loss: 2.5741, Discriminator Loss: 0.2723
#
# Epoch 112/600
# Generator Loss: 3.3107, Discriminator Loss: 0.0900
#
# Epoch 113/600
# Generator Loss: 0.9047, Discriminator Loss: 0.6067
#
# Epoch 114/600
# Generator Loss: 2.0410, Discriminator Loss: 0.2357
#
# Epoch 115/600
# Generator Loss: 3.9656, Discriminator Loss: 0.0825
#
# Epoch 116/600
# Generator Loss: 1.8253, Discriminator Loss: 0.2564
#
# Epoch 117/600
# Generator Loss: 2.9665, Discriminator Loss: 1.0226
#
# Epoch 118/600
# Generator Loss: 5.0288, Discriminator Loss: 0.0284
#
# Epoch 119/600
# Generator Loss: 1.7786, Discriminator Loss: 0.3733
#
# Epoch 120/600
# Generator Loss: 3.3475, Discriminator Loss: 0.9065
#
# Epoch 121/600
# Generator Loss: 1.8621, Discriminator Loss: 0.2784
#
# Epoch 122/600
# Generator Loss: 2.0223, Discriminator Loss: 0.2851
#
# Epoch 123/600
# Generator Loss: 2.0486, Discriminator Loss: 0.3402
#
# Epoch 124/600
# Generator Loss: 3.9554, Discriminator Loss: 0.1127
#
# Epoch 125/600
# Generator Loss: 4.4446, Discriminator Loss: 1.2395
#
# Epoch 126/600
# Generator Loss: 3.3837, Discriminator Loss: 0.6978
#
# Epoch 127/600
# Generator Loss: 1.5067, Discriminator Loss: 0.3838
#
# Epoch 128/600
# Generator Loss: 1.3481, Discriminator Loss: 0.4178
#
# Epoch 129/600
# Generator Loss: 2.1654, Discriminator Loss: 0.2140
#
# Epoch 130/600
# Generator Loss: 3.0093, Discriminator Loss: 0.0763
#
# Epoch 131/600
# Generator Loss: 1.3715, Discriminator Loss: 0.4867
#
# Epoch 132/600
# Generator Loss: 3.1684, Discriminator Loss: 0.0983
#
# Epoch 133/600
# Generator Loss: 1.4534, Discriminator Loss: 0.6131
#
# Epoch 134/600
# Generator Loss: 2.3085, Discriminator Loss: 0.1474
#
# Epoch 135/600
# Generator Loss: 1.0966, Discriminator Loss: 0.5685
#
# Epoch 136/600
# Generator Loss: 2.5366, Discriminator Loss: 0.2399
#
# Epoch 137/600
# Generator Loss: 5.4779, Discriminator Loss: 0.2892
#
# Epoch 138/600
# Generator Loss: 3.1988, Discriminator Loss: 0.1471
#
# Epoch 139/600
# Generator Loss: 2.1910, Discriminator Loss: 0.1915
#
# Epoch 140/600
# Generator Loss: 3.0530, Discriminator Loss: 0.1172
#
# Epoch 141/600
# Generator Loss: 2.9224, Discriminator Loss: 0.1916
#
# Epoch 142/600
# Generator Loss: 3.0962, Discriminator Loss: 0.0781
#
# Epoch 143/600
# Generator Loss: 4.7246, Discriminator Loss: 0.1310
#
# Epoch 144/600
# Generator Loss: 3.1408, Discriminator Loss: 0.3863
#
# Epoch 145/600
# Generator Loss: 4.3906, Discriminator Loss: 0.1060
#
# Epoch 146/600
# Generator Loss: 1.9412, Discriminator Loss: 0.2340
#
# Epoch 147/600
# Generator Loss: 1.7100, Discriminator Loss: 0.4480
#
# Epoch 148/600
# Generator Loss: 4.2483, Discriminator Loss: 0.0585
#
# Epoch 149/600
# Generator Loss: 1.9776, Discriminator Loss: 0.2123
#
# Epoch 150/600
# Generator Loss: 1.2012, Discriminator Loss: 0.4459
#
# Epoch 151/600
# Generator Loss: 3.2612, Discriminator Loss: 0.2743
#
# Epoch 152/600
# Generator Loss: 3.8230, Discriminator Loss: 0.4679
#
# Epoch 153/600
# Generator Loss: 2.7854, Discriminator Loss: 0.2270
#
# Epoch 154/600
# Generator Loss: 5.2509, Discriminator Loss: 0.9885
#
# Epoch 155/600
# Generator Loss: 2.6472, Discriminator Loss: 0.1160
#
# Epoch 156/600
# Generator Loss: 4.7502, Discriminator Loss: 0.1855
#
# Epoch 157/600
# Generator Loss: 3.5042, Discriminator Loss: 0.1086
#
# Epoch 158/600
# Generator Loss: 4.8398, Discriminator Loss: 0.4711
#
# Epoch 159/600
# Generator Loss: 2.1530, Discriminator Loss: 0.3841
#
# Epoch 160/600
# Generator Loss: 4.4592, Discriminator Loss: 0.5562
#
# Epoch 161/600
# Generator Loss: 2.9662, Discriminator Loss: 0.8935
#
# Epoch 162/600
# Generator Loss: 5.4705, Discriminator Loss: 0.0596
#
# Epoch 163/600
# Generator Loss: 2.8370, Discriminator Loss: 0.3329
#
# Epoch 164/600
# Generator Loss: 2.3401, Discriminator Loss: 0.2325
#
# Epoch 165/600
# Generator Loss: 4.2621, Discriminator Loss: 0.9510
#
# Epoch 166/600
# Generator Loss: 5.3034, Discriminator Loss: 0.3946
#
# Epoch 167/600
# Generator Loss: 2.4864, Discriminator Loss: 0.6393
#
# Epoch 168/600
# Generator Loss: 1.6162, Discriminator Loss: 0.3220
#
# Epoch 169/600
# Generator Loss: 3.7595, Discriminator Loss: 0.2164
#
# Epoch 170/600
# Generator Loss: 4.8768, Discriminator Loss: 1.0589
#
# Epoch 171/600
# Generator Loss: 4.3353, Discriminator Loss: 0.1688
#
# Epoch 172/600
# Generator Loss: 2.1066, Discriminator Loss: 0.2300
#
# Epoch 173/600
# Generator Loss: 3.7245, Discriminator Loss: 0.1247
#
# Epoch 174/600
# Generator Loss: 5.2437, Discriminator Loss: 0.1237
#
# Epoch 175/600
# Generator Loss: 3.2916, Discriminator Loss: 0.0936
#
# Epoch 176/600
# Generator Loss: 4.1929, Discriminator Loss: 0.0884
#
# Epoch 177/600
# Generator Loss: 3.0666, Discriminator Loss: 0.2601
#
# Epoch 178/600
# Generator Loss: 4.2091, Discriminator Loss: 0.4608
#
# Epoch 179/600
# Generator Loss: 3.7736, Discriminator Loss: 0.2339
#
# Epoch 180/600
# Generator Loss: 4.2118, Discriminator Loss: 0.3974
#
# Epoch 181/600
# Generator Loss: 5.3920, Discriminator Loss: 1.2272
#
# Epoch 182/600
# Generator Loss: 4.6376, Discriminator Loss: 0.2848
#
# Epoch 183/600
# Generator Loss: 5.0871, Discriminator Loss: 0.2657
#
# Epoch 184/600
# Generator Loss: 3.3611, Discriminator Loss: 0.1325
#
# Epoch 185/600
# Generator Loss: 2.0951, Discriminator Loss: 0.1820
#
# Epoch 186/600
# Generator Loss: 3.2737, Discriminator Loss: 0.0730
#
# Epoch 187/600
# Generator Loss: 3.5068, Discriminator Loss: 0.0439
#
# Epoch 188/600
# Generator Loss: 1.6095, Discriminator Loss: 0.3405
#
# Epoch 189/600
# Generator Loss: 2.8192, Discriminator Loss: 0.1121
#
# Epoch 190/600
# Generator Loss: 2.1066, Discriminator Loss: 0.3424
#
# Epoch 191/600
# Generator Loss: 1.2817, Discriminator Loss: 0.4516
#
# Epoch 192/600
# Generator Loss: 3.1670, Discriminator Loss: 0.3217
#
# Epoch 193/600
# Generator Loss: 0.5073, Discriminator Loss: 1.2520
#
# Epoch 194/600
# Generator Loss: 3.3499, Discriminator Loss: 0.1389
#
# Epoch 195/600
# Generator Loss: 3.6889, Discriminator Loss: 0.2066
#
# Epoch 196/600
# Generator Loss: 3.9452, Discriminator Loss: 0.5985
#
# Epoch 197/600
# Generator Loss: 5.0010, Discriminator Loss: 0.3931
#
# Epoch 198/600
# Generator Loss: 3.0871, Discriminator Loss: 0.1191
#
# Epoch 199/600
# Generator Loss: 4.8301, Discriminator Loss: 0.1024
#
# Epoch 200/600
# Generator Loss: 0.9693, Discriminator Loss: 0.6492
#
# Epoch 201/600
# Generator Loss: 3.1222, Discriminator Loss: 0.0976
#
# Epoch 202/600
# Generator Loss: 3.5915, Discriminator Loss: 0.2604
#
# Epoch 203/600
# Generator Loss: 2.3151, Discriminator Loss: 0.2204
#
# Epoch 204/600
# Generator Loss: 1.6752, Discriminator Loss: 0.3174
#
# Epoch 205/600
# Generator Loss: 1.7488, Discriminator Loss: 0.2824
#
# Epoch 206/600
# Generator Loss: 3.3170, Discriminator Loss: 0.0698
#
# Epoch 207/600
# Generator Loss: 2.4356, Discriminator Loss: 0.4684
#
# Epoch 208/600
# Generator Loss: 5.9688, Discriminator Loss: 0.2052
#
# Epoch 209/600
# Generator Loss: 4.8676, Discriminator Loss: 0.4369
#
# Epoch 210/600
# Generator Loss: 2.2051, Discriminator Loss: 0.1566
#
# Epoch 211/600
# Generator Loss: 2.9362, Discriminator Loss: 0.7850
#
# Epoch 212/600
# Generator Loss: 0.4201, Discriminator Loss: 1.6529
#
# Epoch 213/600
# Generator Loss: 4.6865, Discriminator Loss: 0.4716
#
# Epoch 214/600
# Generator Loss: 1.7364, Discriminator Loss: 0.2842
#
# Epoch 215/600
# Generator Loss: 1.4263, Discriminator Loss: 0.3820
#
# Epoch 216/600
# Generator Loss: 2.0300, Discriminator Loss: 0.2623
#
# Epoch 217/600
# Generator Loss: 4.2330, Discriminator Loss: 0.1596
#
# Epoch 218/600
# Generator Loss: 3.2272, Discriminator Loss: 0.0628
#
# Epoch 219/600
# Generator Loss: 2.2884, Discriminator Loss: 0.1627
#
# Epoch 220/600
# Generator Loss: 3.1725, Discriminator Loss: 0.4793
#
# Epoch 221/600
# Generator Loss: 3.3882, Discriminator Loss: 0.4757
#
# Epoch 222/600
# Generator Loss: 4.2839, Discriminator Loss: 0.4187
#
# Epoch 223/600
# Generator Loss: 4.3977, Discriminator Loss: 0.1005
#
# Epoch 224/600
# Generator Loss: 4.7418, Discriminator Loss: 0.0212
#
# Epoch 225/600
# Generator Loss: 0.6963, Discriminator Loss: 0.8865
#
# Epoch 226/600
# Generator Loss: 3.6171, Discriminator Loss: 0.2192
#
# Epoch 227/600
# Generator Loss: 1.8373, Discriminator Loss: 0.2862
#
# Epoch 228/600
# Generator Loss: 4.5884, Discriminator Loss: 0.5545
#
# Epoch 229/600
# Generator Loss: 2.5828, Discriminator Loss: 0.1413
#
# Epoch 230/600
# Generator Loss: 1.8025, Discriminator Loss: 0.2405
#
# Epoch 231/600
# Generator Loss: 2.6317, Discriminator Loss: 0.1322
#
# Epoch 232/600
# Generator Loss: 2.7411, Discriminator Loss: 0.1865
#
# Epoch 233/600
# Generator Loss: 2.4537, Discriminator Loss: 0.1579
#
# Epoch 234/600
# Generator Loss: 1.3425, Discriminator Loss: 0.4346
#
# Epoch 235/600
# Generator Loss: 3.5766, Discriminator Loss: 0.1870
#
# Epoch 236/600
# Generator Loss: 1.5330, Discriminator Loss: 0.4067
#
# Epoch 237/600
# Generator Loss: 2.7343, Discriminator Loss: 0.1709
#
# Epoch 238/600
# Generator Loss: 3.1549, Discriminator Loss: 0.6308
#
# Epoch 239/600
# Generator Loss: 1.8513, Discriminator Loss: 0.2339
#
# Epoch 240/600
# Generator Loss: 3.4111, Discriminator Loss: 0.0560
#
# Epoch 241/600
# Generator Loss: 3.6901, Discriminator Loss: 0.0543
#
# Epoch 242/600
# Generator Loss: 1.0113, Discriminator Loss: 0.6786
#
# Epoch 243/600
# Generator Loss: 4.5916, Discriminator Loss: 0.9579
#
# Epoch 244/600
# Generator Loss: 1.1962, Discriminator Loss: 0.4275
#
# Epoch 245/600
# Generator Loss: 3.5199, Discriminator Loss: 0.0744
#
# Epoch 246/600
# Generator Loss: 2.0372, Discriminator Loss: 0.3066
#
# Epoch 247/600
# Generator Loss: 2.0607, Discriminator Loss: 0.1788
#
# Epoch 248/600
# Generator Loss: 4.2145, Discriminator Loss: 0.2847
#
# Epoch 249/600
# Generator Loss: 2.2626, Discriminator Loss: 0.1474
#
# Epoch 250/600
# Generator Loss: 5.2350, Discriminator Loss: 0.4448
#
# Epoch 251/600
# Generator Loss: 0.5198, Discriminator Loss: 1.1823
#
# Epoch 252/600
# Generator Loss: 2.4843, Discriminator Loss: 0.1935
#
# Epoch 253/600
# Generator Loss: 0.4267, Discriminator Loss: 1.2812
#
# Epoch 254/600
# Generator Loss: 0.5765, Discriminator Loss: 1.0960
#
# Epoch 255/600
# Generator Loss: 2.8555, Discriminator Loss: 0.2434
#
# Epoch 256/600
# Generator Loss: 0.3776, Discriminator Loss: 1.3658
#
# Epoch 257/600
# Generator Loss: 2.2280, Discriminator Loss: 0.1667
#
# Epoch 258/600
# Generator Loss: 3.0215, Discriminator Loss: 0.2794
#
# Epoch 259/600
# Generator Loss: 4.4620, Discriminator Loss: 0.5309
#
# Epoch 260/600
# Generator Loss: 1.9676, Discriminator Loss: 0.2311
#
# Epoch 261/600
# Generator Loss: 2.6105, Discriminator Loss: 0.2463
#
# Epoch 262/600
# Generator Loss: 4.4470, Discriminator Loss: 0.3136
#
# Epoch 263/600
# Generator Loss: 1.9503, Discriminator Loss: 0.3414
#
# Epoch 264/600
# Generator Loss: 3.8304, Discriminator Loss: 0.4152
#
# Epoch 265/600
# Generator Loss: 3.3666, Discriminator Loss: 0.0783
#
# Epoch 266/600
# Generator Loss: 3.6827, Discriminator Loss: 0.2265
#
# Epoch 267/600
# Generator Loss: 0.8023, Discriminator Loss: 0.7985
#
# Epoch 268/600
# Generator Loss: 1.6843, Discriminator Loss: 0.3206
#
# Epoch 269/600
# Generator Loss: 2.6306, Discriminator Loss: 0.1338
#
# Epoch 270/600
# Generator Loss: 2.5449, Discriminator Loss: 0.2133
#
# Epoch 271/600
# Generator Loss: 2.5150, Discriminator Loss: 0.2369
#
# Epoch 272/600
# Generator Loss: 5.3978, Discriminator Loss: 0.2749
#
# Epoch 273/600
# Generator Loss: 1.0441, Discriminator Loss: 0.6434
#
# Epoch 274/600
# Generator Loss: 1.0331, Discriminator Loss: 0.5586
#
# Epoch 275/600
# Generator Loss: 3.9117, Discriminator Loss: 0.0731
#
# Epoch 276/600
# Generator Loss: 5.2669, Discriminator Loss: 0.5522
#
# Epoch 277/600
# Generator Loss: 1.9790, Discriminator Loss: 0.1929
#
# Epoch 278/600
# Generator Loss: 3.4546, Discriminator Loss: 0.1026
#
# Epoch 279/600
# Generator Loss: 5.0743, Discriminator Loss: 0.3163
#
# Epoch 280/600
# Generator Loss: 4.4141, Discriminator Loss: 0.4074
#
# Epoch 281/600
# Generator Loss: 3.7787, Discriminator Loss: 0.0597
#
# Epoch 282/600
# Generator Loss: 4.3493, Discriminator Loss: 0.1098
#
# Epoch 283/600
# Generator Loss: 3.5631, Discriminator Loss: 0.3801
#
# Epoch 284/600
# Generator Loss: 1.1755, Discriminator Loss: 0.4812
#
# Epoch 285/600
# Generator Loss: 3.9821, Discriminator Loss: 0.3881
#
# Epoch 286/600
# Generator Loss: 5.0380, Discriminator Loss: 0.7011
#
# Epoch 287/600
# Generator Loss: 2.6893, Discriminator Loss: 0.1077
#
# Epoch 288/600
# Generator Loss: 2.6326, Discriminator Loss: 0.1311
#
# Epoch 289/600
# Generator Loss: 2.8578, Discriminator Loss: 0.1381
#
# Epoch 290/600
# Generator Loss: 2.6507, Discriminator Loss: 0.1885
#
# Epoch 291/600
# Generator Loss: 1.9659, Discriminator Loss: 0.2315
#
# Epoch 292/600
# Generator Loss: 2.1794, Discriminator Loss: 0.1808
#
# Epoch 293/600
# Generator Loss: 4.6359, Discriminator Loss: 0.0514
#
# Epoch 294/600
# Generator Loss: 1.3342, Discriminator Loss: 0.4325
#
# Epoch 295/600
# Generator Loss: 2.4431, Discriminator Loss: 0.4372
#
# Epoch 296/600
# Generator Loss: 1.5002, Discriminator Loss: 0.3674
#
# Epoch 297/600
# Generator Loss: 2.6021, Discriminator Loss: 0.1596
#
# Epoch 298/600
# Generator Loss: 0.6946, Discriminator Loss: 1.0186
#
# Epoch 299/600
# Generator Loss: 4.0260, Discriminator Loss: 0.0329
#
# Epoch 300/600
# Generator Loss: 3.5530, Discriminator Loss: 0.1720
#
# Epoch 301/600
# Generator Loss: 2.4560, Discriminator Loss: 0.1931
#
# Epoch 302/600
# Generator Loss: 3.5296, Discriminator Loss: 0.1100
#
# Epoch 303/600
# Generator Loss: 3.5961, Discriminator Loss: 0.3547
#
# Epoch 304/600
# Generator Loss: 2.0349, Discriminator Loss: 0.3287
#
# Epoch 305/600
# Generator Loss: 1.8757, Discriminator Loss: 0.2709
#
# Epoch 306/600
# Generator Loss: 3.6200, Discriminator Loss: 0.0737
#
# Epoch 307/600
# Generator Loss: 1.8358, Discriminator Loss: 0.2929
#
# Epoch 308/600
# Generator Loss: 3.2344, Discriminator Loss: 0.2705
#
# Epoch 309/600
# Generator Loss: 4.6646, Discriminator Loss: 0.1914
#
# Epoch 310/600
# Generator Loss: 4.1139, Discriminator Loss: 0.2205
#
# Epoch 311/600
# Generator Loss: 3.6977, Discriminator Loss: 0.0770
#
# Epoch 312/600
# Generator Loss: 4.0218, Discriminator Loss: 1.5988
#
# Epoch 313/600
# Generator Loss: 1.4433, Discriminator Loss: 0.3517
#
# Epoch 314/600
# Generator Loss: 4.3078, Discriminator Loss: 0.1864
#
# Epoch 315/600
# Generator Loss: 5.0229, Discriminator Loss: 1.2578
#
# Epoch 316/600
# Generator Loss: 4.2325, Discriminator Loss: 0.1491
#
# Epoch 317/600
# Generator Loss: 3.3845, Discriminator Loss: 0.2314
#
# Epoch 318/600
# Generator Loss: 2.7123, Discriminator Loss: 0.1128
#
# Epoch 319/600
# Generator Loss: 4.4972, Discriminator Loss: 0.1070
#
# Epoch 320/600
# Generator Loss: 2.0795, Discriminator Loss: 0.1823
#
# Epoch 321/600
# Generator Loss: 3.6042, Discriminator Loss: 0.1807
#
# Epoch 322/600
# Generator Loss: 3.7836, Discriminator Loss: 0.0761
#
# Epoch 323/600
# Generator Loss: 1.1706, Discriminator Loss: 0.4937
#
# Epoch 324/600
# Generator Loss: 3.7447, Discriminator Loss: 0.0599
#
# Epoch 325/600
# Generator Loss: 1.0655, Discriminator Loss: 0.6859
#
# Epoch 326/600
# Generator Loss: 4.2833, Discriminator Loss: 0.0309
#
# Epoch 327/600
# Generator Loss: 6.3791, Discriminator Loss: 1.0842
#
# Epoch 328/600
# Generator Loss: 4.1700, Discriminator Loss: 0.5557
#
# Epoch 329/600
# Generator Loss: 4.1853, Discriminator Loss: 0.4154
#
# Epoch 330/600
# Generator Loss: 1.2964, Discriminator Loss: 0.4323
#
# Epoch 331/600
# Generator Loss: 5.6641, Discriminator Loss: 0.1286
#
# Epoch 332/600
# Generator Loss: 3.8612, Discriminator Loss: 0.0431
#
# Epoch 333/600
# Generator Loss: 3.5435, Discriminator Loss: 0.4396
#
# Epoch 334/600
# Generator Loss: 1.3708, Discriminator Loss: 0.4337
#
# Epoch 335/600
# Generator Loss: 3.4899, Discriminator Loss: 0.0862
#
# Epoch 336/600
# Generator Loss: 3.8563, Discriminator Loss: 0.2524
#
# Epoch 337/600
# Generator Loss: 3.2586, Discriminator Loss: 0.0756
#
# Epoch 338/600
# Generator Loss: 2.3617, Discriminator Loss: 0.2055
#
# Epoch 339/600
# Generator Loss: 2.1397, Discriminator Loss: 0.1970
#
# Epoch 340/600
# Generator Loss: 4.3469, Discriminator Loss: 0.4054
#
# Epoch 341/600
# Generator Loss: 3.4074, Discriminator Loss: 0.5063
#
# Epoch 342/600
# Generator Loss: 1.6285, Discriminator Loss: 0.3522
#
# Epoch 343/600
# Generator Loss: 2.5421, Discriminator Loss: 0.2552
#
# Epoch 344/600
# Generator Loss: 1.3026, Discriminator Loss: 0.4137
#
# Epoch 345/600
# Generator Loss: 2.1025, Discriminator Loss: 0.2085
#
# Epoch 346/600
# Generator Loss: 4.1846, Discriminator Loss: 0.0851
#
# Epoch 347/600
# Generator Loss: 3.2416, Discriminator Loss: 0.3249
#
# Epoch 348/600
# Generator Loss: 2.0155, Discriminator Loss: 0.2056
#
# Epoch 349/600
# Generator Loss: 4.3479, Discriminator Loss: 0.5969
#
# Epoch 350/600
# Generator Loss: 3.1208, Discriminator Loss: 0.1302
#
# Epoch 351/600
# Generator Loss: 3.6065, Discriminator Loss: 0.3241
#
# Epoch 352/600
# Generator Loss: 4.1633, Discriminator Loss: 0.4011
#
# Epoch 353/600
# Generator Loss: 6.0643, Discriminator Loss: 1.1766
#
# Epoch 354/600
# Generator Loss: 2.1464, Discriminator Loss: 0.2312
#
# Epoch 355/600
# Generator Loss: 1.9770, Discriminator Loss: 0.2679
#
# Epoch 356/600
# Generator Loss: 4.3381, Discriminator Loss: 0.1050
#
# Epoch 357/600
# Generator Loss: 1.9417, Discriminator Loss: 0.3994
#
# Epoch 358/600
# Generator Loss: 3.0720, Discriminator Loss: 0.1304
#
# Epoch 359/600
# Generator Loss: 1.0635, Discriminator Loss: 0.7283
#
# Epoch 360/600
# Generator Loss: 3.7463, Discriminator Loss: 0.1069
#
# Epoch 361/600
# Generator Loss: 2.6441, Discriminator Loss: 0.1342
#
# Epoch 362/600
# Generator Loss: 2.7782, Discriminator Loss: 0.1324
#
# Epoch 363/600
# Generator Loss: 2.3166, Discriminator Loss: 0.1735
#
# Epoch 364/600
# Generator Loss: 1.8760, Discriminator Loss: 0.2906
#
# Epoch 365/600
# Generator Loss: 2.1457, Discriminator Loss: 0.2123
#
# Epoch 366/600
# Generator Loss: 3.1920, Discriminator Loss: 0.2480
#
# Epoch 367/600
# Generator Loss: 2.7838, Discriminator Loss: 0.3045
#
# Epoch 368/600
# Generator Loss: 3.4961, Discriminator Loss: 0.3309
#
# Epoch 369/600
# Generator Loss: 4.8245, Discriminator Loss: 0.1311
#
# Epoch 370/600
# Generator Loss: 1.6895, Discriminator Loss: 0.2875
#
# Epoch 371/600
# Generator Loss: 2.2459, Discriminator Loss: 0.2072
#
# Epoch 372/600
# Generator Loss: 2.1543, Discriminator Loss: 0.3002
#
# Epoch 373/600
# Generator Loss: 3.0555, Discriminator Loss: 0.1899
#
# Epoch 374/600
# Generator Loss: 2.8175, Discriminator Loss: 0.0919
#
# Epoch 375/600
# Generator Loss: 2.9301, Discriminator Loss: 0.1010
#
# Epoch 376/600
# Generator Loss: 1.0533, Discriminator Loss: 0.5675
#
# Epoch 377/600
# Generator Loss: 4.8343, Discriminator Loss: 0.8526
#
# Epoch 378/600
# Generator Loss: 3.6805, Discriminator Loss: 1.2146
#
# Epoch 379/600
# Generator Loss: 2.0195, Discriminator Loss: 0.2194
#
# Epoch 380/600
# Generator Loss: 2.7074, Discriminator Loss: 0.1777
#
# Epoch 381/600
# Generator Loss: 3.8224, Discriminator Loss: 1.2103
#
# Epoch 382/600
# Generator Loss: 0.3456, Discriminator Loss: 1.4831
#
# Epoch 383/600
# Generator Loss: 3.9052, Discriminator Loss: 0.0793
#
# Epoch 384/600
# Generator Loss: 3.4097, Discriminator Loss: 0.3871
#
# Epoch 385/600
# Generator Loss: 1.0719, Discriminator Loss: 0.5383
#
# Epoch 386/600
# Generator Loss: 2.5714, Discriminator Loss: 0.4415
#
# Epoch 387/600
# Generator Loss: 3.7718, Discriminator Loss: 0.7053
#
# Epoch 388/600
# Generator Loss: 0.5391, Discriminator Loss: 1.0257
#
# Epoch 389/600
# Generator Loss: 3.2213, Discriminator Loss: 0.1792
#
# Epoch 390/600
# Generator Loss: 1.8283, Discriminator Loss: 0.3551
#
# Epoch 391/600
# Generator Loss: 2.7338, Discriminator Loss: 0.1050
#
# Epoch 392/600
# Generator Loss: 3.4585, Discriminator Loss: 0.0600
#
# Epoch 393/600
# Generator Loss: 2.6393, Discriminator Loss: 0.1176
#
# Epoch 394/600
# Generator Loss: 0.4319, Discriminator Loss: 1.2562
#
# Epoch 395/600
# Generator Loss: 2.6311, Discriminator Loss: 0.1861
#
# Epoch 396/600
# Generator Loss: 3.7024, Discriminator Loss: 0.0952
#
# Epoch 397/600
# Generator Loss: 1.8454, Discriminator Loss: 0.2469
#
# Epoch 398/600
# Generator Loss: 3.1444, Discriminator Loss: 0.0993
#
# Epoch 399/600
# Generator Loss: 3.3099, Discriminator Loss: 0.4621
#
# Epoch 400/600
# Generator Loss: 4.1806, Discriminator Loss: 0.5796
#
# Epoch 401/600
# Generator Loss: 4.1295, Discriminator Loss: 0.0304
#
# Epoch 402/600
# Generator Loss: 2.7686, Discriminator Loss: 0.8777
#
# Epoch 403/600
# Generator Loss: 2.0691, Discriminator Loss: 0.2248
#
# Epoch 404/600
# Generator Loss: 5.5006, Discriminator Loss: 1.1756
#
# Epoch 405/600
# Generator Loss: 3.1400, Discriminator Loss: 0.3444
#
# Epoch 406/600
# Generator Loss: 3.7292, Discriminator Loss: 0.0597
#
# Epoch 407/600
# Generator Loss: 5.4155, Discriminator Loss: 0.2761
#
# Epoch 408/600
# Generator Loss: 4.0525, Discriminator Loss: 0.1175
#
# Epoch 409/600
# Generator Loss: 2.6140, Discriminator Loss: 0.2074
#
# Epoch 410/600
# Generator Loss: 2.0812, Discriminator Loss: 0.2358
#
# Epoch 411/600
# Generator Loss: 1.6919, Discriminator Loss: 0.3074
#
# Epoch 412/600
# Generator Loss: 2.9373, Discriminator Loss: 0.0894
#
# Epoch 413/600
# Generator Loss: 4.1528, Discriminator Loss: 0.3029
#
# Epoch 414/600
# Generator Loss: 4.4297, Discriminator Loss: 0.1540
#
# Epoch 415/600
# Generator Loss: 2.4838, Discriminator Loss: 0.1362
#
# Epoch 416/600
# Generator Loss: 1.1602, Discriminator Loss: 0.5540
#
# Epoch 417/600
# Generator Loss: 3.8059, Discriminator Loss: 0.0891
#
# Epoch 418/600
# Generator Loss: 1.2673, Discriminator Loss: 0.4236
#
# Epoch 419/600
# Generator Loss: 2.8390, Discriminator Loss: 0.1850
#
# Epoch 420/600
# Generator Loss: 5.2327, Discriminator Loss: 0.9673
#
# Epoch 421/600
# Generator Loss: 5.6039, Discriminator Loss: 0.7210
#
# Epoch 422/600
# Generator Loss: 2.0162, Discriminator Loss: 0.2316
#
# Epoch 423/600
# Generator Loss: 1.6745, Discriminator Loss: 0.2994
#
# Epoch 424/600
# Generator Loss: 4.1628, Discriminator Loss: 0.1441
#
# Epoch 425/600
# Generator Loss: 7.0974, Discriminator Loss: 0.1002
#
# Epoch 426/600
# Generator Loss: 0.7217, Discriminator Loss: 0.8057
#
# Epoch 427/600
# Generator Loss: 2.6730, Discriminator Loss: 0.1337
#
# Epoch 428/600
# Generator Loss: 3.2087, Discriminator Loss: 0.3831
#
# Epoch 429/600
# Generator Loss: 3.6269, Discriminator Loss: 0.0876
#
# Epoch 430/600
# Generator Loss: 2.6195, Discriminator Loss: 0.1183
#
# Epoch 431/600
# Generator Loss: 1.5849, Discriminator Loss: 0.3038
#
# Epoch 432/600
# Generator Loss: 1.7375, Discriminator Loss: 0.3662
#
# Epoch 433/600
# Generator Loss: 0.3411, Discriminator Loss: 1.5121
#
# Epoch 434/600
# Generator Loss: 3.2221, Discriminator Loss: 0.1516
#
# Epoch 435/600
# Generator Loss: 2.8683, Discriminator Loss: 0.4023
#
# Epoch 436/600
# Generator Loss: 0.5236, Discriminator Loss: 1.1537
#
# Epoch 437/600
# Generator Loss: 3.4636, Discriminator Loss: 0.0827
#
# Epoch 438/600
# Generator Loss: 2.3603, Discriminator Loss: 0.5747
#
# Epoch 439/600
# Generator Loss: 0.9286, Discriminator Loss: 0.6351
#
# Epoch 440/600
# Generator Loss: 3.1752, Discriminator Loss: 0.0713
#
# Epoch 441/600
# Generator Loss: 2.9908, Discriminator Loss: 0.2566
#
# Epoch 442/600
# Generator Loss: 0.3602, Discriminator Loss: 1.4581
#
# Epoch 443/600
# Generator Loss: 1.9817, Discriminator Loss: 0.2210
#
# Epoch 444/600
# Generator Loss: 0.9962, Discriminator Loss: 0.6546
#
# Epoch 445/600
# Generator Loss: 1.7289, Discriminator Loss: 0.2501
#
# Epoch 446/600
# Generator Loss: 2.0871, Discriminator Loss: 0.3021
#
# Epoch 447/600
# Generator Loss: 1.6805, Discriminator Loss: 0.2608
#
# Epoch 448/600
# Generator Loss: 3.6961, Discriminator Loss: 0.4301
#
# Epoch 449/600
# Generator Loss: 2.3983, Discriminator Loss: 0.1444
#
# Epoch 450/600
# Generator Loss: 1.3524, Discriminator Loss: 0.4143
#
# Epoch 451/600
# Generator Loss: 1.9334, Discriminator Loss: 0.2437
#
# Epoch 452/600
# Generator Loss: 1.8410, Discriminator Loss: 0.2270
#
# Epoch 453/600
# Generator Loss: 2.1183, Discriminator Loss: 0.3775
#
# Epoch 454/600
# Generator Loss: 2.1703, Discriminator Loss: 0.2399
#
# Epoch 455/600
# Generator Loss: 3.5777, Discriminator Loss: 0.1471
#
# Epoch 456/600
# Generator Loss: 4.9498, Discriminator Loss: 0.7543
#
# Epoch 457/600
# Generator Loss: 1.5069, Discriminator Loss: 0.4252
#
# Epoch 458/600
# Generator Loss: 1.9373, Discriminator Loss: 0.2286
#
# Epoch 459/600
# Generator Loss: 1.9613, Discriminator Loss: 0.2258
#
# Epoch 460/600
# Generator Loss: 2.5135, Discriminator Loss: 0.1080
#
# Epoch 461/600
# Generator Loss: 5.0273, Discriminator Loss: 0.3442
#
# Epoch 462/600
# Generator Loss: 1.3665, Discriminator Loss: 0.5075
#
# Epoch 463/600
# Generator Loss: 4.3143, Discriminator Loss: 0.0319
#
# Epoch 464/600
# Generator Loss: 6.1837, Discriminator Loss: 0.0683
#
# Epoch 465/600
# Generator Loss: 2.5180, Discriminator Loss: 0.1933
#
# Epoch 466/600
# Generator Loss: 5.3887, Discriminator Loss: 0.0466
#
# Epoch 467/600
# Generator Loss: 2.8682, Discriminator Loss: 0.1044
#
# Epoch 468/600
# Generator Loss: 1.7102, Discriminator Loss: 0.2601
#
# Epoch 469/600
# Generator Loss: 0.2098, Discriminator Loss: 2.1143
#
# Epoch 470/600
# Generator Loss: 5.2046, Discriminator Loss: 0.2138
#
# Epoch 471/600
# Generator Loss: 5.0439, Discriminator Loss: 0.1785
#
# Epoch 472/600
# Generator Loss: 4.3586, Discriminator Loss: 0.4737
#
# Epoch 473/600
# Generator Loss: 3.4291, Discriminator Loss: 0.6275
#
# Epoch 474/600
# Generator Loss: 1.5552, Discriminator Loss: 0.3744
#
# Epoch 475/600
# Generator Loss: 3.3473, Discriminator Loss: 0.3173
#
# Epoch 476/600
# Generator Loss: 3.7713, Discriminator Loss: 0.1371
#
# Epoch 477/600
# Generator Loss: 3.9935, Discriminator Loss: 0.1874
#
# Epoch 478/600
# Generator Loss: 3.9461, Discriminator Loss: 0.0473
#
# Epoch 479/600
# Generator Loss: 2.2467, Discriminator Loss: 0.3514
#
# Epoch 480/600
# Generator Loss: 2.8320, Discriminator Loss: 0.1452
#
# Epoch 481/600
# Generator Loss: 3.5307, Discriminator Loss: 0.0727
#
# Epoch 482/600
# Generator Loss: 3.3728, Discriminator Loss: 0.1514
#
# Epoch 483/600
# Generator Loss: 3.4809, Discriminator Loss: 0.2198
#
# Epoch 484/600
# Generator Loss: 2.8925, Discriminator Loss: 0.5294
#
# Epoch 485/600
# Generator Loss: 1.5900, Discriminator Loss: 0.3075
#
# Epoch 486/600
# Generator Loss: 2.9627, Discriminator Loss: 0.1244
#
# Epoch 487/600
# Generator Loss: 3.0449, Discriminator Loss: 0.2813
#
# Epoch 488/600
# Generator Loss: 3.9837, Discriminator Loss: 0.0379
#
# Epoch 489/600
# Generator Loss: 1.6159, Discriminator Loss: 0.3784
#
# Epoch 490/600
# Generator Loss: 4.1091, Discriminator Loss: 0.1774
#
# Epoch 491/600
# Generator Loss: 0.7509, Discriminator Loss: 0.8311
#
# Epoch 492/600
# Generator Loss: 1.8671, Discriminator Loss: 0.2696
#
# Epoch 493/600
# Generator Loss: 1.2153, Discriminator Loss: 0.4791
#
# Epoch 494/600
# Generator Loss: 4.8173, Discriminator Loss: 0.0524
#
# Epoch 495/600
# Generator Loss: 1.3131, Discriminator Loss: 0.4138
#
# Epoch 496/600
# Generator Loss: 2.5260, Discriminator Loss: 0.1781
#
# Epoch 497/600
# Generator Loss: 1.6081, Discriminator Loss: 0.3358
#
# Epoch 498/600
# Generator Loss: 1.2606, Discriminator Loss: 0.5321
#
# Epoch 499/600
# Generator Loss: 3.0423, Discriminator Loss: 0.0856
#
# Epoch 500/600
# Generator Loss: 1.1084, Discriminator Loss: 0.6008
#
# Epoch 501/600
# Generator Loss: 2.3389, Discriminator Loss: 0.1571
#
# Epoch 502/600
# Generator Loss: 2.8040, Discriminator Loss: 0.1947
#
# Epoch 503/600
# Generator Loss: 1.5888, Discriminator Loss: 0.3852
#
# Epoch 504/600
# Generator Loss: 4.0169, Discriminator Loss: 0.1410
#
# Epoch 505/600
# Generator Loss: 1.0458, Discriminator Loss: 0.5870
#
# Epoch 506/600
# Generator Loss: 4.4191, Discriminator Loss: 0.3885
#
# Epoch 507/600
# Generator Loss: 3.7536, Discriminator Loss: 0.0521
#
# Epoch 508/600
# Generator Loss: 4.3287, Discriminator Loss: 0.7512
#
# Epoch 509/600
# Generator Loss: 4.4417, Discriminator Loss: 0.1228
#
# Epoch 510/600
# Generator Loss: 4.9838, Discriminator Loss: 1.0301
#
# Epoch 511/600
# Generator Loss: 2.5341, Discriminator Loss: 0.1530
#
# Epoch 512/600
# Generator Loss: 2.8266, Discriminator Loss: 0.4376
#
# Epoch 513/600
# Generator Loss: 1.6006, Discriminator Loss: 0.3426
#
# Epoch 514/600
# Generator Loss: 5.0577, Discriminator Loss: 0.3280
#
# Epoch 515/600
# Generator Loss: 2.2010, Discriminator Loss: 0.1688
#
# Epoch 516/600
# Generator Loss: 5.0476, Discriminator Loss: 0.1387
#
# Epoch 517/600
# Generator Loss: 5.7096, Discriminator Loss: 0.2630
#
# Epoch 518/600
# Generator Loss: 4.7442, Discriminator Loss: 0.6072
#
# Epoch 519/600
# Generator Loss: 5.6311, Discriminator Loss: 0.0641
#
# Epoch 520/600
# Generator Loss: 4.3998, Discriminator Loss: 0.0508
#
# Epoch 521/600
# Generator Loss: 0.8906, Discriminator Loss: 0.7043
#
# Epoch 522/600
# Generator Loss: 3.0224, Discriminator Loss: 0.7339
#
# Epoch 523/600
# Generator Loss: 2.1664, Discriminator Loss: 0.2876
#
# Epoch 524/600
# Generator Loss: 6.1526, Discriminator Loss: 0.2579
#
# Epoch 525/600
# Generator Loss: 2.8982, Discriminator Loss: 0.1352
#
# Epoch 526/600
# Generator Loss: 1.5999, Discriminator Loss: 0.3222
#
# Epoch 527/600
# Generator Loss: 1.8612, Discriminator Loss: 0.2422
#
# Epoch 528/600
# Generator Loss: 2.6288, Discriminator Loss: 0.1313
#
# Epoch 529/600
# Generator Loss: 2.8087, Discriminator Loss: 0.2615
#
# Epoch 530/600
# Generator Loss: 5.2250, Discriminator Loss: 0.3195
#
# Epoch 531/600
# Generator Loss: 0.5813, Discriminator Loss: 1.0734
#
# Epoch 532/600
# Generator Loss: 1.9922, Discriminator Loss: 0.2857
#
# Epoch 533/600
# Generator Loss: 4.3740, Discriminator Loss: 0.8490
#
# Epoch 534/600
# Generator Loss: 2.5309, Discriminator Loss: 0.3892
#
# Epoch 535/600
# Generator Loss: 4.1162, Discriminator Loss: 0.1240
#
# Epoch 536/600
# Generator Loss: 1.2300, Discriminator Loss: 0.4459
#
# Epoch 537/600
# Generator Loss: 1.3805, Discriminator Loss: 0.5226
#
# Epoch 538/600
# Generator Loss: 2.1589, Discriminator Loss: 0.2398
#
# Epoch 539/600
# Generator Loss: 2.8298, Discriminator Loss: 0.2322
#
# Epoch 540/600
# Generator Loss: 0.4806, Discriminator Loss: 1.2388
#
# Epoch 541/600
# Generator Loss: 3.7288, Discriminator Loss: 0.4783
#
# Epoch 542/600
# Generator Loss: 1.8979, Discriminator Loss: 0.2653
#
# Epoch 543/600
# Generator Loss: 3.4572, Discriminator Loss: 0.2915
#
# Epoch 544/600
# Generator Loss: 3.3461, Discriminator Loss: 0.3454
#
# Epoch 545/600
# Generator Loss: 3.2983, Discriminator Loss: 0.2361
#
# Epoch 546/600
# Generator Loss: 1.3774, Discriminator Loss: 0.4598
#
# Epoch 547/600
# Generator Loss: 1.0161, Discriminator Loss: 0.5757
#
# Epoch 548/600
# Generator Loss: 1.6329, Discriminator Loss: 0.3181
#
# Epoch 549/600
# Generator Loss: 4.3648, Discriminator Loss: 0.1837
#
# Epoch 550/600
# Generator Loss: 6.1465, Discriminator Loss: 0.9163
#
# Epoch 551/600
# Generator Loss: 2.6295, Discriminator Loss: 0.2707
#
# Epoch 552/600
# Generator Loss: 1.7284, Discriminator Loss: 0.2979
#
# Epoch 553/600
# Generator Loss: 2.4436, Discriminator Loss: 0.3187
#
# Epoch 554/600
# Generator Loss: 2.5958, Discriminator Loss: 0.1051
#
# Epoch 555/600
# Generator Loss: 5.2058, Discriminator Loss: 0.0191
#
# Epoch 556/600
# Generator Loss: 1.8501, Discriminator Loss: 0.2655
#
# Epoch 557/600
# Generator Loss: 5.5870, Discriminator Loss: 0.9835
#
# Epoch 558/600
# Generator Loss: 2.5000, Discriminator Loss: 0.1291
#
# Epoch 559/600
# Generator Loss: 2.4938, Discriminator Loss: 0.1595
#
# Epoch 560/600
# Generator Loss: 3.0421, Discriminator Loss: 0.1081
#
# Epoch 561/600
# Generator Loss: 2.3743, Discriminator Loss: 0.1625
#
# Epoch 562/600
# Generator Loss: 3.4881, Discriminator Loss: 0.0629
#
# Epoch 563/600
# Generator Loss: 2.9730, Discriminator Loss: 0.3703
#
# Epoch 564/600
# Generator Loss: 3.4154, Discriminator Loss: 0.1204
#
# Epoch 565/600
# Generator Loss: 6.0135, Discriminator Loss: 1.4125
#
# Epoch 566/600
# Generator Loss: 1.4351, Discriminator Loss: 0.3755
#
# Epoch 567/600
# Generator Loss: 2.4611, Discriminator Loss: 0.1715
#
# Epoch 568/600
# Generator Loss: 1.3742, Discriminator Loss: 0.5405
#
# Epoch 569/600
# Generator Loss: 5.0942, Discriminator Loss: 1.9192
#
# Epoch 570/600
# Generator Loss: 5.6284, Discriminator Loss: 2.0041
#
# Epoch 571/600
# Generator Loss: 1.6740, Discriminator Loss: 0.2829
#
# Epoch 572/600
# Generator Loss: 3.7573, Discriminator Loss: 0.4089
#
# Epoch 573/600
# Generator Loss: 4.7640, Discriminator Loss: 0.4678
#
# Epoch 574/600
# Generator Loss: 2.0707, Discriminator Loss: 0.2422
#
# Epoch 575/600
# Generator Loss: 3.0497, Discriminator Loss: 0.0785
#
# Epoch 576/600
# Generator Loss: 2.9922, Discriminator Loss: 0.1313
#
# Epoch 577/600
# Generator Loss: 0.6811, Discriminator Loss: 0.9748
#
# Epoch 578/600
# Generator Loss: 2.3643, Discriminator Loss: 0.1843
#
# Epoch 579/600
# Generator Loss: 4.7178, Discriminator Loss: 0.1465
#
# Epoch 580/600
# Generator Loss: 1.8150, Discriminator Loss: 0.2843
#
# Epoch 581/600
# Generator Loss: 3.4603, Discriminator Loss: 0.0761
#
# Epoch 582/600
# Generator Loss: 1.8743, Discriminator Loss: 0.2654
#
# Epoch 583/600
# Generator Loss: 2.4561, Discriminator Loss: 0.4442
#
# Epoch 584/600
# Generator Loss: 5.0008, Discriminator Loss: 0.1908
#
# Epoch 585/600
# Generator Loss: 2.1686, Discriminator Loss: 0.1985
#
# Epoch 586/600
# Generator Loss: 6.2515, Discriminator Loss: 0.1932
#
# Epoch 587/600
# Generator Loss: 2.9370, Discriminator Loss: 0.1286
#
# Epoch 588/600
# Generator Loss: 5.1983, Discriminator Loss: 2.4424
#
# Epoch 589/600
# Generator Loss: 3.1419, Discriminator Loss: 0.1027
#
# Epoch 590/600
# Generator Loss: 0.8489, Discriminator Loss: 0.9933
#
# Epoch 591/600
# Generator Loss: 2.7497, Discriminator Loss: 0.1046
#
# Epoch 592/600
# Generator Loss: 1.6070, Discriminator Loss: 0.3296
#
# Epoch 593/600
# Generator Loss: 1.5291, Discriminator Loss: 0.4115
#
# Epoch 594/600
# Generator Loss: 1.8596, Discriminator Loss: 0.2514
#
# Epoch 595/600
# Generator Loss: 2.8956, Discriminator Loss: 0.0840
#
# Epoch 596/600
# Generator Loss: 4.3338, Discriminator Loss: 0.3371
#
# Epoch 597/600
# Generator Loss: 2.0017, Discriminator Loss: 0.1943
#
# Epoch 598/600
# Generator Loss: 3.0592, Discriminator Loss: 0.0923
#
# Epoch 599/600
# Generator Loss: 2.1401, Discriminator Loss: 0.2940
#
# Epoch 600/600
# Generator Loss: 2.0996, Discriminator Loss: 0.2748
#                       Generated Images at Epoch 600

# %% [markdown]
# **FID aTTENTION**

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# Load and preprocess a single image
def load_image(image_path, img_size=(128, 128)):  # Higher resolution for better pixel quality
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, img_size, method='bicubic')  # Use bicubic for smoother resizing
    img = img / 255.0
    return img

# Gaussian kernel generator
def gaussian_kernel(size: int, sigma: float):
    x = tf.range(-size // 2 + 1, size // 2 + 1, dtype=tf.float32)
    x = tf.math.exp(-(x**2) / (2 * sigma**2))
    kernel_1d = x / tf.reduce_sum(x)
    kernel_2d = tf.tensordot(kernel_1d, kernel_1d, axes=0)
    kernel_2d = kernel_2d[:, :, tf.newaxis, tf.newaxis]
    kernel_2d = tf.repeat(kernel_2d, repeats=3, axis=2)
    return kernel_2d

# Apply 10% blur (light blending)
def apply_partial_blur(image, blur_kernel=5, sigma=1.0, blur_ratio=0.1):
    image_batch = tf.expand_dims(image, axis=0)
    kernel = gaussian_kernel(blur_kernel, sigma)
    blurred = tf.nn.depthwise_conv2d(image_batch, kernel, strides=[1, 1, 1, 1], padding='SAME')
    blurred = tf.squeeze(blurred, axis=0)
    return (1 - blur_ratio) * image + blur_ratio * blurred

# Image paths
image_paths = [
    '/kaggle/input/iamgestotest/762maroonkurta.jpg',
    '/kaggle/input/iamgestotest/2000white sports.jpg',
    '/kaggle/input/iamgestotest/1500men snadals.jpg',
    '/kaggle/input/rtuivxhhgj/green.jpg',
    '/kaggle/input/rtuivxhhgj/2602beige.jpg'
]

# Load and apply 10% blur
blurred_images = [apply_partial_blur(load_image(p)) for p in image_paths]

# Plot blurred images
fig, axes = plt.subplots(1, len(blurred_images), figsize=(12,6))
for i, img in enumerate(blurred_images):
    axes[i].imshow(img)
    axes[i].axis('off')

plt.tight_layout()
plt.show()


import numpy as np
import tensorflow as tf
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from scipy.linalg import sqrtm
import matplotlib.pyplot as plt

# Function to preprocess images for InceptionV3 (resize to 299x299 and normalize)
def preprocess_images(images):
    images_resized = tf.image.resize(images, (299, 299))  # Resize to 299x299 for InceptionV3
    return preprocess_input(images_resized)  # Preprocess images for InceptionV3

# Function to load and preprocess a single image (real or generated)
def load_image(image_path, img_size=(64, 64)):
    img = tf.io.read_file(image_path)  # Read the image file
    img = tf.image.decode_jpeg(img, channels=3)  # Decode as JPEG
    img = tf.image.resize(img, img_size)  # Resize to the input size (64x64 for this case)
    img = img / 255.0  # Normalize the image to [0, 1]
    return img

# FID Calculation function
def calculate_fid(real_images, generated_images):
    model = InceptionV3(include_top=False, pooling='avg', input_shape=(299, 299, 3))

    # Preprocess images
    real_images = preprocess_images(real_images)
    generated_images = preprocess_images(generated_images)

    # Extract features (activations) from InceptionV3
    real_act = model(real_images)
    gen_act = model(generated_images)

    # Calculate the mean and covariance of activations
    mu1, sigma1 = np.mean(real_act, axis=0), np.cov(real_act, rowvar=False)
    mu2, sigma2 = np.mean(gen_act, axis=0), np.cov(gen_act, rowvar=False)

    # Calculate the FID score
    ssdiff = np.sum((mu1 - mu2) ** 2.0)
    covmean, _ = sqrtm(sigma1.dot(sigma2), disp=False)

    # Check if the sqrtm produces complex values, and take the real part if necessary
    if np.iscomplexobj(covmean):
        covmean = covmean.real

    fid = ssdiff + np.trace(sigma1 + sigma2 - 2.0 * covmean)
    return fid

# Inception Score Calculation function
def calculate_inception_score(images, splits=10):
    model = InceptionV3(include_top=True, weights='imagenet')
    images_resized = preprocess_images(images)
    preds = model(images_resized).numpy()

    scores = []
    N = preds.shape[0]
    split_size = N // splits
    for i in range(splits):
        part = preds[i * split_size: (i + 1) * split_size]
        py = np.mean(part, axis=0)
        scores.append(np.exp(np.mean([np.sum(p * (np.log(p + 1e-10) - np.log(py + 1e-10))) for p in part])))
    return np.mean(scores), np.std(scores)

# Function to generate images
def generate_and_save_images(generator, noise, captions, epoch):
    generated_images = generator([noise, captions], training=False)


# Tokenizing and padding captions
specific_captions = [
    "ethnic Boys Printed Maroon Kurta",
    "sports Men Gel Running White Sports Shoes",
    "casual Men Aventura Sandal",
    "casual Boys Expressions Yellow T-shirt"
]

# Assuming tokenizer and max_caption_len are already defined (as per your training code)
specific_captions_tokenized = tokenizer.texts_to_sequences(specific_captions)
max_caption_len = 12  # Set based on your padding length
specific_captions_padded = tf.keras.preprocessing.sequence.pad_sequences(specific_captions_tokenized, maxlen=max_caption_len, padding='post')
specific_captions_padded = tf.convert_to_tensor(specific_captions_padded)

# Assuming noise_dim is defined and generator is your trained model
noise_dim = 100  # Adjust based on your model's noise dimension
noise = tf.random.normal([len(specific_captions), noise_dim])  # Generate random noise for each caption

# Generate images from the generator
generated_images = generator([noise, specific_captions_padded], training=False)

# Display the generated images
generate_and_save_images(generator, noise, specific_captions_padded, epoch=1)

# Load real images for FID evaluation
real_image_paths = [
    '/kaggle/input/iamgestotest/762maroonkurta.jpg',  # Replace with your actual file paths
    '/kaggle/input/iamgestotest/2000white sports.jpg',
    '/kaggle/input/iamgestotest/1500men snadals.jpg',
    '/kaggle/input/iamgestotest/1208shirtsmarvel.jpg'
]

# Load real images
real_images = np.array([load_image(path) for path in real_image_paths])

# Calculate FID
fid_score = calculate_fid(real_images, generated_images)
print (f"FID Score": {fid_score:.4f})
# Out:
# FID Score: 5.986

# %% [markdown]
# # **Stack Gan**

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Embedding, LSTM, Concatenate, BatchNormalization, LeakyReLU, Conv2DTranspose, Conv2D
from tensorflow.keras.models import Model

# Parameters
vocab_size = 1155
max_caption_len = 12
embedding_dim = 100
noise_dim = 100
image_shape_stage1 = (64, 64, 3)
image_shape_stage2 = (128, 128, 3)

# ------------------------------
# Text Encoder
def build_text_encoder():
    caption_input = Input(shape=(max_caption_len,))
    x = Embedding(vocab_size, embedding_dim)(caption_input)
    x = LSTM(128)(x)
    return Model(caption_input, x, name="TextEncoder")

text_encoder = build_text_encoder()

# ------------------------------
# Generator - Stage I
def build_stage1_generator():
    noise_input = Input(shape=(noise_dim,))
    caption_input = Input(shape=(max_caption_len,))

    text_features = text_encoder(caption_input)
    merged = Concatenate()([noise_input, text_features])

    x = Dense(8 * 8 * 256, use_bias=False)(merged)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = Reshape((8, 8, 256))(x)

    x = Conv2DTranspose(128, 4, strides=2, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(64, 4, strides=2, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(3, 4, strides=2, padding='same', activation='tanh')(x)

    return Model([noise_input, caption_input], x, name="Stage1Generator")

# ------------------------------
# Discriminator - Stage I
def build_stage1_discriminator():
    image_input = Input(shape=image_shape_stage1)
    caption_input = Input(shape=(max_caption_len,))

    text_features = text_encoder(caption_input)
    text_features = Dense(64 * 64)(text_features)
    text_features = Reshape((64, 64, 1))(text_features)

    merged = Concatenate()([image_input, text_features])

    x = Conv2D(64, 4, strides=2, padding='same')(merged)
    x = LeakyReLU()(x)

    x = Conv2D(128, 4, strides=2, padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Flatten()(x)
    x = Dense(1, activation='sigmoid')(x)

    return Model([image_input, caption_input], x, name="Stage1Discriminator")

# ------------------------------
# Generator - Stage II
def build_stage2_generator(stage1_generator):
    noise_input = Input(shape=(noise_dim,))
    caption_input = Input(shape=(max_caption_len,))

    stage1_image = stage1_generator([noise_input, caption_input])

    x = Conv2D(64, 3, padding='same', activation='relu')(stage1_image)
    x = BatchNormalization()(x)

    x = Conv2DTranspose(128, 4, strides=2, padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(64, 4, strides=2, padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    output = Conv2D(3, 3, padding='same', activation='tanh')(x)
    return Model([noise_input, caption_input], output, name="Stage2Generator")

# ------------------------------
# Discriminator - Stage II
def build_stage2_discriminator():
    image_input = Input(shape=image_shape_stage2)
    caption_input = Input(shape=(max_caption_len,))

    text_features = text_encoder(caption_input)
    text_features = Dense(128 * 128)(text_features)
    text_features = Reshape((128, 128, 1))(text_features)

    merged = Concatenate()([image_input, text_features])

    x = Conv2D(64, 4, strides=2, padding='same')(merged)
    x = LeakyReLU()(x)

    x = Conv2D(128, 4, strides=2, padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Flatten()(x)
    x = Dense(1, activation='sigmoid')(x)

    return Model([image_input, caption_input], x, name="Stage2Discriminator")

# ------------------------------
# Instantiate Models
stage1_gen = build_stage1_generator()
stage1_disc = build_stage1_discriminator()
stage2_gen = build_stage2_generator(stage1_gen)
stage2_disc = build_stage2_discriminator()

stage1_gen.summary()
stage1_disc.summary()
stage2_gen.summary()
stage2_disc.summary()
# Out:
# Model: "Stage1Generator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_38            │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_37            │ (None, 100)            │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TextEncoder (Functional)  │ (None, 128)            │        362,848 │ input_layer_38[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_12            │ (None, 228)            │              0 │ input_layer_37[0][0],  │
# │ (Concatenate)             │                        │                │ TextEncoder[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_20 (Dense)          │ (None, 16384)          │      3,735,552 │ concatenate_12[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_32    │ (None, 16384)          │         65,536 │ dense_20[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_36            │ (None, 16384)          │              0 │ batch_normalization_3… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_12 (Reshape)      │ (None, 8, 8, 256)      │              0 │ leaky_re_lu_36[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_20       │ (None, 16, 16, 128)    │        524,288 │ reshape_12[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_33    │ (None, 16, 16, 128)    │            512 │ conv2d_transpose_20[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_37            │ (None, 16, 16, 128)    │              0 │ batch_normalization_3… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_21       │ (None, 32, 32, 64)     │        131,072 │ leaky_re_lu_37[0][0]   │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_34    │ (None, 32, 32, 64)     │            256 │ conv2d_transpose_21[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_38            │ (None, 32, 32, 64)     │              0 │ batch_normalization_3… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_22       │ (None, 64, 64, 3)      │          3,075 │ leaky_re_lu_38[0][0]   │
# │ (Conv2DTranspose)         │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 4,823,139 (18.40 MB)
#  Trainable params: 4,789,987 (18.27 MB)
#  Non-trainable params: 33,152 (129.50 KB)
# Model: "Stage1Discriminator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_40            │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TextEncoder (Functional)  │ (None, 128)            │        362,848 │ input_layer_40[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_21 (Dense)          │ (None, 4096)           │        528,384 │ TextEncoder[1][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_39            │ (None, 64, 64, 3)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_13 (Reshape)      │ (None, 64, 64, 1)      │              0 │ dense_21[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_13            │ (None, 64, 64, 4)      │              0 │ input_layer_39[0][0],  │
# │ (Concatenate)             │                        │                │ reshape_13[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_24 (Conv2D)        │ (None, 32, 32, 64)     │          4,160 │ concatenate_13[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_39            │ (None, 32, 32, 64)     │              0 │ conv2d_24[0][0]        │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_25 (Conv2D)        │ (None, 16, 16, 128)    │        131,200 │ leaky_re_lu_39[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_35    │ (None, 16, 16, 128)    │            512 │ conv2d_25[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_40            │ (None, 16, 16, 128)    │              0 │ batch_normalization_3… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_8 (Flatten)       │ (None, 32768)          │              0 │ leaky_re_lu_40[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_22 (Dense)          │ (None, 1)              │         32,769 │ flatten_8[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,059,873 (4.04 MB)
#  Trainable params: 1,059,617 (4.04 MB)
#  Non-trainable params: 256 (1.00 KB)
# Model: "Stage2Generator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_41            │ (None, 100)            │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_42            │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Stage1Generator           │ (None, 64, 64, 3)      │      4,823,139 │ input_layer_41[0][0],  │
# │ (Functional)              │                        │                │ input_layer_42[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_26 (Conv2D)        │ (None, 64, 64, 64)     │          1,792 │ Stage1Generator[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_36    │ (None, 64, 64, 64)     │            256 │ conv2d_26[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_23       │ (None, 128, 128, 128)  │        131,200 │ batch_normalization_3… │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_37    │ (None, 128, 128, 128)  │            512 │ conv2d_transpose_23[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_41            │ (None, 128, 128, 128)  │              0 │ batch_normalization_3… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_24       │ (None, 256, 256, 64)   │        131,136 │ leaky_re_lu_41[0][0]   │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_38    │ (None, 256, 256, 64)   │            256 │ conv2d_transpose_24[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_42            │ (None, 256, 256, 64)   │              0 │ batch_normalization_3… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_27 (Conv2D)        │ (None, 256, 256, 3)    │          1,731 │ leaky_re_lu_42[0][0]   │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 5,090,022 (19.42 MB)
#  Trainable params: 5,056,358 (19.29 MB)
#  Non-trainable params: 33,664 (131.50 KB)
# Model: "Stage2Discriminator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_44            │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ TextEncoder (Functional)  │ (None, 128)            │        362,848 │ input_layer_44[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_23 (Dense)          │ (None, 16384)          │      2,113,536 │ TextEncoder[2][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_43            │ (None, 128, 128, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_14 (Reshape)      │ (None, 128, 128, 1)    │              0 │ dense_23[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_14            │ (None, 128, 128, 4)    │              0 │ input_layer_43[0][0],  │
# │ (Concatenate)             │                        │                │ reshape_14[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_28 (Conv2D)        │ (None, 64, 64, 64)     │          4,160 │ concatenate_14[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_43            │ (None, 64, 64, 64)     │              0 │ conv2d_28[0][0]        │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_29 (Conv2D)        │ (None, 32, 32, 128)    │        131,200 │ leaky_re_lu_43[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_39    │ (None, 32, 32, 128)    │            512 │ conv2d_29[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_44            │ (None, 32, 32, 128)    │              0 │ batch_normalization_3… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_9 (Flatten)       │ (None, 131072)         │              0 │ leaky_re_lu_44[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_24 (Dense)          │ (None, 1)              │        131,073 │ flatten_9[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,743,329 (10.46 MB)
#  Trainable params: 2,743,073 (10.46 MB)
#  Non-trainable params: 256 (1.00 KB)

# %% [markdown]
# **Training 10**

# %%
# ------------------------------
# Training Setup
BATCH_SIZE = 64
EPOCHS = 10
BUFFER_SIZE = image_data.shape[0]

dataset = tf.data.Dataset.from_tensor_slices((image_data, padded_captions))
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)
gen_opt = tf.keras.optimizers.Adam(1e-4)
disc_opt = tf.keras.optimizers.Adam(1e-4)
def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    return real_loss + fake_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)
# ------------------------------
# Stage I Training Step
@tf.function
def stage1_train_step(images, captions):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        fake_images = stage1_gen([noise, captions], training=True)
        real_output = stage1_disc([images, captions], training=True)
        fake_output = stage1_disc([fake_images, captions], training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_gen = gen_tape.gradient(gen_loss, stage1_gen.trainable_variables)
    gradients_disc = disc_tape.gradient(disc_loss, stage1_disc.trainable_variables)

    gen_opt.apply_gradients(zip(gradients_gen, stage1_gen.trainable_variables))
    disc_opt.apply_gradients(zip(gradients_disc, stage1_disc.trainable_variables))
    return gen_loss, disc_loss
# ------------------------------
# Stage II Training Step
@tf.function
def stage2_train_step(images, captions):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        high_res_fake = stage2_gen([noise, captions], training=True)
        real_output = stage2_disc([images, captions], training=True)
        fake_output = stage2_disc([high_res_fake, captions], training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_gen = gen_tape.gradient(gen_loss, stage2_gen.trainable_variables)
    gradients_disc = disc_tape.gradient(disc_loss, stage2_disc.trainable_variables)

    gen_opt.apply_gradients(zip(gradients_gen, stage2_gen.trainable_variables))
    disc_opt.apply_gradients(zip(gradients_disc, stage2_disc.trainable_variables))
    return gen_loss, disc_loss

# %%
# ------------------------------
# Stage I Training Loop
print("\nStarting Stage-I Training...")
for epoch in range(1, EPOCHS + 1):
    for images, captions in dataset:
        g_loss, d_loss = stage1_train_step(images, captions)
    print(f"[Stage I] Epoch {epoch}/{EPOCHS} - Generator Loss: {g_loss.numpy():.4f}, Discriminator Loss: {d_loss.numpy():.4f}")
# Out:
# Starting Stage-I Training...
# [Stage I] Epoch 1/10 - Generator Loss: 1.4960, Discriminator Loss: 0.6836
# [Stage I] Epoch 2/10 - Generator Loss: 1.7610, Discriminator Loss: 0.8305
# [Stage I] Epoch 3/10 - Generator Loss: 1.7350, Discriminator Loss: 0.7446
# [Stage I] Epoch 4/10 - Generator Loss: 1.8204, Discriminator Loss: 0.8028
# [Stage I] Epoch 5/10 - Generator Loss: 1.6209, Discriminator Loss: 0.7308
# [Stage I] Epoch 6/10 - Generator Loss: 0.8928, Discriminator Loss: 0.9224
# [Stage I] Epoch 7/10 - Generator Loss: 1.2337, Discriminator Loss: 0.7256
# [Stage I] Epoch 8/10 - Generator Loss: 2.1988, Discriminator Loss: 0.8554
# [Stage I] Epoch 9/10 - Generator Loss: 1.5070, Discriminator Loss: 0.6248
# [Stage I] Epoch 10/10 - Generator Loss: 1.0415, Discriminator Loss: 0.9595

# %%
# ------------------------------
# Stage II Training Loop
print("\nStarting Stage-II Training...")
for epoch in range(1, EPOCHS + 1):
    for images, captions in dataset:
        g_loss, d_loss = stage1_train_step(images, captions)
    print(f"[Stage II] Epoch {epoch}/{EPOCHS} - Generator Loss: {g_loss.numpy():.4f}, Discriminator Loss: {d_loss.numpy():.4f}")
# Out:
# Starting Stage-II Training...
# [Stage II] Epoch 1/10 - Generator Loss: 2.0432, Discriminator Loss: 0.6594
# [Stage II] Epoch 2/10 - Generator Loss: 1.1412, Discriminator Loss: 0.7785
# [Stage II] Epoch 3/10 - Generator Loss: 1.1306, Discriminator Loss: 0.6802
# [Stage II] Epoch 4/10 - Generator Loss: 1.1629, Discriminator Loss: 0.7856
# [Stage II] Epoch 5/10 - Generator Loss: 1.0672, Discriminator Loss: 0.9019
# [Stage II] Epoch 6/10 - Generator Loss: 2.2695, Discriminator Loss: 0.3253
# [Stage II] Epoch 7/10 - Generator Loss: 2.3817, Discriminator Loss: 0.4596
# [Stage II] Epoch 8/10 - Generator Loss: 3.2227, Discriminator Loss: 0.3023
# [Stage II] Epoch 9/10 - Generator Loss: 1.5374, Discriminator Loss: 1.5709
# [Stage II] Epoch 10/10 - Generator Loss: 1.4896, Discriminator Loss: 0.8740

# %% [markdown]
# **Genearte iamge**

# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_image_from_caption(caption, tokenizer, stage2_gen, max_caption_len, noise_dim=100):
    # Preprocess caption
    tokens = tokenizer.texts_to_sequences([caption])
    padded_caption = tf.keras.preprocessing.sequence.pad_sequences(tokens, maxlen=max_caption_len, padding='post')

    # Convert to tensor
    padded_caption = tf.convert_to_tensor(padded_caption)

    # Generate random noise
    noise = tf.random.normal([1, noise_dim])

    # Generate image
    generated_image = stage2_gen([noise, padded_caption], training=False)[0].numpy()

    # Scale image from [-1, 1] to [0, 1]
    generated_image = (generated_image + 1) / 2.0

    # Display image
    plt.imshow(generated_image)
    plt.axis('off')
    plt.title("Generated Image")
    plt.show()

# %%
test_caption = "casual Boys white Printed T-Shirt"
generate_image_from_caption(test_caption, tokenizer, stage2_gen, max_caption_len)
test_caption = "Men Dark Brown Formal Shoes"
generate_image_from_caption(test_caption, tokenizer, stage2_gen, max_caption_len)
test_caption = "Girl's Pink White Check Top Kidswear"
generate_image_from_caption(test_caption, tokenizer, stage2_gen, max_caption_len)

# %% [markdown]
# **train 200**

# %%
# ------------------------------
# Training Setup
BATCH_SIZE = 64
EPOCHS = 200
BUFFER_SIZE = image_data.shape[0]

dataset = tf.data.Dataset.from_tensor_slices((image_data, padded_captions))
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)
gen_opt = tf.keras.optimizers.Adam(1e-4)
disc_opt = tf.keras.optimizers.Adam(1e-4)
def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    return real_loss + fake_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)
# ------------------------------
# Stage I Training Step
@tf.function
def stage1_train_step(images, captions):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        fake_images = stage1_gen([noise, captions], training=True)
        real_output = stage1_disc([images, captions], training=True)
        fake_output = stage1_disc([fake_images, captions], training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_gen = gen_tape.gradient(gen_loss, stage1_gen.trainable_variables)
    gradients_disc = disc_tape.gradient(disc_loss, stage1_disc.trainable_variables)

    gen_opt.apply_gradients(zip(gradients_gen, stage1_gen.trainable_variables))
    disc_opt.apply_gradients(zip(gradients_disc, stage1_disc.trainable_variables))
    return gen_loss, disc_loss
# ------------------------------
# Stage II Training Step
@tf.function
def stage2_train_step(images, captions):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:

generate_image_from_caption(test_caption, tokenizer, stage2_gen, max_caption_len)
test_caption = "Girl's Pink White Check Top Kidswear"
generate_image_from_caption(test_caption, tokenizer, stage2_gen, max_caption_len)

# %% [markdown]
# **Hyperparameters tune**

# %% [markdown]
# Excellent — your dual-stage text-to-image GAN model is now structurally complete with:
#
# ✅ 256x256 resolution
# ✅ Improved LSTM and dropout
# ✅ Upsampling
# ✅ Learning rate scheduler
# ✅ Loss functions

# %%
import tensorflow as tf
from tensorflow.keras.layers import (Input, Dense, Reshape, Flatten, Embedding, LSTM, Dropout,
                                     Concatenate, BatchNormalization, LeakyReLU, Conv2DTranspose, Conv2D)
from tensorflow.keras.models import Model

# Parameters
vocab_size = 1155
max_caption_len = 12
embedding_dim = 100
noise_dim = 100
image_shape_stage1 = (64, 64, 3)
image_shape_stage2 = (256, 256, 3)

# Text Encoder
def build_text_encoder():
    caption_input = Input(shape=(max_caption_len,))
    x = Embedding(vocab_size, embedding_dim)(caption_input)
    x = LSTM(512)(x)
    x = Dropout(0.5)(x)
    return Model(caption_input, x, name="TextEncoder")

text_encoder = build_text_encoder()

# Stage I Generator
def build_stage1_generator():
    noise_input = Input(shape=(noise_dim,))
    caption_input = Input(shape=(max_caption_len,))

    text_features = text_encoder(caption_input)
    merged = Concatenate()([noise_input, text_features])

    x = Dense(8 * 8 * 256, use_bias=False)(merged)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = Reshape((8, 8, 256))(x)

    x = Conv2DTranspose(128, 4, strides=2, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(64, 4, strides=2, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(3, 4, strides=2, padding='same', activation='tanh')(x)

    return Model([noise_input, caption_input], x, name="Stage1Generator")

# Stage I Discriminator
def build_stage1_discriminator():
    image_input = Input(shape=image_shape_stage1)
    caption_input = Input(shape=(max_caption_len,))

    text_features = text_encoder(caption_input)
    text_features = Dense(64 * 64)(text_features)
    text_features = Reshape((64, 64, 1))(text_features)

    merged = Concatenate()([image_input, text_features])

    x = Conv2D(64, 4, strides=2, padding='same')(merged)
    x = LeakyReLU()(x)
    x = Conv2D(128, 4, strides=2, padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = Conv2D(256, 4, strides=2, padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Flatten()(x)
    x = Dense(1, activation='sigmoid')(x)

    return Model([image_input, caption_input], x, name="Stage1Discriminator")

# Stage II Generator (256x256)
def build_stage2_generator(stage1_generator):
    noise_input = Input(shape=(noise_dim,))
    caption_input = Input(shape=(max_caption_len,))

    stage1_image = stage1_generator([noise_input, caption_input])

    x = Conv2D(64, 3, padding='same', activation='relu')(stage1_image)
    x = BatchNormalization()(x)

    x = Conv2DTranspose(128, 4, strides=2, padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(64, 4, strides=2, padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(32, 4, strides=2, padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    output = Conv2D(3, 3, padding='same', activation='tanh')(x)
    return Model([noise_input, caption_input], output, name="Stage2Generator")

# Stage II Discriminator

def build_stage2_discriminator():
    image_input = Input(shape=image_shape_stage2)
    caption_input = Input(shape=(max_caption_len,))

    text_features = text_encoder(caption_input)
    text_features = Dense(256 * 256)(text_features)
    text_features = Reshape((256, 256, 1))(text_features)


    merged = Concatenate()([image_input, text_features])

    x = Conv2D(64, 4, strides=2, padding='same')(merged)
    x = LeakyReLU()(x)
    x = Conv2D(128, 4, strides=2, padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = Conv2D(256, 4, strides=2, padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Flatten()(x)
    x = Dense(1, activation='sigmoid')(x)

    return Model([image_input, caption_input], x, name="Stage2Discriminator")

# Instantiate models
stage1_gen = build_stage1_generator()
stage1_disc = build_stage1_discriminator()
stage2_gen = build_stage2_generator(stage1_gen)
stage2_disc = build_stage2_discriminator()

# Optimizers with scheduler
initial_lr = 2e-4
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=initial_lr,
    decay_steps=10000,
    decay_rate=0.96,
    staircase=True
)
gen_opt = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
disc_opt = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# Loss functions
def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    return real_loss + fake_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %% [markdown]
# **epoch 200**

# %%
# EPOCHS
EPOCHS = 200

# %%
# ------------------------------
# Stage I Training Loop
print("\nStarting Stage-I Training...")
for epoch in range(1, EPOCHS + 1):
    for images, captions in dataset:
        g_loss, d_loss = stage1_train_step(images, captions)
    print(f"[Stage I] Epoch {epoch}/{EPOCHS} - Generator Loss: {g_loss.numpy():.4f}, Discriminator Loss: {d_loss.numpy():.4f}")
# Out:
# Starting Stage
# [Stage II] Epoch 173/200 - Generator Loss: 2.5246, Discriminator Loss: 0.2699
# [Stage II] Epoch 174/200 - Generator Loss: 4.4518, Discriminator Loss: 0.4406
# [Stage II] Epoch 175/200 - Generator Loss: 1.0908, Discriminator Loss: 0.7080
# [Stage II] Epoch 176/200 - Generator Loss: 2.2922, Discriminator Loss: 0.4463
# [Stage II] Epoch 177/200 - Generator Loss: 1.7063, Discriminator Loss: 0.3511
# [Stage II] Epoch 178/200 - Generator Loss: 1.9254, Discriminator Loss: 0.2997
# [Stage II] Epoch 179/200 - Generator Loss: 3.0802, Discriminator Loss: 0.1306
# [Stage II] Epoch 180/200 - Generator Loss: 1.8894, Discriminator Loss: 0.2370
# [Stage II] Epoch 181/200 - Generator Loss: 3.5442, Discriminator Loss: 0.4852
# [Stage II] Epoch 182/200 - Generator Loss: 5.2187, Discriminator Loss: 0.5488
# [Stage II] Epoch 183/200 - Generator Loss: 3.4156, Discriminator Loss: 0.2840
# [Stage II] Epoch 184/200 - Generator Loss: 3.8892, Discriminator Loss: 0.0478
# [Stage II] Epoch 185/200 - Generator Loss: 1.5139, Discriminator Loss: 0.3377
# [Stage II] Epoch 186/200 - Generator Loss: 1.4328, Discriminator Loss: 0.3859
# [Stage II] Epoch 187/200 - Generator Loss: 2.6979, Discriminator Loss: 0.1243
# [Stage II] Epoch 188/200 - Generator Loss: 3.7313, Discriminator Loss: 0.2008
# [Stage II] Epoch 189/200 - Generator Loss: 2.7017, Discriminator Loss: 0.1240
# [Stage II] Epoch 190/200 - Generator Loss: 3.9857, Discriminator Loss: 0.2210
# [Stage II] Epoch 191/200 - Generator Loss: 5.6152, Discriminator Loss: 1.8741
# [Stage II] Epoch 192/200 - Generator Loss: 4.4910, Discriminator Loss: 0.1410
# [Stage II] Epoch 193/200 - Generator Loss: 2.0252, Discriminator Loss: 0.2857
# [Stage II] Epoch 194/200 - Generator Loss: 1.5444, Discriminator Loss: 0.3917
# [Stage II] Epoch 195/200 - Generator Loss: 6.2997, Discriminator Loss: 0.9126
# [Stage II] Epoch 196/200 - Generator Loss: 2.1450, Discriminator Loss: 0.1863
# [Stage II] Epoch 197/200 - Generator Loss: 2.1829, Discriminator Loss: 0.2937
# [Stage II] Epoch 198/200 - Generator Loss: 3.0840, Discriminator Loss: 0.0852
# [Stage II] Epoch 199/200 - Generator Loss: 3.3422, Discriminator Loss: 0.0541
# [Stage II] Epoch 200/200 - Generator Loss: 3.3398, Discriminator Loss: 0.2736

# %%
test_caption = "casual Boys white Printed T-Shirt"
generate_image_from_caption(test_caption, tokenizer, stage2_gen, max_caption_len)
test_caption = "Men Dark Brown Formal Shoes"
generate_image_from_caption(test_caption, tokenizer, stage2_gen, max_caption_len)
test_caption = "Girl's Pink White Check Top Kidswear"
generate_image_from_caption(test_caption, tokenizer, stage2_gen, max_caption_len)

# %% [markdown]
# # Stable Diffuisn **Pretraiuned**

# %%
import pandas as pd
import re
import string

# Clean text function
def clean_text(text):
    if pd.isnull(text):
        return ""
    text = text.lower()  # Convert text to lowercase
    text = re.sub(f"[{string.punctuation}]", "", text)  # Remove punctuation
    text = re.sub(r"[^a-z\s]", "", text)  # Keep only alphabetic characters and spaces
    text = re.sub(r"\b(\w+)( \1\b)+", r"\1", text)  # Remove duplicate consecutive words
    text = re.sub(r"\s+", " ", text).strip()  # Remove extra spaces
    return text


df['final_caption'] = df['CombinedTitle'].fillna('')
# Replace NaN in 'final_caption' with "-"
df['final_caption'] = df['CombinedTitle'].fillna('-')

# Create a new DataFrame containing only 'ImagePath' and 'final_caption'
df_final = df[['ImageURL', 'CombinedTitle']]

# Save this new DataFrame to a CSV file
df_final.to_csv("fashion_dataset_image_and_caption100.csv", index=False)

print("✅ CSV with ImagePath and final_caption saved successfully!")
# Out:
# ✅ CSV with ImagePath and final_caption saved successfully!

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

import pandas as pd
from diffusers import StableDiffusionPipeline, AutoencoderKL, UNet2DConditionModel
from transformers import CLIPTokenizer, CLIPTextModel
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from torchvision import transforms
import requests
from io import BytesIO
from tqdm import tqdm

# Dataset class
class FashionDataset(Dataset):
    def __init__(self, dataset_path):
        self.dataset = pd.read_csv(dataset_path)
        self.transform = transforms.Compose([
            transforms.Resize((256, 256)),
            transforms.ToTensor(),
            transforms.Normalize([0.5], [0.5]),
        ])
        self.tokenizer = CLIPTokenizer.from_pretrained("openai/clip-vit-large-patch14")

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        row = self.dataset.iloc[idx]
        image_url = row["ImageURL"]
        caption = row["CombinedTitle"]

        try:
            response = requests.get(image_url)
            image = Image.open(BytesIO(response.content)).convert("RGB")
        except Exception as e:
            print(f"Error downloading image {image_url}: {e}")
            image = Image.new("RGB", (256, 256))

        image = self.transform(image)
        token = self.tokenizer(caption, padding="max_length", truncation=True, max_length=77, return_tensors="pt")

        return {"pixel_values": image, "input_ids": token["input_ids"].squeeze(0)}

# Training function
def train():
    dataset_path = "/kaggle/working/fashion_dataset_image_and_caption100.csv"
    train_dataset = FashionDataset(dataset_path)
    dataloader = DataLoader(train_dataset, batch_size=1, shuffle=True)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    text_encoder = CLIPTextModel.from_pretrained("openai/clip-vit-large-patch14").to(device).half()
    vae = AutoencoderKL.from_pretrained("CompVis/stable-diffusion-v1-4", subfolder="vae").to(device).half()
    unet = UNet2DConditionModel.from_pretrained("CompVis/stable-diffusion-v1-4", subfolder="unet").to(device).half()

    unet.enable_gradient_checkpointing()
    text_encoder.gradient_checkpointing_enable()

    optimizer = torch.optim.AdamW(unet.parameters(), lr=1e-4)

    for epoch in range(3):
        for batch in tqdm(dataloader):
            images = batch["pixel_values"].to(device).half()
            input_ids = batch["input_ids"].to(device)

            with torch.no_grad():
                latents = vae.encode(images).latent_dist.sample() * 0.18215

            noise = torch.randn_like(latents).to(device)
            timesteps = torch.randint(0, 1000, (latents.shape[0],), device=device).long()
            noisy_latents = latents + noise
            encoder_hidden_states = text_encoder(input_ids)[0]

            noise_pred = unet(noisy_latents, timesteps, encoder_hidden_states).sample
            loss = torch.nn.functional.mse_loss(noise_pred, noise)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            torch.cuda.empty_cache()

        print(f"Epoch {epoch + 1}")

    unet.save_pretrained("fashion_lora_output")

if __name__ == "__main__":
    train()
# Out:
# tokenizer_config.json:   0%|          | 0.00/905 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/961k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.52k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# 100%|██████████| 2906/2906 [27:41<00:00,  1.75it/s]
# Epoch 1
# 100%|██████████| 2906/2906 [27:46<00:00,  1.74it/s]
# Epoch 2
# 100%|██████████| 2906/2906 [30:09<00:00,  1.61it/s]
# Epoch 3

# %% [markdown]
# **Testing on finetuned**

# %%
from diffusers import StableDiffusionPipeline, DDIMScheduler, AutoencoderKL, UNet2DConditionModel
from transformers import CLIPTextModel, CLIPTokenizer
import torch

def generate_images(prompts):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Load components
    tokenizer = CLIPTokenizer.from_pretrained("openai/clip-vit-large-patch14")
    text_encoder = CLIPTextModel.from_pretrained("openai/clip-vit-large-patch14").to(device)
    vae = AutoencoderKL.from_pretrained("CompVis/stable-diffusion-v1-4", subfolder="vae").to(device)
    unet = UNet2DConditionModel.from_pretrained("fashion_lora_output").to(device)
    scheduler = DDIMScheduler.from_pretrained("CompVis/stable-diffusion-v1-4", subfolder="scheduler")

    # Load Stable Diffusion pipeline
    pipe = StableDiffusionPipeline(
        vae=vae,
        text_encoder=text_encoder,
        tokenizer=tokenizer,
        unet=unet,
        scheduler=scheduler,
        safety_checker=None,
        feature_extractor=None,
    ).to(device)

    # Generate images
    for i, prompt in enumerate(prompts):
        print(f"Generating image {i+1} for prompt: {prompt}")
        image = pipe(prompt=prompt, num_inference_steps=50, guidance_scale=7.5).images[0]
        image.show()
        # image.save(f"output_image_{i+1}.png")  # Uncomment to save images

# Example prompts
fashion_prompts = [
    "casual men white tshirt",
    "casual girl greens shirt kidswear",
    "casual men black running shoes",
    "formal men brown shoes",
]

generate_images(fashion_prompts)
# Out:
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# Generating image 1 for prompt: casual men white tshirt
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=256x256>
# Generating image 2 for prompt: casual girl greens shirt kidswear
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=256x256>
# Generating image 3 for prompt: casual men black running shoes
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=256x256>
# Generating image 4 for prompt: formal men brown shoes
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=256x256>

# %% [markdown]
# # **Prompts:**

# %%
#I’m working on a project where I want to generate images from text descriptions, specifically fashion product captions. Can you suggest the best deep learning models or architectures for text-to-image generation
# explain which ones are suitable for high-quality and semantically accurate outputs? Also, which ones work well with small or medium-sized datasets?
#

# %% [markdown]
# # **Tokenizer error **

# %%
Tokenizer error
# Storing raw captions (df['CombinedTitle']) instead of the padded captions (padded_captions)
# Potential mismatch between num_words=2456 and actual vocabulary:

# %% [markdown]
# # **GAN**

# %%
#i have a fashion dataset where captions are just combined titles and images are in url form. what do i need to do to train gan
#1)ValueError: Input 0 of layer "functional_1" is incompatible with the layer: expected shape=(None, 64, 64, 3), found shape=(None, 128, 128, 3)

 # WHY NY GENERATED IMAGES IS BLURRY AT 10 EPOCHOS

 #how can I improve the quality and diversity of generated fashion images when conditioning on text captions
 #3)Error:ValueError: Shapes (None, 64) and (None, 256) are incompatible.fix error

  # why my images are blurry

  #
  #

# %% [markdown]
# # style gan

# %%
#  1. Using build_text_encoder() Twice Creates Two Separate Models  Issue: You are calling build_text_encoder() separately in both the generator and discriminator, which creates two different instances with unshared weights.


# 3. Untrained Text Encoder During GAN Training Issue: Even if shared, the text encoder must be trainable. If you freeze it (common mistake), it won’t adapt to the generator/discriminator’s needs.
# Inconsistent Feature Dimension in Discriminator  Issue: You reshape text features to (64, 64, 1) using this line:
#WHY NY GENERATED IMAGES IS BLURRY AT  600 EPOCHOS now suggest my another model for better image gneration

# %% [markdown]
# # attention gan

# %%
#  can you add attention layer into my gan model here is my gan code
#  why my images are blurry

# %% [markdown]
# # stack gan

# %%
#Can you suggest and implement architectural improvements to enhance the initial image generation
# My discriminators (Stage I and II) aren't performing well. I added more Conv2D layers and increased filters up to 256, but training remains unstable. Can you redesign both discriminators with better feature extraction
# In Stage II Generator, I upscale from 64x64 to 256x256 using Conv2DTranspose layers, but the output is still blurry. Can you revise the upsampling strategy

# %% [markdown]
# stable diffusion

# %%
#Write a PyTorch training script that fine-tunes just the U-Net part of Stable Diffusion using a custom fashion dataset. The dataset includes images (from links) and their captions
#Use the diffusers library to load Stable Diffusion components. Use CLIP to turn the captions into vectors, and AutoencoderKL to turn the images into a compressed form.
#The script should download the images from the internet using their URLs and process the captions with CLIP's tokenizer."
#Now how can i geanearte image from finetuned model

# %% [markdown]
# evalution
